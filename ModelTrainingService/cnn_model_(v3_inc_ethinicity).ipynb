# %% [markdown]
# # Age & Gender Detection with CNN
#
# **Dataset : UTKFace**
#
# UTKFace dataset is a large-scale face dataset with range from 0 to 116 years old. It consists of over 23,708 face images with labels of age, gender, and ethnicity. The images cover large variation in pose, facial expression, illumination, occlusion, resolution, etc.
#
# Since the dataset is `aligned and cropped` faces available to train the model. Have to say that any face input for testing must be cropped and aligned vertically to large extent.

# %%
# Essential libraries
import os
import glob
import seaborn as sns
import scipy.io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras import applications,activations
from keras_preprocessing.image import img_to_array, load_img
from keras.preprocessing import image
from keras import optimizers,utils
from keras.utils import plot_model
from keras.models import Sequential, Model
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D,BatchNormalization,ZeroPadding2D, Input
from keras.layers import Conv2D, Activation,MaxPooling2D
from keras import backend as k
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping

# %%
# Mounting the directory for the dataset to be read.
dataset_folder = '../ModelTrainingService/input/utkface-new/UTKFace/'
training_split = 0.8
image_width = 64
image_height = 64

dataset_dict = {
    'age_id': {'0-24': 0, '25-49':1, '50-74':2, '75-99':3, '100-124':4},
    'race_id': {0: 'white', 1: 'black', 2: 'asian', 3: 'indian', 4: 'others'},
    'gender_id': {0: 'male', 1: 'female'}
}

dataset_dict['age_temp'] = dict((a, i) for i, a in dataset_dict['age_id'].items())          # (Age: id)
dataset_dict['gender_temp'] = dict((g, i) for i, g in dataset_dict['gender_id'].items())    # (Gender: id)
dataset_dict['race_temp'] = dict((r, i) for i, r in dataset_dict['race_id'].items())        # (Race: id)

# %%
# Function to extract the data from our dataset by iterating over each file of the UTK dataset and
# return a Pandas Dataframe with all the fields (age, gender and sex).

def parse_dataset(dataset_path, ext='jpg'):

    def parse_info_from_file(path):  #Parsing info from a file

        try:
            file_name = os.path.split(path)[1]
            file_name = os.path.splitext(file_name)[0]
            age, gender, race, _ = file_name.split('_')

            return int(age), dataset_dict['gender_id'][int(gender)], dataset_dict['race_id'][int(race)]
        except Exception as ex:
            return None, None, None

    files = glob.glob(os.path.join(dataset_path, "*.%s" % ext))

    records = []
    for file in files:
        info = parse_info_from_file(file)
        records.append(info) # To place new items in the available space

    df = pd.DataFrame(records)
    df['file'] = files
    df.columns = ['age', 'gender', 'race', 'file']


    df = df.dropna() # To remove the rows that contains NULL values.

    return df

# %%
# Dataset before indexing
df = parse_dataset(dataset_folder)
df.head()
# Out:
#    age  gender   race                                               file
# 0  100    male  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 1  100    male  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 2  100  female  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 3  100  female  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 4  100  female  white  ../ModelTrainingService/input/utkface-new/UTKF...

# %%
# No NAN values, means our dataset is already clean.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23708 entries, 0 to 23707
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     23708 non-null  int64
#  1   gender  23708 non-null  object
#  2   race    23708 non-null  object
#  3   file    23708 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 741.0+ KB

# %%
# Lower percentile - 25, median - 50 & upper percentile - 75 (for numerical data)
df.describe()
# Out:
#                 age
# count  23708.000000
# mean      33.303484
# std       19.886112
# min        1.000000
# 25%       23.000000
# 50%       29.000000
# 75%       45.000000
# max      116.000000

# %%
# Mean age by gender
df.groupby(['gender']).mean('age')
# Out:
#               age
# gender
# female  30.684280
# male    35.695666

# %%
# Mean age by race
df.groupby(['race']).mean('age')
# Out:
#               age
# race
# asian   25.877729
# black   33.861498
# indian  31.540241
# others  23.169031
# white   37.980949

# %% [markdown]
# # Data analysis & visualization (EDA)
#
# We can create here a function to generate some pie plots. We also look at the other visualization below to understand and grasp better about the data distribution to crete
# more efficient training, validation and test processes.

# %%
import plotly.graph_objects as go
from IPython.display import display, Image

def plot_distribution(pd_series):

    labels = pd_series.value_counts().index.tolist()
    counts = pd_series.value_counts().values.tolist()

    pie_plot = go.Pie(labels=labels, values=counts, hole=.3)
    fig = go.Figure(data=[pie_plot])
    fig.update_layout(title_text='Distribution for %s' % pd_series.name)

    img_bytes = fig.to_image(format="png")
    #fig.show()
    display(Image(img_bytes))

# # Same as bar plot. Creating bins for age ranges and plotting that data. This helps us to see grouped age into bins with percentages.
bins = [0, 10, 20, 30, 40, 60, 80, np.inf]
names = ['<10', '10-20', '20-30', '30-40', '40-60', '60-80', '80+']
age_binned = pd.cut(df['age'], bins, labels=names)
plot_distribution(age_binned)

# %%
# Uniform distribution to a large extent. Although, males slightly exceed females in numbers.No need to change gender in data.
# Pretty well-balanced ! Let's also visualize this on a bar graph (to get better understanding of numbers)
x = (df.gender=='male').sum()
y = (df.gender=='female').sum()

# Males over 12k while females close to 12k
labels = ['male','female']
colors = [ 'r', 'g']
gender_pie = [x,y]
explode = (0, 0)  # explode the 2nd slice (i.e. 'female')
plt.pie(gender_pie,labels = labels,
        colors = colors,
        explode=explode,
        radius=1.5,
        autopct='%.1f%%',
        textprops={'color':"Black", 'size':15},
        startangle=90)
plt.legend(gender_pie, bbox_to_anchor=(1.1, 1.1), fontsize='x-large')
plt.show()

# %%
# Distribution for race
x = (df.race == 'white').sum()
y = (df.race == 'black').sum()
z = (df.race == 'asian').sum()
a = (df.race == 'indian').sum()
b = (df.race == 'others').sum()

race_pie = [x, y, z, a, b]
labels = ['white', 'black', 'asian', 'indian', 'others']
colors = ['g', 'r', 'b', 'y', 'm']
plt.pie(race_pie, labels=labels, colors=colors, radius=1.5, autopct='%.1f%%', textprops={'color':"Black", 'size':10},)
plt.show()

# %%
# The population is mostly between 20-30 age group, the dataset is not very well-balanced. We try to embrace this imbalance through imagedatagenerator below.
ages = df['age']
nbins = 120
plt.figure(figsize=(15,8))
plt.hist(ages,nbins,color='red',histtype='bar')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Number of datapoints')
plt.show()

# %%
# Males over 12k & females close to 12k
sns.countplot(x='gender', data=df);

# %%
# Gives the mean age of both genders of all races
sns.catplot(x='race', y='age', hue='gender', data=df,kind='bar', height=5);

# %%
# We see that most of the males are between 25 and 55, whereas most of the females are between 20 and 40.
# Grouping by race, there is good amount of variations in different races.
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
_ = sns.boxplot(data=df, x='gender', y='age', ax=ax1)
_ = sns.boxplot(data=df, x='race', y='age', ax=ax2)

# %%
# RUN THIS CELL ONLY ONCE
# To create age groups
df['age'] = df['age']//25

''' This basically makes 5 divisions in age-groups -
1. 0-24
2. 25-49
3. 50-74
4. 75-99
5. 100-124 '''

x = (df.age==0).sum()
y = (df.age==1).sum()
z = (df.age==2).sum()
a = (df.age==3).sum()
b = (df.age==4).sum()
c = (df.age==5).sum() # To see that nothing left in the dataset

print(x,' ', y,' ', z,' ', a,' ', b, ' ', c,' ')
# Out:
# 6903   11816   3990   967   32   0

# %%
# After distribition of the ages into groups, we have now age groups 0 to 4 for age feature which contains ages from 1y to 116y.
df.head()
# Out:
#    age  gender   race                                               file
# 0    4    male  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 1    4    male  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 2    4  female  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 3    4  female  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 4    4  female  white  ../ModelTrainingService/input/utkface-new/UTKF...

# %% [markdown]
# # Data image generator
# To be able to use as input to our model, below is the keras image data generator by creating batches of image data to feed the multi-output predictions.

# %%
# Data image generator for augmenting the data
# Generating batches of data, which will be used to feed our multi-output model with both the images and their labels.
import cv2
from keras.utils import to_categorical, normalize
from PIL import Image, ImageFont

class UtkFaceDataGenerator():

    # Data generator for the UTKFace dataset. This class should be used when training our Keras multi-output model.
    def __init__(self, df):
        self.df = df

    def generate_split_indexes(self):
      p = np.random.permutation(len(self.df))
      train_df = int(len(self.df) * training_split)
      train_idx = p[:train_df]
      test_idx = p[train_df:]

      train_df = int(train_df * training_split)
      train_idx, valid_idx = train_idx[:train_df], train_idx[train_df:]


      # converts alias to id
      self.df['age_id'] = self.df['age'].map(lambda age: dataset_dict['age_temp'][age])
      self.df['gender_id'] = self.df['gender'].map(lambda gender: dataset_dict['gender_temp'][gender])
      self.df['race_id'] = self.df['race'].map(lambda race: dataset_dict['race_temp'][race])
      #self.max_age = self.df['age'].max()

      return train_idx, valid_idx, test_idx

    def preprocess_image(self, img_path):

      # Used to perform some minor preprocessing (BGR2RGB) on the image before inputting into the network because matplotlib plot function expects RGB.

      im = cv2.imread(img_path)
      im = cv2.resize(im, (image_width, image_height))
      im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
      im = np.array(im) / 255.0

      return im

    def generate_images(self, image_idx, is_training, batch_size=16):
      """
      Used to generate a batch with images when training/testing/validating our Keras model.
      """

      # arrays to store our batched data
      images, ages, races, genders = [], [], [], []
      while True:
        for idx in image_idx:
          person = self.df.iloc[idx]

          age = person['age']
          race = person['race_id']
          gender = person['gender_id']
          file = person['file']

          im = self.preprocess_image(file)

          #ages.append(age / self.max_age)
          ages.append(to_categorical(age,len(dataset_dict['age_id'])))
          races.append(to_categorical(race, len(dataset_dict['race_id'])))
          genders.append(to_categorical(gender, len(dataset_dict['gender_id'])))
          images.append(im)

          # yielding condition
          if len(images) >= batch_size:
            yield np.array(images), [np.array(ages), np.array(races), np.array(genders)]
            images, ages, races, genders = [], [], [], []

        if not is_training:
          break

data_generator = UtkFaceDataGenerator(df)
train_idx, valid_idx, test_idx = data_generator.generate_split_indexes()

print('Train dataset lenght: ', len(train_idx))
print('Validation dataset lenght: ', len(valid_idx))
print('Test dataset lenght: ', len(test_idx))
# Out:
# Train dataset lenght:  15172
# Validation dataset lenght:  3794
# Test dataset lenght:  4742

# %% [markdown]
# ## Model Architecture

# %%
# Source: https://pyimagesearch.com/2018/06/04/keras-multiple-outputs-and-multiple-losses/
# CNN Model Architecture by splitting the labels (age, gender, race) for flatten, dropout and activation of the layers.
from keras.layers.convolutional import Conv2D, SeparableConv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Dropout
from keras.layers.core import Lambda
from keras.layers.core import Dense
from keras.models import Model
from keras.layers import BatchNormalization, Resizing, Rescaling, RandomFlip, RandomRotation
from keras.layers import SpatialDropout2D
from keras.layers import Flatten
from keras.layers import Input
from keras.regularizers import l2
import tensorflow as tf

# SeparableConv2D: A variation of the traditional convolution that was to compute it faster than conv2D.
# "same" vs "valid": Output size is the "same" results in padding with zeros evenly to the left/right or up/down, while "valid" is no padding.
# Source for more detail about padding: https://stackoverflow.com/questions/37674306/what-is-the-difference-between-same-and-valid-padding-in-tf-nn-max-pool-of-t
# BatchNormalization: To speed up training and to use higher learning rates, making learning easier and to distribute the data uniformly across a mean
#                     that the network sees best as well as to guarantee that the values are within a healthy range, avoiding saturation and vanishing gradients.
# MaxPooling2D: To downsample the input along its spatial dimensions (height and width) by taking the maximum value over an input window defined by pool_size for each channel.
# SpatialDropout2D: To drop the entire 2D feature maps instead of individual elements as dropout does.
# Strides: The window for shifting.
# Source: https://stackoverflow.com/questions/59634780/correct-order-for-spatialdropout2d-batchnormalization-and-activation-function
# Dropouts: To prevent over-fitting the model during training
# relu(Rectifier Linear Unit): Activation to prevent exponential growth in the computation and the emergence of the “vanishing gradient” problem
#                               by keeping gradient always high.
# Dense layer: To create fully connected layers, in which (linear) every output depends on every input after usage of Convolutional Layers with fewer parameters
# by forcing every input to the function and let the neurol network to learn its relation to the output.


class UtkMultiOutputModel():
    """
    Used to generate our multi-output model. This CNN contains three branches, one for age, other for
    sex and another for race. Each branch contains a sequence of Convolutional Layers that is defined
    on the make_default_hidden_layers method.
    """

    def hidden_layers(self, inputs):

        # To generate a default set of hidden layers. Structured as => Conv2D -> Activation "relu" -> BatchNormalization -> Pooling -> Dropout

        model_arc = Conv2D(16, (3, 3), padding="same", use_bias=True)(inputs)
        model_arc = Activation("relu")(model_arc)
        model_arc = MaxPooling2D(pool_size=(2, 2))(model_arc)
        #model_arc = BatchNormalization(axis=-1)(model_arc)

        model_arc = Conv2D(32, (3, 3), padding="same", use_bias=True)(model_arc)
        model_arc = Activation("relu")(model_arc)
        model_arc = MaxPooling2D(pool_size=(2, 2))(model_arc)
        #model_arc = BatchNormalization(axis=-1)(model_arc)

        #model_arc = Conv2D(64, (3, 3), padding="same", use_bias=True, kernel_regularizer = l2( l=0.01))(model_arc)
        model_arc = Conv2D(32, (3, 3), padding="same", use_bias=True)(model_arc)
        model_arc = Activation("relu")(model_arc)
        model_arc = Dropout(0.2)(model_arc)
        model_arc = MaxPooling2D(pool_size=(2, 2))(model_arc)
        #model_arc = BatchNormalization(axis=-1)(model_arc)

        model_arc = Conv2D(64, (3, 3), padding="same", use_bias=True)(model_arc)
        model_arc = Activation("relu")(model_arc)
        model_arc = Dropout(0.2)(model_arc)
        model_arc = MaxPooling2D(pool_size=(2, 2))(model_arc)
        #model_arc = BatchNormalization(axis=-1)(model_arc)
        # model_arc = SpatialDropout2D(0.1)(model_arc)

        # model_arc = SeparableConv2D(128, (3, 3), padding="same")(model_arc)
        # model_arc = Activation("relu")(model_arc)
        # model_arc = MaxPooling2D(pool_size=(2, 2))(model_arc)
        # model_arc = BatchNormalization(axis=-1)(model_arc)
        # model_arc = SpatialDropout2D(0.1)(model_arc)

        # model_arc = SeparableConv2D(128, (3, 3), padding="same")(model_arc)
        # model_arc = Activation("relu")(model_arc)
        # model_arc = MaxPooling2D(pool_size=(2, 2))(model_arc)
        # model_arc = BatchNormalization(axis=-1)(model_arc)
        # model_arc = SpatialDropout2D(0.2)(model_arc)

        # model_arc = SeparableConv2D(128, (3, 3), padding="same")(model_arc)
        # model_arc = Activation("relu")(model_arc)
        # model_arc = MaxPooling2D(pool_size=(2, 2))(model_arc)
        # model_arc = BatchNormalization(axis=-1)(model_arc)
        # model_arc = SpatialDropout2D(0.2)(model_arc)

        return model_arc

    def build_race_branch(self, inputs):

        # Race branch is structured as => Conv -> BatchNormalization -> Pool -> Dropout blocks, followed by the Dense output layer.
        model_arc = self.hidden_layers(inputs)
        model_arc = Flatten()(model_arc)

        #model_arc = Dense(128, use_bias = True, kernel_regularizer = l2( l=0.01))(model_arc)
        model_arc = Dense(128, use_bias = True)(model_arc)
        model_arc = Activation("relu")(model_arc)
        model_arc = Dropout(0.2)(model_arc)
        #model_arc = BatchNormalization()(model_arc)

        model_arc = Dense(64, use_bias=True)(model_arc)
        model_arc = Activation("relu")(model_arc)
        model_arc = Dropout(0.2)(model_arc)
        #model_arc = BatchNormalization()(model_arc)

        # model_arc = Dense(32)(model_arc)
        # model_arc = Activation("relu")(model_arc)
        # model_arc = Dropout(0.2)(model_arc)
        # model_arc = BatchNormalization()(model_arc)

        model_arc = Dense(5, use_bias=True)(model_arc)
        model_arc = Activation("softmax", name="race")(model_arc)

        return model_arc

    def build_gender_branch(self, inputs):

        # The gender branch is structured as = Conv -> BatchNormalization -> Pool -> Dropout blocks, followed by the Dense output layer.
        model_arc = self.hidden_layers(inputs)
        model_arc = Flatten()(model_arc)

        model_arc = Dense(64, use_bias = True)(model_arc)
        model_arc = Activation("relu")(model_arc)
        model_arc = Dropout(0.2)(model_arc)
        #model_arc = BatchNormalization()(model_arc)

        model_arc = Dense(32, use_bias=True)(model_arc)
        model_arc = Activation("relu")(model_arc)
        model_arc = Dropout(0.2)(model_arc)
        #model_arc = BatchNormalization()(model_arc)

        model_arc = Dense(2, use_bias=True)(model_arc)
        model_arc = Activation("sigmoid", name="gender")(model_arc)

        return model_arc

    def build_age_branch(self, inputs):

        # The age branch is structured as = Conv -> BatchNormalization -> Pool -> Dropout blocks, followed by the Dense output layer.
        model_arc = self.hidden_layers(inputs)
        model_arc = Flatten()(model_arc)

        model_arc = Dense(128, use_bias = True)(model_arc)
        model_arc = Activation("relu")(model_arc)
        model_arc = Dropout(0.2)(model_arc)
        #model_arc = BatchNormalization()(model_arc)

        model_arc = Dense(64, use_bias=True)(model_arc)
        model_arc = Activation("relu")(model_arc)
        model_arc = Dropout(0.2)(model_arc)
        #model_arc = BatchNormalization()(model_arc)

        # model_arc = Dense(32)(model_arc)
        # model_arc = Activation("relu")(model_arc)
        # model_arc = BatchNormalization()(model_arc)
        # model_arc = Dropout(0.2)(model_arc)

        model_arc = Dense(5, use_bias=True)(model_arc)
        model_arc = Activation("softmax", name="age")(model_arc)

        return model_arc

    # To assemble the output model with their determined height and width.
    def assemble_model(self, width, height):

        input_shape = (height, width, 3)
        inputs = Input(shape=input_shape)



        age_branch = self.build_age_branch(inputs)
        race_branch = self.build_race_branch(inputs)
        gender_branch = self.build_gender_branch(inputs)
        model = Model(inputs=inputs,
                     outputs = [age_branch, race_branch, gender_branch],
                     name="face_net")
        return model

model = UtkMultiOutputModel().assemble_model(image_width, image_height)

# To print out and save the layer model plot as png
from keras.utils import plot_model
plot_model(model, to_file='../ModelTrainingService/cnn_model_plot(latest).png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "face_net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 64, 64, 16)   448         ['input_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 16)   448         ['input_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 16)   448         ['input_1[0][0]']
#
#  activation (Activation)        (None, 64, 64, 16)   0           ['conv2d[0][0]']
#
#  activation_6 (Activation)      (None, 64, 64, 16)   0           ['conv2d_4[0][0]']
#
#  activation_12 (Activation)     (None, 64, 64, 16)   0           ['conv2d_8[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 16)   0           ['activation[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 16)  0           ['activation_6[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 32, 32, 16)  0           ['activation_12[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 32)   4640        ['max_pooling2d[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 32)   4640        ['max_pooling2d_4[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 32)   4640        ['max_pooling2d_8[0][0]']
#
#  activation_1 (Activation)      (None, 32, 32, 32)   0           ['conv2d_1[0][0]']
#
#  activation_7 (Activation)      (None, 32, 32, 32)   0           ['conv2d_5[0][0]']
#
#  activation_13 (Activation)     (None, 32, 32, 32)   0           ['conv2d_9[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 32)  0           ['activation_1[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 32)  0           ['activation_7[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 16, 16, 32)  0           ['activation_13[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 16, 16, 32)   9248        ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 32)   9248        ['max_pooling2d_5[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 32)   9248        ['max_pooling2d_9[0][0]']
#
#  activation_2 (Activation)      (None, 16, 16, 32)   0           ['conv2d_2[0][0]']
#
#  activation_8 (Activation)      (None, 16, 16, 32)   0           ['conv2d_6[0][0]']
#
#  activation_14 (Activation)     (None, 16, 16, 32)   0           ['conv2d_10[0][0]']
#
#  dropout (Dropout)              (None, 16, 16, 32)   0           ['activation_2[0][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 32)   0           ['activation_8[0][0]']
#
#  dropout_8 (Dropout)            (None, 16, 16, 32)   0           ['activation_14[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 32)    0           ['dropout[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 8, 8, 32)    0           ['dropout_4[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 8, 8, 32)    0           ['dropout_8[0][0]']
#  )
#
#  conv2d_3 (Conv2D)              (None, 8, 8, 64)     18496       ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 8, 8, 64)     18496       ['max_pooling2d_6[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 64)     18496       ['max_pooling2d_10[0][0]']
#
#  activation_3 (Activation)      (None, 8, 8, 64)     0           ['conv2d_3[0][0]']
#
#  activation_9 (Activation)      (None, 8, 8, 64)     0           ['conv2d_7[0][0]']
#
#  activation_15 (Activation)     (None, 8, 8, 64)     0           ['conv2d_11[0][0]']
#
#  dropout_1 (Dropout)            (None, 8, 8, 64)     0           ['activation_3[0][0]']
#
#  dropout_5 (Dropout)            (None, 8, 8, 64)     0           ['activation_9[0][0]']
#
#  dropout_9 (Dropout)            (None, 8, 8, 64)     0           ['activation_15[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 64)    0           ['dropout_1[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 4, 4, 64)    0           ['dropout_5[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 4, 4, 64)    0           ['dropout_9[0][0]']
#  )
#
#  flatten (Flatten)              (None, 1024)         0           ['max_pooling2d_3[0][0]']
#
#  flatten_1 (Flatten)            (None, 1024)         0           ['max_pooling2d_7[0][0]']
#
#  flatten_2 (Flatten)            (None, 1024)         0           ['max_pooling2d_11[0][0]']
#
#  dense (Dense)                  (None, 128)          131200      ['flatten[0][0]']
#
#  dense_3 (Dense)                (None, 128)          131200      ['flatten_1[0][0]']
#
#  dense_6 (Dense)                (None, 64)           65600       ['flatten_2[0][0]']
#
#  activation_4 (Activation)      (None, 128)          0           ['dense[0][0]']
#
#  activation_10 (Activation)     (None, 128)          0           ['dense_3[0][0]']
#
#  activation_16 (Activation)     (None, 64)           0           ['dense_6[0][0]']
#
#  dropout_2 (Dropout)            (None, 128)          0           ['activation_4[0][0]']
#
#  dropout_6 (Dropout)            (None, 128)          0           ['activation_10[0][0]']
#
#  dropout_10 (Dropout)           (None, 64)           0           ['activation_16[0][0]']
#
#  dense_1 (Dense)                (None, 64)           8256        ['dropout_2[0][0]']
#
#  dense_4 (Dense)                (None, 64)           8256        ['dropout_6[0][0]']
#
#  dense_7 (Dense)                (None, 32)           2080        ['dropout_10[0][0]']
#
#  activation_5 (Activation)      (None, 64)           0           ['dense_1[0][0]']
#
#  activation_11 (Activation)     (None, 64)           0           ['dense_4[0][0]']
#
#  activation_17 (Activation)     (None, 32)           0           ['dense_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 64)           0           ['activation_5[0][0]']
#
#  dropout_7 (Dropout)            (None, 64)           0           ['activation_11[0][0]']
#
#  dropout_11 (Dropout)           (None, 32)           0           ['activation_17[0][0]']
#
#  dense_2 (Dense)                (None, 5)            325         ['dropout_3[0][0]']
#
#  dense_5 (Dense)                (None, 5)            325         ['dropout_7[0][0]']
#
#  dense_8 (Dense)                (None, 2)            66          ['dropout_11[0][0]']
#
#  age (Activation)               (None, 5)            0           ['dense_2[0][0]']
#
#  race (Activation)              (None, 5)            0           ['dense_5[0][0]']
#
#  gender (Activation)            (None, 2)            0           ['dense_8[0][0]']
#
# ==================================================================================================
# Total params: 445,804
# Trainable params: 445,804
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training the model

# %%
from keras.metrics import AUC
import math
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint
from keras.callbacks import LearningRateScheduler

# CALLBACKS

# Exponential_decay() or step_decay() functions alternatively can be used for dynamic learning rate
#----------------------------------------------------------------------------------------------------------------------------------------------
# Learning Rate Schedules in Keras reduces the learning rate by a certain factor after certain no of epochs

#Source:    (https://towardsdatascience.com/learning-rate-schedules-and-adaptive-learning-rate-methods-for-deep-learning-2c8f433990d1)
#           (https://sanjayasubedi.com.np/deeplearning/multioutput-keras/)
#           (https://github.com/sukilau/Ziff-deep-learning/blob/master/3-CIFAR10-lrate/CIFAR10-lrate.ipynb)

# According ot several sources (few example of it above), since the learning rate is the most important
# hyperparameter to tune the training in a neural network, it is stated that to reduce learning rate as the training progresses,
# is a good practice for a better outcome (accuracy).

# Exponential Decay
# def exp_decay(epoch):
#    initial_lrate = 0.001
#    k = 0.2
#    lrate = initial_lrate * np.exp(-k * epoch)  # lr, k are hyperparameters and t=epoch is the iteration number
#    return lrate

# Step Decay, to drop the learning rate by a factor every few epochs.
def step_decay(epoch):
	initial_lrate = 0.0010
	drop = 0.8             # % drop rate
	epochs_drop = 7.0      # To drop after every number of epoch
	lrate = initial_lrate * math.pow(drop, math.floor((1 + epoch) / epochs_drop)) #Fromula for step_decay
	return lrate

# Source: (https://datascience.stackexchange.com/questions/42599/what-is-the-relationship-between-the-accuracy-and-the-loss-in-deep-learning)
# a low accuracy and huge loss means you made huge errors on a lot of data
# a low accuracy but low loss means you made little errors on a lot of data
# a great accuracy with low loss means you made low errors on a few data (best case)

lrate = LearningRateScheduler(step_decay)       # At the beginning of every epoch, this callback gets the updated learning rate value
#lrate = LearningRateScheduler(exp_decay)

# `binary_crossentropy`, sigmoid activation, scalar target.
# `categorical_crossentropy`, softmax activation, one-hot encoded target.

# It is this callback that allows a function to invoke during program execution.
callbacks_list = [lrate]
#----------------------------------------------------------------------------------------------------------------------------------------

filepath = "../ModelTrainingService/models/CNN_Dec260151.hdf5"
checkpoint = ModelCheckpoint(filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True,
                             mode='max')

monitor_val_acc = [EarlyStopping(monitor = 'val_loss',
                                min_delta = 0,
                                patience = 10,
                                verbose = 1,
                                mode='max',
                                restore_best_weights = True)]

#callbacks_list = [PlotLossesKeras(), monitor_val_acc, checkpoint]

# Source: https://neptune.ai/blog/keras-metrics
init_lr = 1e-5
epochs = 150
#opt = Adam(learning_rate=0.0) # 0.0 means not to be used here.
opt = Adam(learning_rate=init_lr, decay=init_lr/epochs)
#opt = SGD(learning_rate=init_lr, momentum=0.9, decay=1e-8, nesterov=True)
model.compile(optimizer= opt,  # 'rmsprop',
              loss={
                  'age': 'categorical_crossentropy',
                  'race': 'categorical_crossentropy',
                  'gender': 'binary_crossentropy'},
              loss_weights={
                  'age': 1.5,
                  'race': 1.5,
                  'gender': 0.1},
              metrics={
                  'age': ['accuracy', AUC(curve="ROC")],
                  'race': ['accuracy', AUC(curve="ROC")],
                  'gender': ['accuracy', AUC(curve="ROC")]})

# %%
# class_weight in Keras: To ensure the unevenness in data distribution (as in age) is sorted out by giving the classes with fewer numbers is assigned more
# weight to prevent being biased against prevalent classes.
from sklearn.utils import class_weight

class_weight = class_weight.compute_class_weight('balanced',
                                                 classes=np.array([0,1,2,3,4]),
                                                 y=np.array(df['age']))

class_weight1 = {'age': class_weight}

# %%
# To generate batches for train_idx to be able to prevent "too large to fit inside RAM at once so-called memory errors".
# Soource: https://www.codementor.io/@alexander-k/keras-training-earlystopping-callback-to-avoid-overfitting-1ehrjlx8kw

import sys
import math
import keras
from datetime import datetime
import datetime
import time
import os
from django.utils.datetime_safe import datetime
from keras.callbacks import EarlyStopping
from livelossplot import PlotLossesKeras
plt.style.use('ggplot')
from sklearn.preprocessing import LabelBinarizer
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler

# To measure the time for the traiing session
start = datetime.now()

# Training and validation batches
batch_size = 32
train_gen = data_generator.generate_images(train_idx,
                                           is_training=True,
                                           batch_size=batch_size)

valid_gen = data_generator.generate_images(valid_idx,
                                           is_training=True,
                                           batch_size=batch_size)

# fit() as known fit_generator() before 2020: Validation while training the model to evaluate the loss.
history = model.fit(train_gen,
                    steps_per_epoch=len(train_idx)//batch_size,
                    epochs=epochs,
                    #callbacks=callbacks_list,
                    validation_data=valid_gen,
                    validation_steps=len(valid_idx)//batch_size,
                    verbose=1)

#Training time
end = datetime.now()
elapsed = end-start
print ('\nElapsed Time: ', elapsed)
# Out:
# Epoch 1/150
# 474/474 [==============================] - 27s 45ms/step - loss: 4.3041 - age_loss: 1.3356 - race_loss: 1.4878 - gender_loss: 0.6904 - age_accuracy: 0.4504 - age_auc: 0.7655 - race_accuracy: 0.4121 - race_auc_1: 0.6734 - gender_accuracy: 0.5326 - gender_auc_2: 0.5503 - val_loss: 4.0907 - val_age_loss: 1.2237 - val_race_loss: 1.4576 - val_gender_loss: 0.6880 - val_age_accuracy: 0.5021 - val_age_auc: 0.8189 - val_race_accuracy: 0.4248 - val_race_auc_1: 0.7135 - val_gender_accuracy: 0.5307 - val_gender_auc_2: 0.6003
# Epoch 2/150
# 474/474 [==============================] - 21s 45ms/step - loss: 4.0462 - age_loss: 1.2073 - race_loss: 1.4450 - gender_loss: 0.6790 - age_accuracy: 0.4773 - age_auc: 0.8025 - race_accuracy: 0.4242 - race_auc_1: 0.6973 - gender_accuracy: 0.5959 - gender_auc_2: 0.6261 - val_loss: 4.0563 - val_age_loss: 1.2077 - val_race_loss: 1.4516 - val_gender_loss: 0.6751 - val_age_accuracy: 0.5310 - val_age_auc: 0.8254 - val_race_accuracy: 0.4245 - val_race_auc_1: 0.7278 - val_gender_accuracy: 0.6621 - val_gender_auc_2: 0.6914
# Epoch 3/150
# 474/474 [==============================] - 22s 46ms/step - loss: 3.9938 - age_loss: 1.1842 - race_loss: 1.4344 - gender_loss: 0.6586 - age_accuracy: 0.4910 - age_auc: 0.8103 - race_accuracy: 0.4254 - race_auc_1: 0.7062 - gender_accuracy: 0.6453 - gender_auc_2: 0.6770 - val_loss: 4.0163 - val_age_loss: 1.1952 - val_race_loss: 1.4386 - val_gender_loss: 0.6551 - val_age_accuracy: 0.5466 - val_age_auc: 0.8315 - val_race_accuracy: 0.4251 - val_race_auc_1: 0.7384 - val_gender_accuracy: 0.6623 - val_gender_auc_2: 0.7079
# Epoch 4/150
# 474/474 [==============================] - 22s 46ms/step - loss: 3.9491 - age_loss: 1.1737 - race_loss: 1.4162 - gender_loss: 0.6428 - age_accuracy: 0.4953 - age_auc: 0.8144 - race_accuracy: 0.4304 - race_auc_1: 0.7182 - gender_accuracy: 0.6557 - gender_auc_2: 0.6917 - val_loss: 3.9732 - val_age_loss: 1.1856 - val_race_loss: 1.4204 - val_gender_loss: 0.6423 - val_age_accuracy: 0.5474 - val_age_auc: 0.8345 - val_race_accuracy: 0.4529 - val_race_auc_1: 0.7483 - val_gender_accuracy: 0.6642 - val_gender_auc_2: 0.7143
# Epoch 5/150
# 474/474 [==============================] - 21s 45ms/step - loss: 3
150
# 474/474 [==============================] - 21s 44ms/step - loss: 3.6582 - age_loss: 1.1113 - race_loss: 1.2870 - gender_loss: 0.6066 - age_accuracy: 0.5394 - age_auc: 0.8362 - race_accuracy: 0.5040 - race_auc_1: 0.7796 - gender_accuracy: 0.6841 - gender_auc_2: 0.7374 - val_loss: 3.7065 - val_age_loss: 1.1272 - val_race_loss: 1.3033 - val_gender_loss: 0.6081 - val_age_accuracy: 0.5723 - val_age_auc: 0.8519 - val_race_accuracy: 0.5138 - val_race_auc_1: 0.8036 - val_gender_accuracy: 0.6915 - val_gender_auc_2: 0.7570
# Epoch 11/150
# 474/474 [==============================] - 20s 43ms/step - loss: 3.6156 - age_loss: 1.0980 - race_loss: 1.2723 - gender_loss: 0.5998 - age_accuracy: 0.5450 - age_auc: 0.8405 - race_accuracy: 0.5084 - race_auc_1: 0.7855 - gender_accuracy: 0.6945 - gender_auc_2: 0.7459 - val_loss: 3.6701 - val_age_loss: 1.1166 - val_race_loss: 1.2899 - val_gender_loss: 0.6025 - val_age_accuracy: 0.5749 - val_age_auc: 0.8552 - val_race_accuracy: 0.5228 - val_race_auc_1: 0.8088 - val_gender_accuracy: 0.6997 - val_gender_auc_2: 0.7662
# Epoch 12/150
# 474/474 [==============================] - 23s 48ms/step - loss: 3.5859 - age_loss: 1.0923 - race_loss: 1.2589 - gender_loss: 0.5914 - age_accuracy: 0.5491 - age_auc: 0.8425 - race_accuracy: 0.5143 - race_auc_1: 0.7908 - gender_accuracy: 0.7015 - gender_auc_2: 0.7564 - val_loss: 3.6379 - val_age_loss: 1.1096 - val_race_loss: 1.2760 - val_gender_loss: 0.5954 - val_age_accuracy: 0.5784 - val_age_auc: 0.8581 - val_race_accuracy: 0.5260 - val_race_auc_1: 0.8114 - val_gender_accuracy: 0.7060 - val_gender_auc_2: 0.7731
# Epoch 13/150
# 474/474 [==============================] - 22s 47ms/step - loss: 3.5522 - age_loss: 1.0829 - race_loss: 1.2464 - gender_loss: 0.5821 - age_accuracy: 0.5569 - age_auc: 0.8454 - race_accuracy: 0.5165 - race_auc_1: 0.7958 - gender_accuracy: 0.7079 - gender_auc_2: 0.7673 - val_loss: 3.6007 - val_age_loss: 1.0984 - val_race_loss: 1.2630 - val_gender_loss: 0.5852 - val_age_accuracy: 0.5855 - val_age_auc: 0.8616 - val_race_accuracy: 0.5352 - val_race_auc_1: 0.8157 - val_gender_accuracy: 0.7188 - val_gender_auc_2: 0.7878
# Epoch 14/150
# 474/474 [==============================] - 21s 45ms/step - loss: 3.5181 - age_loss: 1.0692 - race_loss: 1.2379 - gender_loss: 0.5750 - age_accuracy: 0.5580 - age_auc: 0.8498 - race_accuracy: 0.5223 - race_auc_1: 0.7987 - gender_accuracy: 0.7153 - gender_auc_2: 0.7745 - val_loss: 3.5613 - val_age_loss: 1.0875 - val_race_loss: 1.2482 - val_gender_loss: 0.5770 - val_age_accuracy: 0.5874 - val_age_auc: 0.8639 - val_race_accuracy: 0.5440 - val_race_auc_1: 0.8206 - val_gender_accuracy: 0.7230 - val_gender_auc_2: 0.7966
# Epoch 15/150
# 474/474 [==============================] - 21s 44ms/step - loss: 3.4925 - age_loss: 1.0609 - race_loss: 1.2296 - gender_loss: 0.5668 - age_accuracy: 0.5628 - age_auc: 0.8522 - race_accuracy: 0.5265 - race_auc_1: 0.8016 - gender_accuracy: 0.7224 - gender_auc_2: 0.7835 - val_loss: 3.5338 - val_age_loss: 1.0794 - val_race_loss: 1.2386 - val_gender_loss: 0.5682 - val_age_accuracy: 0.5866 - val_age_auc: 0.8658 - val_race_accuracy: 0.5490 - val_race_auc_1: 0.8248 - val_gender_accuracy: 0.7301 - val_gender_auc_2: 0.8073
# Epoch 16/150
# 474/474 [==============================] - 21s 44ms/step - loss: 3.4701 - age_loss: 1.0555 - race_loss: 1.2207 - gender_loss: 0.5582 - age_accuracy: 0.5682 - age_auc: 0.8541 - race_accuracy: 0.5285 - race_auc_1: 0.8046 - gender_accuracy: 0.7282 - gender_auc_2: 0.7916 - val_loss: 3.5178 - val_age_loss: 1.0742 - val_race_loss: 1.2336 - val_gender_loss: 0.5599 - val_age_accuracy: 0.5887 - val_age_auc: 0.8686 - val_race_accuracy: 0.5461 - val_race_auc_1: 0.8253 - val_gender_accuracy: 0.7418 - val_gender_auc_2: 0.8173
# Epoch 17/150
# 474/474 [==============================] - 20s 43ms/step - loss: 3.4306 - age_loss: 1.0426 - race_loss: 1.2076 - gender_loss: 0.5518 - age_accuracy: 0.5694 - age_auc: 0.8579 - race_accuracy: 0.5318 - race_auc_1: 0.8097 - gender_accuracy: 0.7348 - gender_auc_2: 0.7980 - val_loss: 3.4817 - val_age_loss: 1.0666 - val_race_loss: 1.2177 - val_gender_loss: 0.5518 - val_age_accuracy: 0.5908 - val_age_auc: 0.8708 - val_race_accuracy: 0.5577 - val_race_auc_1: 0.8302 - val_gender_accuracy: 0.7468 - val_gender_auc_2: 0.8268
# Epoch 18/150
# 474/474 [==============================] - 21s 43ms/step - loss: 3.4035 - age_loss: 1.0340 - race_loss: 1.1989 - gender_loss: 0.5413 - age_accuracy: 0.5737 - age_auc: 0.8604 - race_accuracy: 0.5390 - race_auc_1: 0.8126 - gender_accuracy: 0.7416 - gender_auc_2: 0.8076 - val_loss: 3.4527 - val_age_loss: 1.0572 - val_race_loss: 1.2085 - val_gender_loss: 0.5420 - val_age_accuracy: 0.5948 - val_age_auc: 0.8731 - val_race_accuracy: 0.5633 - val_race_auc_1: 0.8325 - val_gender_accuracy: 0.7558 - val_gender_auc_2: 0.8347
# Epoch 19/150
# 474/474 [==============================] - 21s 44ms/step - loss: 3.3818 - age_loss: 1.0277 - race_loss: 1.1915 - gender_loss: 0.5308 - age_accuracy: 0.5761 - age_auc: 0.8620 - race_accuracy: 0.5388 - race_auc_1: 0.8150 - gender_accuracy: 0.7463 - gender_auc_2: 0.8160 - val_loss: 3.4305 - val_age_loss: 1.0487 - val_race_loss: 1.2027 - val_gender_loss: 0.5337 - val_age_accuracy: 0.5980 - val_age_auc: 0.8754 - val_race_accuracy: 0.5699 - val_race_auc_1: 0.8355 - val_gender_accuracy: 0.7648 - val_gender_auc_2: 0.8424
# Epoch 20/150
# 474/474 [==============================] - 21s 44ms/step - loss: 3.3630 - age_loss: 1.0215 - race_loss: 1.1857 - gender_loss: 0.5232 - age_accuracy: 0.5759 - age_auc: 0.8636 - race_accuracy: 0.5438 - race_auc_1: 0.8169 - gender_accuracy: 0.7533 - gender_auc_2: 0.8222 - val_loss: 3.4126 - val_age_loss: 1.0438 - val_race_loss: 1.1964 - val_gender_loss: 0.5227 - val_age_accuracy: 0.6020 - val_age_auc: 0.8772 - val_race_accuracy: 0.5707 - val_race_auc_1: 0.8373 - val_gender_accuracy: 0.7736 - val_gender_auc_2: 0.8495
# Epoch 21/150
# 474/474 [==============================] - 21s 43ms/step - loss: 3.3205 - age_loss: 1.0076 - race_loss: 1.1719 - gender_loss: 0.5126 - age_accuracy: 0.5809 - age_auc: 0.8677 - race_accuracy: 0.5497 - race_auc_1: 0.8218 - gender_accuracy: 0.7609 - gender_auc_2: 0.8307 - val_loss: 3.3808 - val_age_loss: 1.0345 - val_race_loss: 1.1851 - val_gender_loss: 0.5137 - val_age_accuracy: 0.6020 - val_age_auc: 0.8789 - val_race_accuracy: 0.5739 - val_race_auc_1: 0.8399 - val_gender_accuracy: 0.7773 - val_gender_auc_2: 0.8547
# Epoch 22/150
# 474/474 [==============================] - 20s 43ms/step - loss: 3.3071 - age_loss: 1.0047 - race_loss: 1.1663 - gender_loss: 0.5067 - age_accuracy: 0.5838 - age_auc: 0.8685 - race_accuracy: 0.5524 - race_auc_1: 0.8234 - gender_accuracy: 0.7636 - gender_auc_2: 0.8348 - val_loss: 3.3509 - val_age_loss: 1.0272 - val_race_loss: 1.1729 - val_gender_loss: 0.5075 - val_age_accuracy: 0.6038 - val_age_auc: 0.8804 - val_race_accuracy: 0.5808 - val_race_auc_1: 0.8425 - val_gender_accuracy: 0.7834 - val_gender_auc_2: 0.8618
# Epoch 23/150
# 474/474 [==============================] - 20s 43ms/step - loss: 3.2843 - age_loss: 0.9952 - race_loss: 1.1608 - gender_loss: 0.5035 - age_accuracy: 0.5820 - age_auc: 0.8709 - race_accuracy: 0.5534 - race_auc_1: 0.8255 - gender_accuracy: 0.7678 - gender_auc_2: 0.8372 - val_loss: 3.3327 - val_age_loss: 1.0209 - val_race_loss: 1.1674 - val_gender_loss: 0.5019 - val_age_accuracy: 0.6073 - val_age_auc: 0.8824 - val_race_accuracy: 0.5834 - val_race_auc_1: 0.8455 - val_gender_accuracy: 0.7865 - val_gender_auc_2: 0.8647
# Epoch 24/150
# 474/474 [==============================] - 21s 43ms/step - loss: 3.2584 - age_loss: 0.9864 - race_loss: 1.1528 - gender_loss: 0.4949 - age_accuracy: 0.5855 - age_auc: 0.8733 - race_accuracy: 0.5594 - race_auc_1: 0.8277 - gender_accuracy: 0.7723 - gender_auc_2: 0.8441 - val_loss: 3.3032 - val_age_loss: 1.0105 - val_race_loss: 1.1587 - val_gender_loss: 0.4939 - val_age_accuracy: 0.6112 - val_age_auc: 0.8837 - val_race_accuracy: 0.5845 - val_race_auc_1: 0.8472 - val_gender_accuracy: 0.7868 - val_gender_auc_2: 0.8695
# Epoch 25/150
# 474/474 [==============================] - 21s 45ms/step - loss: 3.2275 - age_loss: 0.9779 - race_loss: 1.1411 - gender_loss: 0.4898 - age_accuracy: 0.5930 - age_auc: 0.8755 - race_accuracy: 0.5635 - race_auc_1: 0.8315 - gender_accuracy: 0.7716 - gender_auc_2: 0.8474 - val_loss: 3.2840 - val_age_loss: 1.0058 - val_race_loss: 1.1510 - val_gender_loss: 0.4882 - val_age_accuracy: 0.6118 - val_age_auc: 0.8860 - val_race_accuracy: 0.5877 - val_race_auc_1: 0.8486 - val_gender_accuracy: 0.7908 - val_gender_auc_2: 0.8727
# Epoch 26/150
# 474/474 [==============================] - 21s 44ms/step - loss: 3
150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.8796 - age_loss: 0.8633 - race_loss: 1.0294 - gender_loss: 0.4058 - age_accuracy: 0.6414 - age_auc: 0.9024 - race_accuracy: 0.6156 - race_auc_1: 0.8648 - gender_accuracy: 0.8233 - gender_auc_2: 0.8984 - val_loss: 2.9056 - val_age_loss: 0.8788 - val_race_loss: 1.0315 - val_gender_loss: 0.4014 - val_age_accuracy: 0.6547 - val_age_auc: 0.9104 - val_race_accuracy: 0.6449 - val_race_auc_1: 0.8815 - val_gender_accuracy: 0.8369 - val_gender_auc_2: 0.9170
# Epoch 47/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.8734 - age_loss: 0.8592 - race_loss: 1.0295 - gender_loss: 0.4033 - age_accuracy: 0.6396 - age_auc: 0.9034 - race_accuracy: 0.6177 - race_auc_1: 0.8649 - gender_accuracy: 0.8245 - gender_auc_2: 0.8997 - val_loss: 2.8840 - val_age_loss: 0.8750 - val_race_loss: 1.0211 - val_gender_loss: 0.3977 - val_age_accuracy: 0.6562 - val_age_auc: 0.9111 - val_race_accuracy: 0.6462 - val_race_auc_1: 0.8831 - val_gender_accuracy: 0.8385 - val_gender_auc_2: 0.9183
# Epoch 48/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.8472 - age_loss: 0.8501 - race_loss: 1.0214 - gender_loss: 0.3983 - age_accuracy: 0.6459 - age_auc: 0.9054 - race_accuracy: 0.6214 - race_auc_1: 0.8668 - gender_accuracy: 0.8256 - gender_auc_2: 0.9021 - val_loss: 2.8749 - val_age_loss: 0.8727 - val_race_loss: 1.0174 - val_gender_loss: 0.3971 - val_age_accuracy: 0.6568 - val_age_auc: 0.9120 - val_race_accuracy: 0.6478 - val_race_auc_1: 0.8839 - val_gender_accuracy: 0.8387 - val_gender_auc_2: 0.9195
# Epoch 49/150
# 474/474 [==============================] - 21s 45ms/step - loss: 2.8405 - age_loss: 0.8532 - race_loss: 1.0140 - gender_loss: 0.3974 - age_accuracy: 0.6437 - age_auc: 0.9045 - race_accuracy: 0.6236 - race_auc_1: 0.8690 - gender_accuracy: 0.8246 - gender_auc_2: 0.9027 - val_loss: 2.8646 - val_age_loss: 0.8685 - val_race_loss: 1.0151 - val_gender_loss: 0.3928 - val_age_accuracy: 0.6581 - val_age_auc: 0.9121 - val_race_accuracy: 0.6515 - val_race_auc_1: 0.8858 - val_gender_accuracy: 0.8382 - val_gender_auc_2: 0.9201
# Epoch 50/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.8340 - age_loss: 0.8477 - race_loss: 1.0152 - gender_loss: 0.3973 - age_accuracy: 0.6541 - age_auc: 0.9061 - race_accuracy: 0.6227 - race_auc_1: 0.8687 - gender_accuracy: 0.8281 - gender_auc_2: 0.9029 - val_loss: 2.8564 - val_age_loss: 0.8699 - val_race_loss: 1.0083 - val_gender_loss: 0.3908 - val_age_accuracy: 0.6581 - val_age_auc: 0.9126 - val_race_accuracy: 0.6523 - val_race_auc_1: 0.8872 - val_gender_accuracy: 0.8422 - val_gender_auc_2: 0.9216
# Epoch 51/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.
150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.6480 - age_loss: 0.8042 - race_loss: 0.9374 - gender_loss: 0.3566 - age_accuracy: 0.6642 - age_auc: 0.9145 - race_accuracy: 0.6623 - race_auc_1: 0.8886 - gender_accuracy: 0.8463 - gender_auc_2: 0.9225 - val_loss: 2.6748 - val_age_loss: 0.8204 - val_race_loss: 0.9393 - val_gender_loss: 0.3539 - val_age_accuracy: 0.6716 - val_age_auc: 0.9205 - val_race_accuracy: 0.6806 - val_race_auc_1: 0.9021 - val_gender_accuracy: 0.8533 - val_gender_auc_2: 0.9333
# Epoch 68/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.6425 - age_loss: 0.8013 - race_loss: 0.9366 - gender_loss: 0.3574 - age_accuracy: 0.6646 - age_auc: 0.9152 - race_accuracy: 0.6615 - race_auc_1: 0.8887 - gender_accuracy: 0.8483 - gender_auc_2: 0.9223 - val_loss: 2.6669 - val_age_loss: 0.8207 - val_race_loss: 0.9338 - val_gender_loss: 0.3517 - val_age_accuracy: 0.6732 - val_age_auc: 0.9199 - val_race_accuracy: 0.6825 - val_race_auc_1: 0.9033 - val_gender_accuracy: 0.8530 - val_gender_auc_2: 0.9339
# Epoch 69/150
# 474/474 [==============================] - 21s 43ms/step - loss: 2.6368 - age_loss: 0.8010 - race_loss: 0.9332 - gender_loss: 0.3551 - age_accuracy: 0.6605 - age_auc: 0.9151 - race_accuracy: 0.6631 - race_auc_1: 0.8894 - gender_accuracy: 0.8504 - gender_auc_2: 0.9231 - val_loss: 2.6548 - val_age_loss: 0.8211 - val_race_loss: 0.9254 - val_gender_loss: 0.3515 - val_age_accuracy: 0.6700 - val_age_auc: 0.9210 - val_race_accuracy: 0.6846 - val_race_auc_1: 0.9043 - val_gender_accuracy: 0.8535 - val_gender_auc_2: 0.9344
# Epoch 70/150
# 474/474 [==============================] - 21s 43ms/step - loss: 2.6252 - age_loss: 0.7960 - race_loss: 0.9306 - gender_loss: 0.3534 - age_accuracy: 0.6692 - age_auc: 0.9162 - race_accuracy: 0.6597 - race_auc_1: 0.8903 - gender_accuracy: 0.8476 - gender_auc_2: 0.9238 - val_loss: 2.6397 - val_age_loss: 0.8128 - val_race_loss: 0.9238 - val_gender_loss: 0.3480 - val_age_accuracy: 0.6713 - val_age_auc: 0.9212 - val_race_accuracy: 0.6875 - val_race_auc_1: 0.9050 - val_gender_accuracy: 0.8538 - val_gender_auc_2: 0.9348
# Epoch 71/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.6150 - age_loss: 0.7954 - race_loss: 0.9246 - gender_loss: 0.3506 - age_accuracy: 0.6659 - age_auc: 0.9164 - race_accuracy: 0.6620 - race_auc_1: 0.8917 - gender_accuracy: 0.8484 - gender_auc_2: 0.9249 - val_loss: 2.6397 - val_age_loss: 0.8109 - val_race_loss: 0.9258 - val_gender_loss: 0.3475 - val_age_accuracy: 0.6740 - val_age_auc: 0.9217 - val_race_accuracy: 0.6883 - val_race_auc_1: 0.9045 - val_gender_accuracy: 0.8543 - val_gender_auc_2: 0.9356
# Epoch 72/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.
150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.5643 - age_loss: 0.7827 - race_loss: 0.9042 - gender_loss: 0.3388 - age_accuracy: 0.6709 - age_auc: 0.9189 - race_accuracy: 0.6713 - race_auc_1: 0.8964 - gender_accuracy: 0.8525 - gender_auc_2: 0.9301 - val_loss: 2.5822 - val_age_loss: 0.7965 - val_race_loss: 0.9028 - val_gender_loss: 0.3335 - val_age_accuracy: 0.6780 - val_age_auc: 0.9239 - val_race_accuracy: 0.6984 - val_race_auc_1: 0.9097 - val_gender_accuracy: 0.8581 - val_gender_auc_2: 0.9395
# Epoch 79/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.5472 - age_loss: 0.7775 - race_loss: 0.8982 - gender_loss: 0.3378 - age_accuracy: 0.6739 - age_auc: 0.9202 - race_accuracy: 0.6774 - race_auc_1: 0.8978 - gender_accuracy: 0.8554 - gender_auc_2: 0.9307 - val_loss: 2.5816 - val_age_loss: 0.7951 - val_race_loss: 0.9037 - val_gender_loss: 0.3343 - val_age_accuracy: 0.6774 - val_age_auc: 0.9235 - val_race_accuracy: 0.6976 - val_race_auc_1: 0.9094 - val_gender_accuracy: 0.8570 - val_gender_auc_2: 0.9391
# Epoch 80/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.5393 - age_loss: 0.7779 - race_loss: 0.8925 - gender_loss: 0.3373 - age_accuracy: 0.6741 - age_auc: 0.9198 - race_accuracy: 0.6784 - race_auc_1: 0.8990 - gender_accuracy: 0.8560 - gender_auc_2: 0.9307 - val_loss: 2.5754 - val_age_loss: 0.7976 - val_race_loss: 0.8970 - val_gender_loss: 0.3348 - val_age_accuracy: 0.6753 - val_age_auc: 0.9233 - val_race_accuracy: 0.6978 - val_race_auc_1: 0.9107 - val_gender_accuracy: 0.8588 - val_gender_auc_2: 0.9390
# Epoch 81/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.5377 - age_loss: 0.7782 - race_loss: 0.8912 - gender_loss: 0.3351 - age_accuracy: 0.6746 - age_auc: 0.9196 - race_accuracy: 0.6791 - race_auc_1: 0.8994 - gender_accuracy: 0.8566 - gender_auc_2: 0.9316 - val_loss: 2.5691 - val_age_loss: 0.7964 - val_race_loss: 0.8942 - val_gender_loss: 0.3323 - val_age_accuracy: 0.6774 - val_age_auc: 0.9235 - val_race_accuracy: 0.6999 - val_race_auc_1: 0.9112 - val_gender_accuracy: 0.8586 - val_gender_auc_2: 0.9396
# Epoch 82/150
# 474/474 [==============================] - 22s 46ms/step - loss: 2.5182 - age_loss: 0.7701 - race_loss: 0.8864 - gender_loss: 0.3349 - age_accuracy: 0.6792 - age_auc: 0.9215 - race_accuracy: 0.6814 - race_auc_1: 0.9004 - gender_accuracy: 0.8569 - gender_auc_2: 0.9315 - val_loss: 2.5522 - val_age_loss: 0.7892 - val_race_loss: 0.8902 - val_gender_loss: 0.3310 - val_age_accuracy: 0.6785 - val_age_auc: 0.9247 - val_race_accuracy: 0.7002 - val_race_auc_1: 0.9115 - val_gender_accuracy: 0.8591 - val_gender_auc_2: 0.9409
# Epoch 83/150
# 474/474 [==============================] - 21s 45ms/step - loss: 2.5190 - age_loss: 0.7719 - race_loss: 0.8851 - gender_loss: 0.3355 - age_accuracy: 0.6761 - age_auc: 0.9209 - race_accuracy: 0.6798 - race_auc_1: 0.9008 - gender_accuracy: 0.8559 - gender_auc_2: 0.9316 - val_loss: 2.5601 - val_age_loss: 0.7910 - val_race_loss: 0.8937 - val_gender_loss: 0.3302 - val_age_accuracy: 0.6806 - val_age_auc: 0.9248 - val_race_accuracy: 0.7026 - val_race_auc_1: 0.9115 - val_gender_accuracy: 0.8610 - val_gender_auc_2: 0.9406
# Epoch 84/150
# 474/474 [==============================] - 23s 49ms/step - loss: 2.5189 - age_loss: 0.7738 - race_loss: 0.8832 - gender_loss: 0.3333 - age_accuracy: 0.6758 - age_auc: 0.9205 - race_accuracy: 0.6849 - race_auc_1: 0.9010 - gender_accuracy: 0.8574 - gender_auc_2: 0.9325 - val_loss: 2.5498 - val_age_loss: 0.7888 - val_race_loss: 0.8892 - val_gender_loss: 0.3290 - val_age_accuracy: 0.6803 - val_age_auc: 0.9244 - val_race_accuracy: 0.7063 - val_race_auc_1: 0.9126 - val_gender_accuracy: 0.8610 - val_gender_auc_2: 0.9408
# Epoch 85/150
# 474/474 [==============================] - 20s 43ms/step - loss: 2.5174 - age_loss: 0.7710 - race_loss: 0.8852 - gender_loss: 0.3314 - age_accuracy: 0.6781 - age_auc: 0.9211 - race_accuracy: 0.6792 - race_auc_1: 0.9006 - gender_accuracy: 0.8610 - gender_auc_2: 0.9334 - val_loss: 2.5483 - val_age_loss: 0.7908 - val_race_loss: 0.8863 - val_gender_loss: 0.3264 - val_age_accuracy: 0.6780 - val_age_auc: 0.9251 - val_race_accuracy: 0.7074 - val_race_auc_1: 0.9134 - val_gender_accuracy: 0.8628 - val_gender_auc_2: 0.9413
# Epoch 86/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.4981 - age_loss: 0.7672 - race_loss: 0.8761 - gender_loss: 0.3318 - age_accuracy: 0.6808 - age_auc: 0.9218 - race_accuracy: 0.6853 - race_auc_1: 0.9029 - gender_accuracy: 0.8588 - gender_auc_2: 0.9330 - val_loss: 2.5349 - val_age_loss: 0.7866 - val_race_loss: 0.8815 - val_gender_loss: 0.3265 - val_age_accuracy: 0.6811 - val_age_auc: 0.9249 - val_race_accuracy: 0.7071 - val_race_auc_1: 0.9136 - val_gender_accuracy: 0.8626 - val_gender_auc_2: 0.9414
# Epoch 87/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.4920 - age_loss: 0.7664 - race_loss: 0.8731 - gender_loss: 0.3276 - age_accuracy: 0.6769 - age_auc: 0.9220 - race_accuracy: 0.6859 - race_auc_1: 0.9035 - gender_accuracy: 0.8584 - gender_auc_2: 0.9346 - val_loss: 2.5241 - val_age_loss: 0.7826 - val_race_loss: 0.8785 - val_gender_loss: 0.3245 - val_age_accuracy: 0.6841 - val_age_auc: 0.9256 - val_race_accuracy: 0.7076 - val_race_auc_1: 0.9143 - val_gender_accuracy: 0.8620 - val_gender_auc_2: 0.9424
# Epoch 88/150
# 474/474 [==============================] - 21s 45ms/step - loss: 2.4876 - age_loss: 0.7646 - race_loss: 0.8717 - gender_loss: 0.3312 - age_accuracy: 0.6803 - age_auc: 0.9224 - race_accuracy: 0.6888 - race_auc_1: 0.9038 - gender_accuracy: 0.8597 - gender_auc_2: 0.9333 - val_loss: 2.5209 - val_age_loss: 0.7847 - val_race_loss: 0.8742 - val_gender_loss: 0.3252 - val_age_accuracy: 0.6843 - val_age_auc: 0.9257 - val_race_accuracy: 0.7132 - val_race_auc_1: 0.9159 - val_gender_accuracy: 0.8644 - val_gender_auc_2: 0.9426
# Epoch 89/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.4780 - age_loss: 0.7633 - race_loss: 0.8669 - gender_loss: 0.3263 - age_accuracy: 0.6791 - age_auc: 0.9226 - race_accuracy: 0.6899 - race_auc_1: 0.9047 - gender_accuracy: 0.8612 - gender_auc_2: 0.9352 - val_loss: 2.5102 - val_age_loss: 0.7846 - val_race_loss: 0.8674 - val_gender_loss: 0.3222 - val_age_accuracy: 0.6854 - val_age_auc: 0.9255 - val_race_accuracy: 0.7071 - val_race_auc_1: 0.9162 - val_gender_accuracy: 0.8647 - val_gender_auc_2: 0.9429
# Epoch 90/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.4786 - age_loss: 0.7618 - race_loss: 0.8688 - gender_loss: 0.3266 - age_accuracy: 0.6780 - age_auc: 0.9229 - race_accuracy: 0.6875 - race_auc_1: 0.9042 - gender_accuracy: 0.8605 - gender_auc_2: 0.9352 - val_loss: 2.5083 - val_age_loss: 0.7823 - val_race_loss: 0.8685 - val_gender_loss: 0.3217 - val_age_accuracy: 0.6838 - val_age_auc: 0.9260 - val_race_accuracy: 0.7097 - val_race_auc_1: 0.9163 - val_gender_accuracy: 0.8663 - val_gender_auc_2: 0.9433
# Epoch 91/150
# ...
# Epoch 122/150
# 474/474 [==============================] - 21s 45ms/step - loss: 2.3103 - age_loss: 0.7226 - race_loss: 0.7981 - gender_loss: 0.2923 - age_accuracy: 0.6916 - age_auc: 0.9299 - race_accuracy: 0.7220 - race_auc_1: 0.9190 - gender_accuracy: 0.8776 - gender_auc_2: 0.9482 - val_loss: 2.3719 - val_age_loss: 0.7476 - val_race_loss: 0.8141 - val_gender_loss: 0.2928 - val_age_accuracy: 0.6997 - val_age_auc: 0.9315 - val_race_accuracy: 0.7285 - val_race_auc_1: 0.9261 - val_gender_accuracy: 0.8755 - val_gender_auc_2: 0.9517
# Epoch 123/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.3055 - age_loss: 0.7206 - race_loss: 0.7968 - gender_loss: 0.2934 - age_accuracy: 0.6975 - age_auc: 0.9305 - race_accuracy: 0.7182 - race_auc_1: 0.9196 - gender_accuracy: 0.8771 - gender_auc_2: 0.9479 - val_loss: 2.3674 - val_age_loss: 0.7476 - val_race_loss: 0.8111 - val_gender_loss: 0.2938 - val_age_accuracy: 0.6960 - val_age_auc: 0.9305 - val_race_accuracy: 0.7278 - val_race_auc_1: 0.9259 - val_gender_accuracy: 0.8753 - val_gender_auc_2: 0.9513
# Epoch 124/150
# 474/474 [==============================] - 21s 45ms/step - loss: 2.3070 - age_loss: 0.7217 - race_loss: 0.7966 - gender_loss: 0.2956 - age_accuracy: 0.6967 - age_auc: 0.9304 - race_accuracy: 0.7180 - race_auc_1: 0.9195 - gender_accuracy: 0.8770 - gender_auc_2: 0.9471 - val_loss: 2.3604 - val_age_loss: 0.7418 - val_race_loss: 0.8123 - val_gender_loss: 0.2933 - val_age_accuracy: 0.6986 - val_age_auc: 0.9317 - val_race_accuracy: 0.7283 - val_race_auc_1: 0.9265 - val_gender_accuracy: 0.8747 - val_gender_auc_2: 0.9515
# Epoch 125/150
# 474/474 [==============================] - 21s 45ms/step - loss: 2.2948 - age_loss: 0.7172 - race_loss: 0.7931 - gender_loss: 0.2938 - age_accuracy: 0.6965 - age_auc: 0.9309 - race_accuracy: 0.7210 - race_auc_1: 0.9200 - gender_accuracy: 0.8766 - gender_auc_2: 0.9477 - val_loss: 2.3638 - val_age_loss: 0.7434 - val_race_loss: 0.8130 - val_gender_loss: 0.2928 - val_age_accuracy: 0.6976 - val_age_auc: 0.9319 - val_race_accuracy: 0.7301 - val_race_auc_1: 0.9268 - val_gender_accuracy: 0.8739 - val_gender_auc_2: 0.9516
# Epoch 126/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.2981 - age_loss: 0.7168 - race_loss: 0.7959 - gender_loss: 0.2906 - age_accuracy: 0.6979 - age_auc: 0.9310 - race_accuracy: 0.7212 - race_auc_1: 0.9196 - gender_accuracy: 0.8768 - gender_auc_2: 0.9488 - val_loss: 2.3577 - val_age_loss: 0.7431 - val_race_loss: 0.8092 - val_gender_loss: 0.2921 - val_age_accuracy: 0.6962 - val_age_auc: 0.9312 - val_race_accuracy: 0.7304 - val_race_auc_1: 0.9271 - val_gender_accuracy: 0.8747 - val_gender_auc_2: 0.9519
# Epoch 127/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.2918 - age_loss: 0.7139 - race_loss: 0.7946 - gender_loss: 0.2910 - age_accuracy: 0.6961 - age_auc: 0.9314 - race_accuracy: 0.7165 - race_auc_1: 0.9200 - gender_accuracy: 0.8801 - gender_auc_2: 0.9488 - val_loss: 2.3571 - val_age_loss: 0.7437 - val_race_loss: 0.8083 - val_gender_loss: 0.2917 - val_age_accuracy: 0.6981 - val_age_auc: 0.9316 - val_race_accuracy: 0.7299 - val_race_auc_1: 0.9269 - val_gender_accuracy: 0.8758 - val_gender_auc_2: 0.9520
# Epoch 128/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.2823 - age_loss: 0.7136 - race_loss: 0.7888 - gender_loss: 0.2877 - age_accuracy: 0.6982 - age_auc: 0.9317 - race_accuracy: 0.7222 - race_auc_1: 0.9211 - gender_accuracy: 0.8766 - gender_auc_2: 0.9499 - val_loss: 2.3656 - val_age_loss: 0.7445 - val_race_loss: 0.8132 - val_gender_loss: 0.2901 - val_age_accuracy: 0.6981 - val_age_auc: 0.9312 - val_race_accuracy: 0.7254 - val_race_auc_1: 0.9256 - val_gender_accuracy: 0.8761 - val_gender_auc_2: 0.9523
# Epoch 129/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.2841 - age_loss: 0.7165 - race_loss: 0.7868 - gender_loss: 0.2923 - age_accuracy: 0.6981 - age_auc: 0.9311 - race_accuracy: 0.7247 - race_auc_1: 0.9215 - gender_accuracy: 0.8757 - gender_auc_2: 0.9483 - val_loss: 2.3442 - val_age_loss: 0.7400 - val_race_loss: 0.8034 - val_gender_loss: 0.2907 - val_age_accuracy: 0.7005 - val_age_auc: 0.9314 - val_race_accuracy: 0.7317 - val_race_auc_1: 0.9281 - val_gender_accuracy: 0.8761 - val_gender_auc_2: 0.9525
# Epoch 130/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.2825 - age_loss: 0.7114 - race_loss: 0.7910 - gender_loss: 0.2894 - age_accuracy: 0.7025 - age_auc: 0.9321 - race_accuracy: 0.7207 - race_auc_1: 0.9208 - gender_accuracy: 0.8791 - gender_auc_2: 0.9494 - val_loss: 2.3543 - val_age_loss: 0.7408 - val_race_loss: 0.8092 - val_gender_loss: 0.2924 - val_age_accuracy: 0.6957 - val_age_auc: 0.9314 - val_race_accuracy: 0.7299 - val_race_auc_1: 0.9274 - val_gender_accuracy: 0.8758 - val_gender_auc_2: 0.9512
# Epoch 131/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.2835 - age_loss: 0.7142 - race_loss: 0.7889 - gender_loss: 0.2891 - age_accuracy: 0.6967 - age_auc: 0.9316 - race_accuracy: 0.7197 - race_auc_1: 0.9212 - gender_accuracy: 0.8784 - gender_auc_2: 0.9495 - val_loss: 2.3391 - val_age_loss: 0.7364 - val_race_loss: 0.8036 - val_gender_loss: 0.2902 - val_age_accuracy: 0.6984 - val_age_auc: 0.9323 - val_race_accuracy: 0.7312 - val_race_auc_1: 0.9287 - val_gender_accuracy: 0.8771 - val_gender_auc_2: 0.9526
# Epoch 132/150
# 474/474 [==============================] - 21s 45ms/step - loss: 2.2620 - age_loss: 0.7100 - race_loss: 0.7789 - gender_loss: 0.2872 - age_accuracy: 0.7002 - age_auc: 0.9324 - race_accuracy: 0.7273 - race_auc_1: 0.9231 - gender_accuracy: 0.8792 - gender_auc_2: 0.9502 - val_loss: 2.3326 - val_age_loss: 0.7360 - val_race_loss: 0.7999 - val_gender_loss: 0.2881 - val_age_accuracy: 0.6986 - val_age_auc: 0.9325 - val_race_accuracy: 0.7333 - val_race_auc_1: 0.9293 - val_gender_accuracy: 0.8774 - val_gender_auc_2: 0.9528
# Epoch 133/150
# 474/474 [==============================] - 21s 45ms/step - loss: 2.2643 - age_loss: 0.7108 - race_loss: 0.7796 - gender_loss: 0.2870 - age_accuracy: 0.7017 - age_auc: 0.9322 - race_accuracy: 0.7232 - race_auc_1: 0.9231 - gender_accuracy: 0.8805 - gender_auc_2: 0.9503 - val_loss: 2.3282 - val_age_loss: 0.7406 - val_race_loss: 0.7924 - val_gender_loss: 0.2883 - val_age_accuracy: 0.6970 - val_age_auc: 0.9309 - val_race_accuracy: 0.7312 - val_race_auc_1: 0.9293 - val_gender_accuracy: 0.8761 - val_gender_auc_2: 0.9529
# Epoch 134/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.2704 - age_loss: 0.7110 - race_loss: 0.7833 - gender_loss: 0.2890 - age_accuracy: 0.6989 - age_auc: 0.9321 - race_accuracy: 0.7244 - race_auc_1: 0.9220 - gender_accuracy: 0.8810 - gender_auc_2: 0.9496 - val_loss: 2.3326 - val_age_loss: 0.7366 - val_race_loss: 0.7993 - val_gender_loss: 0.2882 - val_age_accuracy: 0.6997 - val_age_auc: 0.9319 - val_race_accuracy: 0.7325 - val_race_auc_1: 0.9291 - val_gender_accuracy: 0.8779 - val_gender_auc_2: 0.9528
# Epoch 135/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.2602 - age_loss: 0.7117 - race_loss: 0.7759 - gender_loss: 0.2883 - age_accuracy: 0.7004 - age_auc: 0.9319 - race_accuracy: 0.7278 - race_auc_1: 0.9236 - gender_accuracy: 0.8802 - gender_auc_2: 0.9497 - val_loss: 2.3268 - val_age_loss: 0.7326 - val_race_loss: 0.7994 - val_gender_loss: 0.2881 - val_age_accuracy: 0.6997 - val_age_auc: 0.9327 - val_race_accuracy: 0.7315 - val_race_auc_1: 0.9282 - val_gender_accuracy: 0.8774 - val_gender_auc_2: 0.9526
# Epoch 136/150
# 474/474 [==============================] - 21s 45ms/step - loss: 2.2517 - age_loss: 0.7057 - race_loss: 0.7762 - gender_loss: 0.2889 - age_accuracy: 0.6989 - age_auc: 0.9330 - race_accuracy: 0.7286 - race_auc_1: 0.9236 - gender_accuracy: 0.8807 - gender_auc_2: 0.9495 - val_loss: 2.3234 - val_age_loss: 0.7327 - val_race_loss: 0.7970 - val_gender_loss: 0.2875 - val_age_accuracy: 0.7015 - val_age_auc: 0.9326 - val_race_accuracy: 0.7336 - val_race_auc_1: 0.9289 - val_gender_accuracy: 0.8774 - val_gender_auc_2: 0.9536
# Epoch 137/150
# 474/474 [==============================] - 22s 46ms/step - loss: 2.2526 - age_loss: 0.7046 - race_loss: 0.7782 - gender_loss: 0.2841 - age_accuracy: 0.7014 - age_auc: 0.9332 - race_accuracy: 0.7265 - race_auc_1: 0.9231 - gender_accuracy: 0.8792 - gender_auc_2: 0.9511 - val_loss: 2.3207 - val_age_loss: 0.7305 - val_race_loss: 0.7975 - val_gender_loss: 0.2869 - val_age_accuracy: 0.6986 - val_age_auc: 0.9326 - val_race_accuracy: 0.7320 - val_race_auc_1: 0.9296 - val_gender_accuracy: 0.8784 - val_gender_auc_2: 0.9529
# Epoch 138/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.2425 - age_loss: 0.7058 - race_loss: 0.7702 - gender_loss: 0.2857 - age_accuracy: 0.7027 - age_auc: 0.9329 - race_accuracy: 0.7284 - race_auc_1: 0.9247 - gender_accuracy: 0.8799 - gender_auc_2: 0.9507 - val_loss: 2.3199 - val_age_loss: 0.7339 - val_race_loss: 0.7937 - val_gender_loss: 0.2866 - val_age_accuracy: 0.7034 - val_age_auc: 0.9321 - val_race_accuracy: 0.7344 - val_race_auc_1: 0.9299 - val_gender_accuracy: 0.8782 - val_gender_auc_2: 0.9530
# Epoch 139/150
# 474/474 [==============================] - 22s 46ms/step - loss: 2.2331 - age_loss: 0.6996 - race_loss: 0.7703 - gender_loss: 0.2827 - age_accuracy: 0.7040 - age_auc: 0.9340 - race_accuracy: 0.7330 - race_auc_1: 0.9247 - gender_accuracy: 0.8824 - gender_auc_2: 0.9516 - val_loss: 2.3084 - val_age_loss: 0.7315 - val_race_loss: 0.7884 - val_gender_loss: 0.2861 - val_age_accuracy: 0.7015 - val_age_auc: 0.9320 - val_race_accuracy: 0.7357 - val_race_auc_1: 0.9301 - val_gender_accuracy: 0.8774 - val_gender_auc_2: 0.9530
# Epoch 140/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.2440 - age_loss: 0.7038 - race_loss: 0.7733 - gender_loss: 0.2827 - age_accuracy: 0.7022 - age_auc: 0.9332 - race_accuracy: 0.7315 - race_auc_1: 0.9239 - gender_accuracy: 0.8826 - gender_auc_2: 0.9518 - val_loss: 2.3058 - val_age_loss: 0.7271 - val_race_loss: 0.7911 - val_gender_loss: 0.2837 - val_age_accuracy: 0.7063 - val_age_auc: 0.9338 - val_race_accuracy: 0.7333 - val_race_auc_1: 0.9292 - val_gender_accuracy: 0.8798 - val_gender_auc_2: 0.9538
# Epoch 141/150
# 474/474 [==============================] - 22s 46ms/step - loss: 2.2412 - age_loss: 0.7063 - race_loss: 0.7689 - gender_loss: 0.2847 - age_accuracy: 0.7036 - age_auc: 0.9328 - race_accuracy: 0.7299 - race_auc_1: 0.9251 - gender_accuracy: 0.8791 - gender_auc_2: 0.9510 - val_loss: 2.3214 - val_age_loss: 0.7291 - val_race_loss: 0.7996 - val_gender_loss: 0.2836 - val_age_accuracy: 0.7015 - val_age_auc: 0.9329 - val_race_accuracy: 0.7341 - val_race_auc_1: 0.9280 - val_gender_accuracy: 0.8806 - val_gender_auc_2: 0.9539
# Epoch 142/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.2233 - age_loss: 0.6984 - race_loss: 0.7651 - gender_loss: 0.2799 - age_accuracy: 0.7062 - age_auc: 0.9344 - race_accuracy: 0.7315 - race_auc_1: 0.9258 - gender_accuracy: 0.8815 - gender_auc_2: 0.9526 - val_loss: 2.3137 - val_age_loss: 0.7308 - val_race_loss: 0.7928 - val_gender_loss: 0.2826 - val_age_accuracy: 0.7042 - val_age_auc: 0.9328 - val_race_accuracy: 0.7333 - val_race_auc_1: 0.9299 - val_gender_accuracy: 0.8811 - val_gender_auc_2: 0.9538
# Epoch 143/150
# 474/474 [==============================] - 22s 46ms/step - loss: 2.2307 - age_loss: 0.7020 - race_loss: 0.7664 - gender_loss: 0.2811 - age_accuracy: 0.7046 - age_auc: 0.9338 - race_accuracy: 0.7308 - race_auc_1: 0.9255 - gender_accuracy: 0.8829 - gender_auc_2: 0.9524 - val_loss: 2.3003 - val_age_loss: 0.7275 - val_race_loss: 0.7873 - val_gender_loss: 0.2812 - val_age_accuracy: 0.7015 - val_age_auc: 0.9333 - val_race_accuracy: 0.7368 - val_race_auc_1: 0.9309 - val_gender_accuracy: 0.8816 - val_gender_auc_2: 0.9545
# Epoch 144/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.2302 - age_loss: 0.7005 - race_loss: 0.7676 - gender_loss: 0.2793 - age_accuracy: 0.7069 - age_auc: 0.9341 - race_accuracy: 0.7320 - race_auc_1: 0.9252 - gender_accuracy: 0.8862 - gender_auc_2: 0.9529 - val_loss: 2.3066 - val_age_loss: 0.7304 - val_race_loss: 0.7886 - val_gender_loss: 0.2813 - val_age_accuracy: 0.7023 - val_age_auc: 0.9330 - val_race_accuracy: 0.7399 - val_race_auc_1: 0.9310 - val_gender_accuracy: 0.8816 - val_gender_auc_2: 0.9544
# Epoch 145/150
# 474/474 [==============================] - 23s 48ms/step - loss: 2.2201 - age_loss: 0.6967 - race_loss: 0.7646 - gender_loss: 0.2815 - age_accuracy: 0.7098 - age_auc: 0.9347 - race_accuracy: 0.7338 - race_auc_1: 0.9255 - gender_accuracy: 0.8810 - gender_auc_2: 0.9522 - val_loss: 2.2917 - val_age_loss: 0.7247 - val_race_loss: 0.7843 - val_gender_loss: 0.2814 - val_age_accuracy: 0.7029 - val_age_auc: 0.9337 - val_race_accuracy: 0.7386 - val_race_auc_1: 0.9310 - val_gender_accuracy: 0.8803 - val_gender_auc_2: 0.9543
# Epoch 146/150
# 474/474 [==============================] - 23s 49ms/step - loss: 2.2271 - age_loss: 0.7006 - race_loss: 0.7657 - gender_loss: 0.2753 - age_accuracy: 0.7076 - age_auc: 0.9341 - race_accuracy: 0.7311 - race_auc_1: 0.9255 - gender_accuracy: 0.8829 - gender_auc_2: 0.9541 - val_loss: 2.3042 - val_age_loss: 0.7301 - val_race_loss: 0.7873 - val_gender_loss: 0.2807 - val_age_accuracy: 0.7037 - val_age_auc: 0.9329 - val_race_accuracy: 0.7373 - val_race_auc_1: 0.9307 - val_gender_accuracy: 0.8814 - val_gender_auc_2: 0.9549
# Epoch 147/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.2172 - age_loss: 0.6988 - race_loss: 0.7609 - gender_loss: 0.2763 - age_accuracy: 0.7039 - age_auc: 0.9342 - race_accuracy: 0.7358 - race_auc_1: 0.9264 - gender_accuracy: 0.8826 - gender_auc_2: 0.9537 - val_loss: 2.2933 - val_age_loss: 0.7319 - val_race_loss: 0.7781 - val_gender_loss: 0.2826 - val_age_accuracy: 0.7010 - val_age_auc: 0.9321 - val_race_accuracy: 0.7386 - val_race_auc_1: 0.9317 - val_gender_accuracy: 0.8798 - val_gender_auc_2: 0.9539
# Epoch 148/150
# 474/474 [==============================] - 24s 51ms/step - loss: 2.2215 - age_loss: 0.6993 - race_loss: 0.7632 - gender_loss: 0.2776 - age_accuracy: 0.7077 - age_auc: 0.9341 - race_accuracy: 0.7331 - race_auc_1: 0.9262 - gender_accuracy: 0.8835 - gender_auc_2: 0.9535 - val_loss: 2.2884 - val_age_loss: 0.7264 - val_race_loss: 0.7806 - val_gender_loss: 0.2807 - val_age_accuracy: 0.7013 - val_age_auc: 0.9331 - val_race_accuracy: 0.7373 - val_race_auc_1: 0.9315 - val_gender_accuracy: 0.8819 - val_gender_auc_2: 0.9546
# Epoch 149/150
# 474/474 [==============================] - 22s 47ms/step - loss: 2.2148 - age_loss: 0.6984 - race_loss: 0.7597 - gender_loss: 0.2761 - age_accuracy: 0.7074 - age_auc: 0.9341 - race_accuracy: 0.7328 - race_auc_1: 0.9269 - gender_accuracy: 0.8847 - gender_auc_2: 0.9539 - val_loss: 2.2893 - val_age_loss: 0.7272 - val_race_loss: 0.7803 - val_gender_loss: 0.2801 - val_age_accuracy: 0.6997 - val_age_auc: 0.9327 - val_race_accuracy: 0.7386 - val_race_auc_1: 0.9313 - val_gender_accuracy: 0.8814 - val_gender_auc_2: 0.9548
# Epoch 150/150
# 474/474 [==============================] - 21s 45ms/step - loss: 2.2132 - age_loss: 0.6973 - race_loss: 0.7597 - gender_loss: 0.2769 - age_accuracy: 0.7065 - age_auc: 0.9345 - race_accuracy: 0.7329 - race_auc_1: 0.9267 - gender_accuracy: 0.8842 - gender_auc_2: 0.9535 - val_loss: 2.2732 - val_age_loss: 0.7248 - val_race_loss: 0.7720 - val_gender_loss: 0.2794 - val_age_accuracy: 0.6999 - val_age_auc: 0.9329 - val_race_accuracy: 0.7370 - val_race_auc_1: 0.9325 - val_gender_accuracy: 0.8832 - val_gender_auc_2: 0.9550
#
# Elapsed Time:  0:53:02.114418

# %%
# save the model to disk
#Source: (https://www.tensorflow.org/api_docs/python/tf/keras/models/save_model)
# Save the entire model as a SavedModel.

# save(): To create a SavedModel folder `saved_model`, containing "assets", "saved_model.pb" & "variables".
# The model architecture, and training configuration (including the optimizer, losses, and metrics) are stored in `saved_model.pb`.
# The weights are saved in the `variables/` directory.
# path = "../models/saved_model/latest_model"

#model.save('../models/saved_model/latest_model/you_model_name.tf')

f_name = r'CNN-model-'
f_time = datetime.now().strftime("%Y-%m-%d_%I-%M-%S_%p")
file = f_name + f_time + '.h5'
filepath = '../ModelTrainingService/models/' + file
model.save(filepath, include_optimizer=True)
print("[INFO] Model \"%s\" saved (Saving into the path takes few minutes)." % file)
# Out:
# [INFO] Model "CNN-model-2023-01-03_04-43-01_PM.h5" saved (Saving into the path takes few minutes).

# %%
# Load the latest trained model
from keras.models import load_model

#loaded_model = load_model('../models/saved_model/latest_model')
#loaded_model = load_model('../models/saved_model/latest_model/you_model_name.tf')
loaded_model = load_model(filepath, compile=False)
print("[INFO] Model \"%s\" loaded" % file)
# Out:
# [INFO] Model "CNN-model-2023-01-03_04-43-01_PM.h5" loaded

# %%
# Predict the age group and the gender of the person from aligned & cropped profile face picture.

from keras.preprocessing import image
from keras.utils import load_img
from keras.preprocessing.image import ImageDataGenerator

# Load the image and size it.
def loadImage(filepath):
  test_img = load_img(filepath, target_size=(image_width, image_height, 3))
  test_img = img_to_array(test_img) # To convert a loaded image in PIL format into a NumPy array for use with deep learning models.
  test_img /= 255
  test_img = np.expand_dims(test_img, axis = 0)

  return test_img

import random as rn
from PIL import Image, ImageFont

# To choose image randomly from dataset
path=df['file']
picture = rn.choice(path)

#picture='../models/test_img/kenny-rogers.jpg' # Change the path for other image files if you would like to see more.
age_prediction, race_prediction, gender_prediction = loaded_model.predict(loadImage(picture))

print('Age_prediction: ', (age_prediction * 100), '%')
print('Race_prediction: ', (race_prediction * 100), '%')
print('Gender_prediction: ', (gender_prediction * 100), '%')
print(picture)

img = load_img(picture)
plt.imshow(img)
plt.show()
max = -1
count = 0

for i in age_prediction[0]:
    if i > max:
        max = i
        temp = count
    count+=1

#Conditions for outputs
if temp == 0:
    print('0-24 yrs old')
if temp == 1:
    print('25-49 yrs old')
if temp == 2:
    print('50-74 yrs old')
if temp == 3:
    print('75-99 yrs old')
if temp == 4:
    print('100-124 yrs old')

if gender_prediction[0][0] > gender_prediction[0][1]:
  print('Male')
else:
  print('Female')
# Out:
# 1/1 [==============================] - 0s 48ms/step
# Age_prediction:  [[1.0565766e+01 7.9502777e+01 9.7544928e+00 1.6939603e-01 7.5626876e-03]] %
# Race_prediction:  [[58.391006  12.880261   2.5976467 18.28295    7.848134 ]] %
# Gender_prediction:  [[99.69445    0.3280288]] %
# ../ModelTrainingService/input/utkface-new/UTKFace\26_0_0_20170103235356420.jpg.chip.jpg
# 25-49 yrs old
# Male

# %% [markdown]
# ## Evaluating our model on the validation and test dataset

# %%
# To returns the loss value & metric values for the model in test dataset
test_batch_size = 128
test_generator = data_generator.generate_images(test_idx,
                                                is_training=False,
                                                batch_size=test_batch_size)

age_pred, race_pred, gender_pred = model.predict(test_generator,
                                                 steps=len(test_idx)//test_batch_size)
# print('Age_on_test: ', len(age_pred))
# print('Gender_on_test: ', len(gender_pred))
# print('Race_on_test: ', len(race_pred))
# Out:
# 37/37 [==============================] - 8s 185ms/step

# %%
test_batch_size = 128

test_generator  = data_generator.generate_images(test_idx,
                                                is_training=False,
                                                batch_size=test_batch_size)

images, age_true, race_true, gender_true = [], [], [], []

for test_batch in test_generator:
    image = test_batch[0]
    labels = test_batch[1]

    images.extend(image)
    age_true.extend(labels[0])
    race_true.extend(labels[1])
    gender_true.extend(labels[2])

age_true = np.array(age_true)
race_true = np.array(race_true)
gender_true = np.array(gender_true)

race_true, gender_true = race_true.argmax(axis=-1), gender_true.argmax(axis=-1)
race_pred, gender_pred = race_pred.argmax(axis=-1), gender_pred.argmax(axis=-1)

age_true = age_true.argmax(axis=-1) # * data_generator.max_age
age_pred = age_pred.argmax(axis=-1) # * data_generator.max_age

# %%
train_scores = {}
train_scores = model.evaluate(train_gen, steps=1000, batch_size=32)
print('\nEvaluation results on training dataset...')
dict(zip(model.metrics_names, train_scores))
# Out:
# 1000/1000 [==============================] - 38s 38ms/step - loss: 2.1717 - age_loss: 0.6859 - race_loss: 0.7447 - gender_loss: 0.2586 - age_accuracy: 0.7251 - age_auc: 0.9426 - race_accuracy: 0.7592 - race_auc_1: 0.9392 - gender_accuracy: 0.8996 - gender_auc_2: 0.9641
#
# Evaluation results on training dataset...
# {'loss': 2.1717405319213867,
#  'age_loss': 0.6858786344528198,
#  'race_loss': 0.7447106242179871,
#  'gender_loss': 0.25858065485954285,
#  'age_accuracy': 0.7251250147819519,
#  'age_auc': 0.9425671696662903,
#  'race_accuracy': 0.7591562271118164,
#  'race_auc_1': 0.9392462968826294,
#  'gender_accuracy': 0.8996250033378601,
#  'gender_auc_2': 0.9640530943870544}

# %%
valid_scores = {}
valid_scores = model.evaluate(valid_gen, steps=1000, batch_size=32)
print('\nEvaluation results on validation dataset...')
dict(zip(model.metrics_names, valid_scores))
# Out:
# 1000/1000 [==============================] - 37s 37ms/step - loss: 2.2732 - age_loss: 0.7245 - race_loss: 0.7724 - gender_loss: 0.2792 - age_accuracy: 0.7007 - age_auc: 0.9330 - race_accuracy: 0.7372 - race_auc_1: 0.9324 - gender_accuracy: 0.8831 - gender_auc_2: 0.9551
#
# Evaluation results on validation dataset...
# {'loss': 2.273216724395752,
#  'age_loss': 0.7244604229927063,
#  'race_loss': 0.7723994255065918,
#  'gender_loss': 0.27924972772598267,
#  'age_accuracy': 0.7007499933242798,
#  'age_auc': 0.932955801486969,
#  'race_accuracy': 0.7372499704360962,
#  'race_auc_1': 0.9324145317077637,
#  'gender_accuracy': 0.8830937743186951,
#  'gender_auc_2': 0.9551004767417908}

# %%
# Evaluate the model on test data
test_gen = data_generator.generate_images(test_idx,
                                           is_training=True,
                                           batch_size=32)
test_results = {}
test_scores = model.evaluate(test_gen, steps=1000, batch_size=32)
print('\nEvaluation results on test dataset...')
dict(zip(model.metrics_names, test_scores))
# test_results = dict(zip(model.metrics_names, test_scores))
# print('\n')
# for key, value in test_results.items():
#   print("%s: %s" % (key, round(value*100, 2)), '%')
# Out:
# 1000/1000 [==============================] - 38s 37ms/step - loss: 2.2559 - age_loss: 0.7098 - race_loss: 0.7747 - gender_loss: 0.2920 - age_accuracy: 0.7092 - age_auc: 0.9361 - race_accuracy: 0.7460 - race_auc_1: 0.9312 - gender_accuracy: 0.8756 - gender_auc_2: 0.9506
#
# Evaluation results on test dataset...
# {'loss': 2.255948305130005,
#  'age_loss': 0.7098116874694824,
#  'race_loss': 0.7746881246566772,
#  'gender_loss': 0.2919757664203644,
#  'age_accuracy': 0.7091562747955322,
#  'age_auc': 0.936077892780304,
#  'race_accuracy': 0.7460312247276306,
#  'race_auc_1': 0.931212306022644,
#  'gender_accuracy': 0.8756250143051147,
#  'gender_auc_2': 0.950584352016449}

# %%
# Classification report for gender feature
from sklearn.metrics import classification_report, confusion_matrix
print('Classification Report for "Gender"\n')
classification_report_gender = classification_report(gender_true, gender_pred, target_names=dataset_dict['gender_temp'].keys(), zero_division=0)
print(classification_report_gender)
# Out:
# Classification Report for "Gender"
#
#               precision    recall  f1-score   support
#
#         male       0.88      0.88      0.88      2471
#       female       0.87      0.87      0.87      2265
#
#     accuracy                           0.88      4736
#    macro avg       0.88      0.88      0.88      4736
# weighted avg       0.88      0.88      0.88      4736

# %%
# Classification report for age feature
classification_report_gender = classification_report(age_true, age_pred, target_names=dataset_dict['age_id'].keys(), zero_division=0)
print(classification_report_gender)
#print('Classification Report for "Gender"\n')
# Out:
#               precision    recall  f1-score   support
#
#         0-24       0.76      0.68      0.72      1405
#        25-49       0.71      0.86      0.78      2326
#        50-74       0.61      0.45      0.51       785
#        75-99       0.68      0.25      0.37       217
#      100-124       0.00      0.00      0.00         3
#
#     accuracy                           0.71      4736
#    macro avg       0.55      0.45      0.48      4736
# weighted avg       0.70      0.71      0.70      4736

# %%
# Age ROC curves (Multiclass classification)
# Source: https://stackoverflow.com/questions/39685740/calculate-sklearn-roc-auc-score-for-multi-class
from sklearn.metrics import accuracy_score, roc_curve

age_groups = ['0-24', '25-49','50-74','75-99', '100-124']
def roc_auc_score_multiclass(age_true, age_pred, average = "macro"):

  #creating a set of all the unique classes using the actual class list
  unique_class = set(age_true)
  roc_auc_dict = {}

  for per_class in unique_class:
    #creating a list of all the classes except the current class
    other_class = [x for x in unique_class if x != per_class]

    #marking the current class as 1 and all other classes as 0
    new_actual_class = [0 if x in other_class else 1 for x in age_true]
    new_pred_class = [0 if x in other_class else 1 for x in age_pred]

    #using the sklearn metrics method to calculate the roc_auc_score
    from sklearn.metrics import roc_curve, roc_auc_score
    fpr_age, tpr_age, threshold_age = roc_curve(new_actual_class, new_pred_class)
    roc_auc = roc_auc_score(new_actual_class, new_pred_class)
    roc_auc_dict[per_class] = roc_auc


    # plotting
    plt.plot(fpr_age, tpr_age, linestyle='-',color='red', label=f'Area Under ROC Curve : {roc_auc:.3f}')
    plt.plot([0, 1], [0, 1], color='blue', linestyle='--', label='Baseline')
    plt.title('Age group ' + age_groups[per_class] + ' ROC curve')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive rate')
    plt.legend(loc='best', fancybox=True,)
    save_name = 'metrics_figures/ROC_curve_age_group_' + age_groups[per_class] + '.png'
    plt.savefig(save_name, bbox_inches='tight')
    plt.show()
    plt.close()

  return roc_auc_dict

roc_auc_multiclass = roc_auc_score_multiclass(age_true, age_pred)
acc = accuracy_score(age_true, age_pred)

for i in roc_auc_multiclass:
  print('Roc_Auc_score for age group', age_groups[i], ': {:.0%}'.format(roc_auc_multiclass[i]))
# Out:
# Roc_Auc_score for age group 0-24 : 80%
# Roc_Auc_score for age group 25-49 : 76%
# Roc_Auc_score for age group 50-74 : 69%
# Roc_Auc_score for age group 75-99 : 62%
# Roc_Auc_score for age group 100-124 : 50%

# %%
# Gender ROC curves (Binary classification)
from sklearn.metrics import roc_auc_score, roc_curve

fpr_gender, tpr_gender, threshold_gender = roc_curve(gender_true, gender_pred)
auc_score_gender = roc_auc_score(gender_true, gender_pred)

# plotting
plt.plot(fpr_gender, tpr_gender, linestyle='-',color='green', label=f'Area Under ROC Curve : {auc_score_gender:.3f}')
plt.plot([0, 1], [0, 1], color='blue', linestyle='--', label='Baseline')
plt.title('Gender ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best', fancybox=True,)
plt.savefig(fname='metrics_figures/ROC_curve_gender.png', bbox_inches='tight')
plt.show()
plt.close()

# %%
# Confusion matrix for age and gender (true vs predicted)
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools

# Source= https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html#sphx-glr-auto-examples-model-selection-plot-confusion-matrix-py
def plot_confusion_matrix(cm,
                          classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm,
               interpolation='nearest',
               cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if title == 'Confusion Matrix for "Age" (Multiclass Classification)':
      plt.savefig(fname='metrics_figures/Conf_Mtrx_age.png', bbox_inches='tight')
    else:
      plt.savefig(fname='metrics_figures/Conf_Mtrx_gender.png', bbox_inches='tight')
    plt.show()
    plt.close()

print('Total age count in test dataset: %s' % len(age_pred), '\n')
cm_age = confusion_matrix(age_true, age_pred)
cm_age_plot_labels = ['0-24', '25-49', '50-74', '75-99', '100-124']
plot_confusion_matrix(cm=cm_age, classes=cm_age_plot_labels, title='Confusion Matrix for "Age" (Multiclass Classification)')

print('Total gender count in test dataset: %s' % len(gender_pred), '\n')
cm_gender = confusion_matrix(gender_true, gender_pred)
cm_gender_plot_labels = ['male', 'female']
plot_confusion_matrix(cm=cm_gender, classes=cm_gender_plot_labels, title='Confusion Matrix for "Gender" (Binary Classification)')
# Out:
# Total age count in test dataset: 4736
#
# Confusion matrix, without normalization
# [[ 959  437    7    2    0]
#  [ 239 1993   93    1    0]
#  [  50  364  351   20    0]
#  [  15   19  128   55    0]
#  [   0    0    0    3    0]]
# Total gender count in test dataset: 4736
#
# Confusion matrix, without normalization
# [[2183  288]
#  [ 300 1965]]

# %%
# # Age accuracy

plt.plot(history.history['age_accuracy'])
plt.plot(history.history['val_age_accuracy'])
plt.title('Age Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='best', fancybox=True)
plt.savefig(fname='metrics_figures/age_accuracy.png', bbox_inches='tight')
plt.show()
plt.close()

# # Age loss
plt.plot(history.history['age_loss'])
plt.plot(history.history['val_age_loss'])
plt.title('Age Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='best', fancybox=True)
plt.savefig(fname='metrics_figures/age_loss.png', bbox_inches='tight')
plt.show()
plt.close()

# %%
# Gender accuracy
plt.plot(history.history['gender_accuracy'])
plt.plot(history.history['val_gender_accuracy'])
plt.title('Gender Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='best', fancybox=True)
plt.savefig(fname='metrics_figures/gender_accuracy.png', bbox_inches='tight')
plt.show()
plt.close()

# Gender loss
plt.plot(history.history['gender_loss'])
plt.plot(history.history['val_gender_loss'])
plt.title('Gender Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='best', fancybox=True)
plt.savefig(fname='metrics_figures/gender_loss.png', bbox_inches='tight')
plt.show()
plt.close()

# %%
# Overall loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Overall Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='best', fancybox=True)
plt.savefig(fname='metrics_figures/overall_loss.png', bbox_inches='tight')
plt.show()
plt.close()
