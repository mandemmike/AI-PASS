# %% [markdown]
# # Age & Gender Detection with CNN
#
# **Dataset : UTKFace**
#
# UTKFace dataset is a large-scale face dataset with range from 0 to 116 years old. It consists of over 23,708 face images with labels of age, gender, and ethnicity. The images cover large variation in pose, facial expression, illumination, occlusion, resolution, etc.
#
# Since the dataset is `aligned and cropped` faces available to train the model. Have to say that any face input for testing must be cropped and aligned vertically to large extent.

# %%
# Essential libraries
import os
import glob
import seaborn as sns
import scipy.io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras import applications,activations
from keras_preprocessing.image import img_to_array, load_img
from keras.preprocessing import image
from keras import optimizers,utils
from keras.utils import plot_model
from keras.models import Sequential, Model
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D,BatchNormalization,ZeroPadding2D, Input
from keras.layers import Conv2D, Activation,MaxPooling2D
from keras import backend as k
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping

# %%
# Mounting the directory for the dataset to be read.
dataset_folder = '../ModelTrainingService/input/utkface-new/UTKFace/'
training_split = 0.8
image_width = image_height = 48

dataset_dict = {
    'age_id': {'0-24': 0, '25-49':1, '50-74':2, '75-99':3, '100-124':4},
    'race_id': {0: 'white', 1: 'black', 2: 'asian', 3: 'indian', 4: 'others'},
    'gender_id': {0: 'male', 1: 'female'}
}

dataset_dict['age_temp'] = dict((a, i) for i, a in dataset_dict['age_id'].items())          # (Age: id)
dataset_dict['gender_temp'] = dict((g, i) for i, g in dataset_dict['gender_id'].items())    # (Gender: id)
dataset_dict['race_temp'] = dict((r, i) for i, r in dataset_dict['race_id'].items())        # (Race: id)

# %%
# Function to extract the data from our dataset by iterating over each file of the UTK dataset and
# return a Pandas Dataframe with all the fields (age, gender and sex).

def parse_dataset(dataset_path, ext='jpg'):

    def parse_info_from_file(path):  #Parsing info from a file

        try:
            file_name = os.path.split(path)[1]
            file_name = os.path.splitext(file_name)[0]
            age, gender, race, _ = file_name.split('_')

            return int(age), dataset_dict['gender_id'][int(gender)], dataset_dict['race_id'][int(race)]
        except Exception as ex:
            return None, None, None

    files = glob.glob(os.path.join(dataset_path, "*.%s" % ext))

    records = []
    for file in files:
        info = parse_info_from_file(file)
        records.append(info) # To place new items in the available space

    df = pd.DataFrame(records)
    df['file'] = files
    df.columns = ['age', 'gender', 'race', 'file']


    df = df.dropna() # To remove the rows that contains NULL values.

    return df

# %%
# Dataset before indexing
df = parse_dataset(dataset_folder)
df.head()
# Out:
#    age  gender   race                                               file
# 0  100    male  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 1  100    male  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 2  100  female  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 3  100  female  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 4  100  female  white  ../ModelTrainingService/input/utkface-new/UTKF...

# %%
# No NAN values, means our dataset is already clean.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23708 entries, 0 to 23707
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     23708 non-null  int64
#  1   gender  23708 non-null  object
#  2   race    23708 non-null  object
#  3   file    23708 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 741.0+ KB

# %%
# Lower percentile - 25, median - 50 & upper percentile - 75 (for numerical data)
df.describe()
# Out:
#                 age
# count  23708.000000
# mean      33.303484
# std       19.886112
# min        1.000000
# 25%       23.000000
# 50%       29.000000
# 75%       45.000000
# max      116.000000

# %%
# Mean age by gender
df.groupby(['gender']).mean('age')
# Out:
#               age
# gender
# female  30.684280
# male    35.695666

# %%
# Mean age by race
df.groupby(['race']).mean('age')
# Out:
#               age
# race
# asian   25.877729
# black   33.861498
# indian  31.540241
# others  23.169031
# white   37.980949

# %% [markdown]
# # Data analysis & visualization (EDA)
#
# We can create here a function to generate some pie plots. We also look at the other visualization below to understand and grasp better about the data distribution to crete
# more efficient training, validation and test processes.

# %%
import plotly.graph_objects as go
from IPython.display import display, Image

def plot_distribution(pd_series):

    labels = pd_series.value_counts().index.tolist()
    counts = pd_series.value_counts().values.tolist()

    pie_plot = go.Pie(labels=labels, values=counts, hole=.3)
    fig = go.Figure(data=[pie_plot])
    fig.update_layout(title_text='Distribution for %s' % pd_series.name)

    img_bytes = fig.to_image(format="png")
    #fig.show()
    display(Image(img_bytes))

# # Same as bar plot. Creating bins for age ranges and plotting that data. This helps us to see grouped age into bins with percentages.
bins = [0, 10, 20, 30, 40, 60, 80, np.inf]
names = ['<10', '10-20', '20-30', '30-40', '40-60', '60-80', '80+']
age_binned = pd.cut(df['age'], bins, labels=names)
plot_distribution(age_binned)

# %%
# Uniform distribution to a large extent. Although, males slightly exceed females in numbers.No need to change gender in data.
# Pretty well-balanced ! Let's also visualize this on a bar graph (to get better understanding of numbers)
x = (df.gender=='male').sum()
y = (df.gender=='female').sum()

# Males over 12k while females close to 12k
labels = ['male','female']
colors = [ 'r', 'g']
gender_pie = [x,y]
explode = (0, 0)  # explode the 2nd slice (i.e. 'female')
plt.pie(gender_pie,labels = labels,
        colors = colors,
        explode=explode,
        radius=1.5,
        autopct='%.1f%%',
        textprops={'color':"Black", 'size':15},
        startangle=90)
plt.legend(gender_pie, bbox_to_anchor=(1.1, 1.1), fontsize='x-large')
plt.show()

# %%
# Distribution for race
x = (df.race == 'white').sum()
y = (df.race == 'black').sum()
z = (df.race == 'asian').sum()
a = (df.race == 'indian').sum()
b = (df.race == 'others').sum()

race_pie = [x, y, z, a, b]
labels = ['white', 'black', 'asian', 'indian', 'others']
colors = ['g', 'r', 'b', 'y', 'm']
plt.pie(race_pie, labels=labels, colors=colors, radius=1.5, autopct='%.1f%%', textprops={'color':"Black", 'size':10},)
plt.show()

# %%
# The population is mostly between 20-30 age group, the dataset is not very well-balanced. We try to embrace this imbalance through imagedatagenerator below.
ages = df['age']
nbins = 120
plt.figure(figsize=(15,8))
plt.hist(ages,nbins,color='red',histtype='bar')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Number of datapoints')
plt.show()

# %%
# Males over 12k & females close to 12k
sns.countplot(x='gender', data=df);

# %%
# Gives the mean age of both genders of all races
sns.catplot(x='race', y='age', hue='gender', data=df,kind='bar', height=5);

# %%
# We see that most of the males are between 25 and 55, whereas most of the females are between 20 and 40.
# Grouping by race, there is good amount of variations in different races.
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
_ = sns.boxplot(data=df, x='gender', y='age', ax=ax1)
_ = sns.boxplot(data=df, x='race', y='age', ax=ax2)

# %%
# RUN THIS CELL ONLY ONCE
# To create age groups
df['age'] = df['age']//25

''' This basically makes 5 divisions in age-groups -
1. 0-24
2. 25-49
3. 50-74
4. 75-99
5. 100-124 '''

x = (df.age==0).sum()
y = (df.age==1).sum()
z = (df.age==2).sum()
a = (df.age==3).sum()
b = (df.age==4).sum()
c = (df.age==5).sum() # To see that nothing left in the dataset

print(x,' ', y,' ', z,' ', a,' ', b, ' ', c,' ')
# Out:
# 6903   11816   3990   967   32   0

# %%
# After distribition of the ages into groups, we have now age groups 0 to 4 for age feature which contains ages from 1y to 116y.
df.head()
# Out:
#    age  gender   race                                               file
# 0    4    male  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 1    4    male  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 2    4  female  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 3    4  female  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 4    4  female  white  ../ModelTrainingService/input/utkface-new/UTKF...

# %% [markdown]
# # Data image generator
# To be able to use as input to our model, below is the keras image data generator by creating batches of image data to feed the multi-output predictions.

# %%
# Data image generator for augmenting the data
# Generating batches of data, which will be used to feed our multi-output model with both the images and their labels.
import cv2
from keras.utils import to_categorical, normalize
from PIL import Image, ImageFont

class UtkFaceDataGenerator():

    # Data generator for the UTKFace dataset. This class should be used when training our Keras multi-output model.
    def __init__(self, df):
        self.df = df

    def generate_split_indexes(self):
      p = np.random.permutation(len(self.df))
      train_df = int(len(self.df) * training_split)
      train_idx = p[:train_df]
      test_idx = p[train_df:]

      train_df = int(train_df * training_split)
      train_idx, valid_idx = train_idx[:train_df], train_idx[train_df:]


      # converts alias to id
      self.df['age_id'] = self.df['age'].map(lambda age: dataset_dict['age_temp'][age])
      self.df['gender_id'] = self.df['gender'].map(lambda gender: dataset_dict['gender_temp'][gender])
      self.df['race_id'] = self.df['race'].map(lambda race: dataset_dict['race_temp'][race])
      #self.max_age = self.df['age'].max()

      return train_idx, valid_idx, test_idx

    def preprocess_image(self, img_path):

      # Used to perform some minor preprocessing (BGR2RGB) on the image before inputting into the network because matplotlib plot function expects RGB.

      im = cv2.imread(img_path)
      im = cv2.resize(im, (image_width, image_height))
      im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
      im = np.array(im) / 255.0

      return im

    def generate_images(self, image_idx, is_training, batch_size=16):
      """
      Used to generate a batch with images when training/testing/validating our Keras model.
      """

      # arrays to store our batched data
      images, ages, races, genders = [], [], [], []
      while True:
        for idx in image_idx:
          person = self.df.iloc[idx]

          age = person['age']
          race = person['race_id']
          gender = person['gender_id']
          file = person['file']

          im = self.preprocess_image(file)

          #ages.append(age / self.max_age)
          ages.append(to_categorical(age,len(dataset_dict['age_id'])))
          races.append(to_categorical(race, len(dataset_dict['race_id'])))
          genders.append(to_categorical(gender, len(dataset_dict['gender_id'])))
          images.append(im)

          # yielding condition
          if len(images) >= batch_size:
            yield np.array(images), [np.array(ages), np.array(races), np.array(genders)]
            images, ages, races, genders = [], [], [], []

        if not is_training:
          break

data_generator = UtkFaceDataGenerator(df)
train_idx, valid_idx, test_idx = data_generator.generate_split_indexes()

print('Train dataset lenght: ', len(train_idx))
print('Validation dataset lenght: ', len(valid_idx))
print('Test dataset lenght: ', len(test_idx))
# Out:
# Train dataset lenght:  15172
# Validation dataset lenght:  3794
# Test dataset lenght:  4742

# %% [markdown]
# ## Model Architecture

# %%
# Source: https://pyimagesearch.com/2018/06/04/keras-multiple-outputs-and-multiple-losses/
# CNN Model Architecture by splitting the labels (age, gender, race) for flatten, dropout and activation of the layers.
from keras.layers.convolutional import Conv2D, SeparableConv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Dropout
from keras.layers.core import Lambda
from keras.layers.core import Dense
from keras.models import Model
from keras.layers import BatchNormalization
from keras.layers import SpatialDropout2D
from keras.layers import Flatten
from keras.layers import Input
from keras.regularizers import l2
import tensorflow as tf

# SeparableConv2D: A variation of the traditional convolution that was to compute it faster than conv2D.
# "same" vs "valid": Output size is the "same" results in padding with zeros evenly to the left/right or up/down, while "valid" is no padding.
# Source for more detail about padding: https://stackoverflow.com/questions/37674306/what-is-the-difference-between-same-and-valid-padding-in-tf-nn-max-pool-of-t
# BatchNormalization: To speed up training and to use higher learning rates, making learning easier and to distribute the data uniformly across a mean
#                     that the network sees best as well as to guarantee that the values are within a healthy range, avoiding saturation and vanishing gradients.
# MaxPooling2D: To downsample the input along its spatial dimensions (height and width) by taking the maximum value over an input window defined by pool_size for each channel.
# SpatialDropout2D: To drop the entire 2D feature maps instead of individual elements as dropout does.
# Strides: The window for shifting.
# Source: https://stackoverflow.com/questions/59634780/correct-order-for-spatialdropout2d-batchnormalization-and-activation-function
# Dropouts: To prevent over-fitting the model during training
# relu(Rectifier Linear Unit): Activation to prevent exponential growth in the computation and the emergence of the “vanishing gradient” problem
#                               by keeping gradient always high.
# Dense layer: To create fully connected layers, in which (linear) every output depends on every input after usage of Convolutional Layers with fewer parameters
# by forcing every input to the function and let the neurol network to learn its relation to the output.


class UtkMultiOutputModel():
    """
    Used to generate our multi-output model. This CNN contains three branches, one for age, other for
    sex and another for race. Each branch contains a sequence of Convolutional Layers that is defined
    on the make_default_hidden_layers method.
    """

    def hidden_layers(self, inputs):

        # To generate a default set of hidden layers. Structured as => Conv2D -> Activation "relu" -> BatchNormalization -> Pooling -> Dropout

        model_arc = SeparableConv2D(32, (3, 3), padding="same")(inputs)
        model_arc = Activation("relu")(model_arc)
        model_arc = MaxPooling2D(pool_size=(3, 3))(model_arc)
        model_arc = BatchNormalization(axis=-1)(model_arc)
        model_arc = SpatialDropout2D(0.25)(model_arc)

        model_arc = SeparableConv2D(64, (3, 3), padding="same")(model_arc)
        model_arc = Activation("relu")(model_arc)
        model_arc = MaxPooling2D(pool_size=(2, 2))(model_arc)
        model_arc = BatchNormalization(axis=-1)(model_arc)
        model_arc = SpatialDropout2D(0.25)(model_arc)

        model_arc = SeparableConv2D(128, (3, 3), padding="same")(model_arc)
        model_arc = Activation("relu")(model_arc)
        model_arc = MaxPooling2D(pool_size=(2, 2))(model_arc)
        model_arc = BatchNormalization(axis=-1)(model_arc)
        model_arc = SpatialDropout2D(0.1)(model_arc)

        # model_arc = SeparableConv2D(128, (3, 3), padding="same")(model_arc)
        # model_arc = Activation("relu")(model_arc)
        # model_arc = MaxPooling2D(pool_size=(2, 2))(model_arc)
        # model_arc = BatchNormalization(axis=-1)(model_arc)
        # model_arc = SpatialDropout2D(0.1)(model_arc)
        #
        # model_arc = SeparableConv2D(256, (3, 3), padding="same")(model_arc)
        # model_arc = Activation("relu")(model_arc)
        # model_arc = MaxPooling2D(pool_size=(2, 2))(model_arc)
        # model_arc = SpatialDropout2D(0.1)(model_arc)
        # model_arc = BatchNormalization(axis=-1)(model_arc)
        #
        # model_arc = SeparableConv2D(256, (3, 3), padding="same")(model_arc)
        # model_arc = Activation("relu")(model_arc)
        # model_arc = MaxPooling2D(pool_size=(2, 2))(model_arc)
        # model_arc = SpatialDropout2D(0.1)(model_arc)
        # model_arc = BatchNormalization(axis=-1)(model_arc)
        #
        # model_arc = SeparableConv2D(256, (3, 3), padding="same")(model_arc)
        # model_arc = Activation("relu")(model_arc)
        # model_arc = MaxPooling2D(pool_size=(2, 2))(model_arc)
        # model_arc = SpatialDropout2D(0.1)(model_arc)
        # model_arc = BatchNormalization(axis=-1)(model_arc)

        return model_arc

    def build_race_branch(self, inputs):

        # Race branch is structured as => Conv -> BatchNormalization -> Pool -> Dropout blocks, followed by the Dense output layer.
        model_arc = self.hidden_layers(inputs)
        model_arc = Flatten()(model_arc)
        model_arc = Dense(128)(model_arc)
        model_arc = Activation("relu")(model_arc)
        model_arc = Dropout(0.3)(model_arc)
        model_arc = BatchNormalization()(model_arc)
        model_arc = Dense(64)(model_arc)
        model_arc = Activation("relu")(model_arc)
        model_arc = Dropout(0.3)(model_arc)
        model_arc = BatchNormalization()(model_arc)
        model_arc = Dense(32)(model_arc)
        model_arc = Activation("relu")(model_arc)
        model_arc = Dropout(0.2)(model_arc)
        model_arc = BatchNormalization()(model_arc)
        model_arc = Dense(5)(model_arc)
        model_arc = Activation("softmax", name="race")(model_arc)

        return model_arc

    def build_gender_branch(self, inputs):

        # The gender branch is structured as = Conv -> BatchNormalization -> Pool -> Dropout blocks, followed by the Dense output layer.
        model_arc = self.hidden_layers(inputs)
        model_arc = Flatten()(model_arc)
        model_arc = Dense(128)(model_arc)
        model_arc = Activation("relu")(model_arc)
        model_arc = Dropout(0.3)(model_arc)
        model_arc = BatchNormalization()(model_arc)
        model_arc = Dense(2)(model_arc)
        model_arc = Activation("sigmoid", name="gender")(model_arc)

        return model_arc

    def build_age_branch(self, inputs):

        # The age branch is structured as = Conv -> BatchNormalization -> Pool -> Dropout blocks, followed by the Dense output layer.
        model_arc = self.hidden_layers(inputs)
        model_arc = Flatten()(model_arc)
        model_arc = Dense(128)(model_arc)
        model_arc = Activation("relu")(model_arc)
        model_arc = Dropout(0.3)(model_arc)
        model_arc = BatchNormalization()(model_arc)
        model_arc = Dense(64)(model_arc)
        model_arc = Activation("relu")(model_arc)
        model_arc = Dropout(0.3)(model_arc)
        model_arc = BatchNormalization()(model_arc)
        model_arc = Dense(32)(model_arc)
        model_arc = Activation("relu")(model_arc)
        model_arc = Dropout(0.2)(model_arc)
        model_arc = BatchNormalization()(model_arc)
        model_arc = Dense(5)(model_arc)
        model_arc = Activation("softmax", name="age")(model_arc)

        return model_arc

    # To assemble the output model with their determined height and width.
    def assemble_full_model(self, width, height):

        input_shape = (height, width, 3)
        inputs = Input(shape=input_shape)

        age_branch = self.build_age_branch(inputs)
        race_branch = self.build_race_branch(inputs)
        gender_branch = self.build_gender_branch(inputs)
        model = Model(inputs=inputs,
                     outputs = [age_branch, race_branch, gender_branch],
                     name="face_net")
        return model

model = UtkMultiOutputModel().assemble_full_model(image_width, image_height)

# To print out and save the layer model plot as png
from keras.utils import plot_model

plot_model(model, to_file='../ModelTrainingService/cnn_model_plot(latest).png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "face_net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  separable_conv2d (SeparableCon  (None, 48, 48, 32)  155         ['input_1[0][0]']
#  v2D)
#
#  separable_conv2d_3 (SeparableC  (None, 48, 48, 32)  155         ['input_1[0][0]']
#  onv2D)
#
#  activation (Activation)        (None, 48, 48, 32)   0           ['separable_conv2d[0][0]']
#
#  activation_6 (Activation)      (None, 48, 48, 32)   0           ['separable_conv2d_3[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 16, 16, 32)   0           ['activation[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 32)  0           ['activation_6[0][0]']
#
#  batch_normalization (BatchNorm  (None, 16, 16, 32)  128         ['max_pooling2d[0][0]']
#  alization)
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 32)  128         ['max_pooling2d_3[0][0]']
#  rmalization)
#
#  spatial_dropout2d (SpatialDrop  (None, 16, 16, 32)  0           ['batch_normalization[0][0]']
#  out2D)
#
#  spatial_dropout2d_3 (SpatialDr  (None, 16, 16, 32)  0           ['batch_normalization_6[0][0]']
#  opout2D)
#
#  separable_conv2d_6 (SeparableC  (None, 48, 48, 32)  155         ['input_1[0][0]']
#  onv2D)
#
#  separable_conv2d_1 (SeparableC  (None, 16, 16, 64)  2400        ['spatial_dropout2d[0][0]']
#  onv2D)
#
#  separable_conv2d_4 (SeparableC  (None, 16, 16, 64)  2400        ['spatial_dropout2d_3[0][0]']
#  onv2D)
#
#  activation_12 (Activation)     (None, 48, 48, 32)   0           ['separable_conv2d_6[0][0]']
#
#  activation_1 (Activation)      (None, 16, 16, 64)   0           ['separable_conv2d_1[0][0]']
#
#  activation_7 (Activation)      (None, 16, 16, 64)   0           ['separable_conv2d_4[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 32)  0           ['activation_12[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)    0           ['activation_1[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 64)    0           ['activation_7[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 16, 16, 32)  128         ['max_pooling2d_6[0][0]']
#  ormalization)
#
#  batch_normalization_1 (BatchNo  (None, 8, 8, 64)    256         ['max_pooling2d_1[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 8, 8, 64)    256         ['max_pooling2d_4[0][0]']
#  rmalization)
#
#  spatial_dropout2d_6 (SpatialDr  (None, 16, 16, 32)  0           ['batch_normalization_12[0][0]']
#  opout2D)
#
#  spatial_dropout2d_1 (SpatialDr  (None, 8, 8, 64)    0           ['batch_normalization_1[0][0]']
#  opout2D)
#
#  spatial_dropout2d_4 (SpatialDr  (None, 8, 8, 64)    0           ['batch_normalization_7[0][0]']
#  opout2D)
#
#  separable_conv2d_7 (SeparableC  (None, 16, 16, 64)  2400        ['spatial_dropout2d_6[0][0]']
#  onv2D)
#
#  separable_conv2d_2 (SeparableC  (None, 8, 8, 128)   8896        ['spatial_dropout2d_1[0][0]']
#  onv2D)
#
#  separable_conv2d_5 (SeparableC  (None, 8, 8, 128)   8896        ['spatial_dropout2d_4[0][0]']
#  onv2D)
#
#  activation_13 (Activation)     (None, 16, 16, 64)   0           ['separable_conv2d_7[0][0]']
#
#  activation_2 (Activation)      (None, 8, 8, 128)    0           ['separable_conv2d_2[0][0]']
#
#  activation_8 (Activation)      (None, 8, 8, 128)    0           ['separable_conv2d_5[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 64)    0           ['activation_13[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 4, 4, 128)   0           ['activation_2[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 128)   0           ['activation_8[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 8, 8, 64)    256         ['max_pooling2d_7[0][0]']
#  ormalization)
#
#  batch_normalization_2 (BatchNo  (None, 4, 4, 128)   512         ['max_pooling2d_2[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 4, 4, 128)   512         ['max_pooling2d_5[0][0]']
#  rmalization)
#
#  spatial_dropout2d_7 (SpatialDr  (None, 8, 8, 64)    0           ['batch_normalization_13[0][0]']
#  opout2D)
#
#  spatial_dropout2d_2 (SpatialDr  (None, 4, 4, 128)   0           ['batch_normalization_2[0][0]']
#  opout2D)
#
#  spatial_dropout2d_5 (SpatialDr  (None, 4, 4, 128)   0           ['batch_normalization_8[0][0]']
#  opout2D)
#
#  separable_conv2d_8 (SeparableC  (None, 8, 8, 128)   8896        ['spatial_dropout2d_7[0][0]']
#  onv2D)
#
#  flatten (Flatten)              (None, 2048)         0           ['spatial_dropout2d_2[0][0]']
#
#  flatten_1 (Flatten)            (None, 2048)         0           ['spatial_dropout2d_5[0][0]']
#
#  activation_14 (Activation)     (None, 8, 8, 128)    0           ['separable_conv2d_8[0][0]']
#
#  dense (Dense)                  (None, 128)          262272      ['flatten[0][0]']
#
#  dense_4 (Dense)                (None, 128)          262272      ['flatten_1[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 4, 4, 128)   0           ['activation_14[0][0]']
#
#  activation_3 (Activation)      (None, 128)          0           ['dense[0][0]']
#
#  activation_9 (Activation)      (None, 128)          0           ['dense_4[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 4, 4, 128)   512         ['max_pooling2d_8[0][0]']
#  ormalization)
#
#  dropout (Dropout)              (None, 128)          0           ['activation_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 128)          0           ['activation_9[0][0]']
#
#  spatial_dropout2d_8 (SpatialDr  (None, 4, 4, 128)   0           ['batch_normalization_14[0][0]']
#  opout2D)
#
#  batch_normalization_3 (BatchNo  (None, 128)         512         ['dropout[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 128)         512         ['dropout_3[0][0]']
#  rmalization)
#
#  flatten_2 (Flatten)            (None, 2048)         0           ['spatial_dropout2d_8[0][0]']
#
#  dense_1 (Dense)                (None, 64)           8256        ['batch_normalization_3[0][0]']
#
#  dense_5 (Dense)                (None, 64)           8256        ['batch_normalization_9[0][0]']
#
#  dense_8 (Dense)                (None, 64)           131136      ['flatten_2[0][0]']
#
#  activation_4 (Activation)      (None, 64)           0           ['dense_1[0][0]']
#
#  activation_10 (Activation)     (None, 64)           0           ['dense_5[0][0]']
#
#  activation_15 (Activation)     (None, 64)           0           ['dense_8[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['activation_4[0][0]']
#
#  dropout_4 (Dropout)            (None, 64)           0           ['activation_10[0][0]']
#
#  dropout_6 (Dropout)            (None, 64)           0           ['activation_15[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64)          256         ['dropout_1[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 64)          256         ['dropout_4[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 64)          256         ['dropout_6[0][0]']
#  ormalization)
#
#  dense_2 (Dense)                (None, 32)           2080        ['batch_normalization_4[0][0]']
#
#  dense_6 (Dense)                (None, 32)           2080        ['batch_normalization_10[0][0]']
#
#  dense_9 (Dense)                (None, 32)           2080        ['batch_normalization_15[0][0]']
#
#  activation_5 (Activation)      (None, 32)           0           ['dense_2[0][0]']
#
#  activation_11 (Activation)     (None, 32)           0           ['dense_6[0][0]']
#
#  activation_16 (Activation)     (None, 32)           0           ['dense_9[0][0]']
#
#  dropout_2 (Dropout)            (None, 32)           0           ['activation_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 32)           0           ['activation_11[0][0]']
#
#  dropout_7 (Dropout)            (None, 32)           0           ['activation_16[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32)          128         ['dropout_2[0][0]']
#  rmalization)
#
#  batch_normalization_11 (BatchN  (None, 32)          128         ['dropout_5[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 32)          128         ['dropout_7[0][0]']
#  ormalization)
#
#  dense_3 (Dense)                (None, 5)            165         ['batch_normalization_5[0][0]']
#
#  dense_7 (Dense)                (None, 5)            165         ['batch_normalization_11[0][0]']
#
#  dense_10 (Dense)               (None, 2)            66          ['batch_normalization_16[0][0]']
#
#  age (Activation)               (None, 5)            0           ['dense_3[0][0]']
#
#  race (Activation)              (None, 5)            0           ['dense_7[0][0]']
#
#  gender (Activation)            (None, 2)            0           ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 718,045
# Trainable params: 715,613
# Non-trainable params: 2,432
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training the model

# %%
from keras.metrics import AUC
import math
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint
from keras.callbacks import LearningRateScheduler

# Source: https://neptune.ai/blog/keras-metrics
init_lr = 1e-4
epochs = 100
#opt = Adam(learning_rate=0.0) # 0.0 means not to be used here.
opt = Adam(learning_rate=init_lr, decay=init_lr/epochs)
#pt = SGD(learning_rate=init_lr, momentum=0.9)
model.compile(optimizer= opt,  # 'rmsprop',
              loss={
                  'age': 'categorical_crossentropy',
                  'race': 'categorical_crossentropy',
                  'gender': 'binary_crossentropy'},
              loss_weights={
                  'age': 1.5,
                  'race': 1.5,
                  'gender': 0.1},
              metrics={
                  'age': ['accuracy', AUC(curve="ROC")],
                  'race': ['accuracy', AUC(curve="ROC")],
                  'gender': ['accuracy', AUC(curve="ROC")]})

# %%
# class_weight in Keras: To ensure the unevenness in data distribution (as in age) is sorted out by giving the classes with fewer numbers is assigned more
# weight to prevent being biased against prevalent classes.
from sklearn.utils import class_weight

class_weight = class_weight.compute_class_weight('balanced',
                                                 classes=np.array([0,1,2,3,4]),
                                                 y=np.array(df['age']))

class_weight1 = {'age': class_weight}

# %%
# To generate batches for train_idx to be able to prevent "too large to fit inside RAM at once so-called memory errors".
# Soource: https://www.codementor.io/@alexander-k/keras-training-earlystopping-callback-to-avoid-overfitting-1ehrjlx8kw

import sys
import math
import keras
from datetime import datetime
import datetime
import time
import os
from django.utils.datetime_safe import datetime
from keras.callbacks import EarlyStopping
from livelossplot import PlotLossesKeras
plt.style.use('ggplot')
from sklearn.preprocessing import LabelBinarizer
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler

# CALLBACKS

# Exponential_decay() or step_decay() functions alternatively can be used for dynamic learning rate
#----------------------------------------------------------------------------------------------------------------------------------------------
# Learning Rate Schedules in Keras reduces the learning rate by a certain factor after certain no of epochs

#Source:    (https://towardsdatascience.com/learning-rate-schedules-and-adaptive-learning-rate-methods-for-deep-learning-2c8f433990d1)
#           (https://sanjayasubedi.com.np/deeplearning/multioutput-keras/)
#           (https://github.com/sukilau/Ziff-deep-learning/blob/master/3-CIFAR10-lrate/CIFAR10-lrate.ipynb)

# According ot several sources (few example of it above), since the learning rate is the most important
# hyperparameter to tune the training in a neural network, it is stated that to reduce learning rate as the training progresses,
# is a good practice for a better outcome (accuracy).

# Exponential Decay
# def exp_decay(epoch):
#    initial_lrate = 0.001
#    k = 0.2
#    lrate = initial_lrate * np.exp(-k * epoch)  # lr, k are hyperparameters and t=epoch is the iteration number
#    return lrate

# Step Decay, to drop the learning rate by a factor every few epochs.
# def step_decay(epoch):
# 	initial_lrate = 0.008
# 	drop = 0.7              # % drop rate
# 	epochs_drop = 10.0      # To drop after every number of epoch
# 	lrate = initial_lrate * math.pow(drop, math.floor((1 + epoch) / epochs_drop)) #Fromula for step_decay
# 	return lrate

# Source: (https://datascience.stackexchange.com/questions/42599/what-is-the-relationship-between-the-accuracy-and-the-loss-in-deep-learning)
# a low accuracy and huge loss means you made huge errors on a lot of data
# a low accuracy but low loss means you made little errors on a lot of data
# a great accuracy with low loss means you made low errors on a few data (best case)

#lrate = LearningRateScheduler(step_decay)       # At the beginning of every epoch, this callback gets the updated learning rate value
#lrate = LearningRateScheduler(exp_decay)

# `binary_crossentropy`, sigmoid activation, scalar target.
# `categorical_crossentropy`, softmax activation, one-hot encoded target.

# It is this callback that allows a function to invoke during program execution.
#callbacks_list = [lrate]
#----------------------------------------------------------------------------------------------------------------------------------------

# To measure the time for the traiing session
start = datetime.now()

filepath = "../ModelTrainingService/models/CNN_Dec260151.hdf5"
checkpoint = ModelCheckpoint(filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True,
                             mode='max')

monitor_val_acc = [EarlyStopping(monitor = 'val_loss',
                                min_delta = 0,
                                patience = 10,
                                verbose = 1,
                                mode='max',
                                restore_best_weights = True)]

#callbacks_list = [PlotLossesKeras(), monitor_val_acc, checkpoint]


# Training and validation batches
batch_size = 32
train_gen = data_generator.generate_images(train_idx,
                                           is_training=True,
                                           batch_size=batch_size)

valid_gen = data_generator.generate_images(valid_idx,
                                           is_training=True,
                                           batch_size=batch_size)

# fit() as known fit_generator() before 2020: Validation while training the model to evaluate the loss.
history = model.fit(train_gen,
                    steps_per_epoch=len(train_idx)//batch_size,
                    epochs=epochs,
                    #callbacks=callbacks_list,
                    validation_data=valid_gen,
                    validation_steps=len(valid_idx)//batch_size,
                    verbose=1)

#Training time
end = datetime.now()
elapsed = end-start
print ('\nElapsed Time: ', elapsed)
# Out:
# Epoch 1/100
# 474/474 [==============================] - 36s 52ms/step - loss: 5.7057 - age_loss: 1.9386 - race_loss: 1.8157 - gender_loss: 0.7417 - age_accuracy: 0.2753 - age_auc: 0.5747 - race_accuracy: 0.2831 - race_auc_1: 0.5865 - gender_accuracy: 0.6192 - gender_auc_2: 0.6396 - val_loss: 4.4576 - val_age_loss: 1.4833 - val_race_loss: 1.4439 - val_gender_loss: 0.6689 - val_age_accuracy: 0.1764 - val_age_auc: 0.7044 - val_race_accuracy: 0.4266 - val_race_auc_1: 0.6955 - val_gender_accuracy: 0.6806 - val_gender_auc_2: 0.7183
# Epoch 12/100
# 474/474 [==============================] - 25s 53ms/step - loss: 3.2051 - age_loss: 0.9314 - race_loss: 1.1794 - gender_loss: 0.3900 - age_accuracy: 0.6203 - age_auc: 0.8881 - race_accuracy: 0.5531 - race_auc_1: 0.8190 - gender_accuracy: 0.8236 - gender_auc_2: 0.9055 - val_loss: 2.7926 - val_age_loss: 0.8206 - val_race_loss: 1.0189 - val_gender_loss: 0.3343 - val_age_accuracy: 0.6629 - val_age_auc: 0.9135 - val_race_accuracy: 0.6104 - val_race_auc_1: 0.8673 - val_gender_accuracy: 0.8528 - val_gender_auc_2: 0.9330
# Epoch 13/100
# 474/474 [==============================] - 24s 50ms/step - loss: 3.1426 - age_loss: 0.9207 - race_loss: 1.1489 - gender_loss: 0.3818 - age_accuracy: 0.6194 - age_auc: 0.8899 - race_accuracy: 0.5647 - race_auc_1: 0.8282 - gender_accuracy: 0.8289 - gender_auc_2: 0.9098 - val_loss: 2.7246 - val_age_loss: 0.8079 - val_race_loss: 0.9869 - val_gender_loss: 0.3251 - val_age_accuracy: 0.6668 - val_age_auc: 0.9156 - val_race_accuracy: 0.6279 - val_race_auc_1: 0.8759 - val_gender_accuracy: 0.8554 - val_gender_auc_2: 0.9369
# Epoch 14/100
# 474/474 [==============================] - 26s 55ms/step - loss: 3.0713 - age_loss: 0.9044 - race_loss: 1.1182 - gender_loss: 0.3735 - age_accuracy: 0.6280 - age_auc: 0.8937 - race_accuracy: 0.5805 - race_auc_1: 0.8386 - gender_accuracy: 0.8335 - gender_auc_2: 0.9138 - val_loss: 2.6628 - val_age_loss: 0.8022 - val_race_loss: 0.9514 - val_gender_loss: 0.3229 - val_age_accuracy: 0.6695 - val_age_auc: 0.9168 - val_race_accuracy: 0.6465 - val_race_auc_1: 0.8852 - val_gender_accuracy: 0.8549 - val_gender_auc_2: 0.9374
# Epoch 15/100
# 474/474 [==============================] - 25s 53ms/step - loss: 3.0162 - age_loss: 0.8899 - race_loss: 1.0964 - gender_loss: 0.3667 - age_accuracy: 0.6261 - age_auc: 0.8967 - race_accuracy: 0.5939 - race_auc_1: 0.8448 - gender_accuracy: 0.8347 - gender_auc_2: 0.9167 - val_loss: 2.6012 - val_age_loss: 0.7840 - val_race_loss: 0.9286 - val_gender_loss: 0.3247 - val_age_accuracy: 0.6772 - val_age_auc: 0.9200 - val_race_accuracy: 0.6570 - val_race_auc_1: 0.8906 - val_gender_accuracy: 0.8567 - val_gender_auc_2: 0.9376
# Epoch 16/100
# 474/474 [==============================] - 26s 55ms/step - loss: 2
100
# 474/474 [==============================] - 25s 53ms/step - loss: 2.7077 - age_loss: 0.8136 - race_loss: 0.9692 - gender_loss: 0.3352 - age_accuracy: 0.6593 - age_auc: 0.9128 - race_accuracy: 0.6501 - race_auc_1: 0.8799 - gender_accuracy: 0.8508 - gender_auc_2: 0.9310 - val_loss: 2.3637 - val_age_loss: 0.7290 - val_race_loss: 0.8267 - val_gender_loss: 0.3012 - val_age_accuracy: 0.6949 - val_age_auc: 0.9297 - val_race_accuracy: 0.7023 - val_race_auc_1: 0.9136 - val_gender_accuracy: 0.8655 - val_gender_auc_2: 0.9466
# Epoch 23/100
# 474/474 [==============================] - 26s 55ms/step - loss: 2.6669 - age_loss: 0.8104 - race_loss: 0.9453 - gender_loss: 0.3339 - age_accuracy: 0.6561 - age_auc: 0.9131 - race_accuracy: 0.6589 - race_auc_1: 0.8858 - gender_accuracy: 0.8491 - gender_auc_2: 0.9313 - val_loss: 2.3482 - val_age_loss: 0.7240 - val_race_loss: 0.8218 - val_gender_loss: 0.2952 - val_age_accuracy: 0.6947 - val_age_auc: 0.9306 - val_race_accuracy: 0.7031 - val_race_auc_1: 0.9147 - val_gender_accuracy: 0.8713 - val_gender_auc_2: 0.9482
# Epoch 24/100
# 474/474 [==============================] - 26s 54ms/step - loss: 2.6368 - age_loss: 0.7988 - race_loss: 0.9372 - gender_loss: 0.3281 - age_accuracy: 0.6627 - age_auc: 0.9155 - race_accuracy: 0.6647 - race_auc_1: 0.8880 - gender_accuracy: 0.8534 - gender_auc_2: 0.9341 - val_loss: 2.3201 - val_age_loss: 0.7178 - val_race_loss: 0.8092 - val_gender_loss: 0.2970 - val_age_accuracy: 0.6949 - val_age_auc: 0.9314 - val_race_accuracy: 0.7047 - val_race_auc_1: 0.9175 - val_gender_accuracy: 0.8705 - val_gender_auc_2: 0.9483
# Epoch 25/100
# 474/474 [==============================] - 26s 54ms/step - loss: 2.6386 - age_loss: 0.8039 - race_loss: 0.9341 - gender_loss: 0.3167 - age_accuracy: 0.6661 - age_auc: 0.9146 - race_accuracy: 0.6693 - race_auc_1: 0.8885 - gender_accuracy: 0.8606 - gender_auc_2: 0.9385 - val_loss: 2.3049 - val_age_loss: 0.7122 - val_race_loss: 0.8045 - val_gender_loss: 0.2975 - val_age_accuracy: 0.6999 - val_age_auc: 0.9327 - val_race_accuracy: 0.7113 - val_race_auc_1: 0.9186 - val_gender_accuracy: 0.8686 - val_gender_auc_2: 0.9483
# Epoch 26/100
# 474/474 [==============================] - 26s 54ms/step - loss: 2.6051 - age_loss: 0.7867 - race_loss: 0.9289 - gender_loss: 0.3177 - age_accuracy: 0.6697 - age_auc: 0.9179 - race_accuracy: 0.6674 - race_auc_1: 0.8898 - gender_accuracy: 0.8597 - gender_auc_2: 0.9381 - val_loss: 2.2943 - val_age_loss: 0.7118 - val_race_loss: 0.7985 - val_gender_loss: 0.2889 - val_age_accuracy: 0.6978 - val_age_auc: 0.9322 - val_race_accuracy: 0.7119 - val_race_auc_1: 0.9199 - val_gender_accuracy: 0.8724 - val_gender_auc_2: 0.9507
# Epoch 27/100
100
# 474/474 [==============================] - 26s 54ms/step - loss: 2.4075 - age_loss: 0.7403 - race_loss: 0.8455 - gender_loss: 0.2882 - age_accuracy: 0.6829 - age_auc: 0.9266 - race_accuracy: 0.7060 - race_auc_1: 0.9088 - gender_accuracy: 0.8734 - gender_auc_2: 0.9492 - val_loss: 2.1589 - val_age_loss: 0.6781 - val_race_loss: 0.7420 - val_gender_loss: 0.2873 - val_age_accuracy: 0.7092 - val_age_auc: 0.9380 - val_race_accuracy: 0.7338 - val_race_auc_1: 0.9310 - val_gender_accuracy: 0.8750 - val_gender_auc_2: 0.9527
# Epoch 38/100
# 474/474 [==============================] - 25s 53ms/step - loss: 2.3976 - age_loss: 0.7358 - race_loss: 0.8430 - gender_loss: 0.2953 - age_accuracy: 0.6891 - age_auc: 0.9274 - race_accuracy: 0.7046 - race_auc_1: 0.9094 - gender_accuracy: 0.8712 - gender_auc_2: 0.9469 - val_loss: 2.1715 - val_age_loss: 0.6800 - val_race_loss: 0.7490 - val_gender_loss: 0.2794 - val_age_accuracy: 0.7105 - val_age_auc: 0.9377 - val_race_accuracy: 0.7360 - val_race_auc_1: 0.9300 - val_gender_accuracy: 0.8795 - val_gender_auc_2: 0.9544
# Epoch 39/100
# 474/474 [==============================] - 25s 53ms/step - loss: 2.3791 - age_loss: 0.7292 - race_loss: 0.8374 - gender_loss: 0.2931 - age_accuracy: 0.6891 - age_auc: 0.9285 - race_accuracy: 0.7040 - race_auc_1: 0.9107 - gender_accuracy: 0.8712 - gender_auc_2: 0.9474 - val_loss: 2.1534 - val_age_loss: 0.6766 - val_race_loss: 0.7408 - val_gender_loss: 0.2732 - val_age_accuracy: 0.7135 - val_age_auc: 0.9381 - val_race_accuracy: 0.7383 - val_race_auc_1: 0.9313 - val_gender_accuracy: 0.8814 - val_gender_auc_2: 0.9556
# Epoch 40/100
# 474/474 [==============================] - 25s 54ms/step - loss: 2.3691 - age_loss: 0.7236 - race_loss: 0.8366 - gender_loss: 0.2878 - age_accuracy: 0.6942 - age_auc: 0.9297 - race_accuracy: 0.7068 - race_auc_1: 0.9106 - gender_accuracy: 0.8733 - gender_auc_2: 0.9494 - val_loss: 2.1459 - val_age_loss: 0.6742 - val_race_loss: 0.7380 - val_gender_loss: 0.2771 - val_age_accuracy: 0.7148 - val_age_auc: 0.9388 - val_race_accuracy: 0.7399 - val_race_auc_1: 0.9318 - val_gender_accuracy: 0.8824 - val_gender_auc_2: 0.9548
# Epoch 41/100
# 474/474 [==============================] - 54s 115ms/step - loss: 2.3408 - age_loss: 0.7152 - race_loss: 0.8264 - gender_loss: 0.2841 - age_accuracy: 0.6928 - age_auc: 0.9312 - race_accuracy: 0.7085 - race_auc_1: 0.9131 - gender_accuracy: 0.8784 - gender_auc_2: 0.9508 - val_loss: 2.1323 - val_age_loss: 0.6737 - val_race_loss: 0.7295 - val_gender_loss: 0.2745 - val_age_accuracy: 0.7161 - val_age_auc: 0.9387 - val_race_accuracy: 0.7410 - val_race_auc_1: 0.9331 - val_gender_accuracy: 0.8840 - val_gender_auc_2: 0.9561
# Epoch 42/100
# 474/474 [==============================] - 27s 56ms/step - loss: 2.0274 - age_loss: 0.6343 - race_loss: 0.7016 - gender_loss: 0.2367 - age_accuracy: 0.7307 - age_auc: 0.9450 - race_accuracy: 0.7568 - race_auc_1: 0.9370 - gender_accuracy: 0.8984 - gender_auc_2: 0.9659 - val_loss: 1.9784 - val_age_loss: 0.6398 - val_race_loss: 0.6617 - val_gender_loss: 0.2615 - val_age_accuracy: 0.7272 - val_age_auc: 0.9442 - val_race_accuracy: 0.7715 - val_race_auc_1: 0.9448 - val_gender_accuracy: 0.8919 - val_gender_auc_2: 0.9613
# Epoch 78/100
# 474/474 [==============================] - 27s 56ms/step - loss: 2.0171 - age_loss: 0.6337 - race_loss: 0.6955 - gender_loss: 0.2335 - age_accuracy: 0.7314 - age_auc: 0.9449 - race_accuracy: 0.7576 - race_auc_1: 0.9381 - gender_accuracy: 0.9030 - gender_auc_2: 0.9668 - val_loss: 1.9725 - val_age_loss: 0.6367 - val_race_loss: 0.6609 - val_gender_loss: 0.2611 - val_age_accuracy: 0.7331 - val_age_auc: 0.9447 - val_race_accuracy: 0.7725 - val_race_auc_1: 0.9450 - val_gender_accuracy: 0.8901 - val_gender_auc_2: 0.9613
# Epoch 79/100
# 474/474 [==============================] - 26s 55ms/step - loss: 1.9929 - age_loss: 0.6331 - race_loss: 0.6794 - gender_loss: 0.2409 - age_accuracy: 0.7349 - age_auc: 0.9451 - race_accuracy: 0.7607 - race_auc_1: 0.9410 - gender_accuracy: 0.8976 - gender_auc_2: 0.9646 - val_loss: 1.9746 - val_age_loss: 0.6379 - val_race_loss: 0.6608 - val_gender_loss: 0.2659 - val_age_accuracy: 0.7352 - val_age_auc: 0.9447 - val_race_accuracy: 0.7701 - val_race_auc_1: 0.9450 - val_gender_accuracy: 0.8880 - val_gender_auc_2: 0.9599
# Epoch 80/100
# 474/474 [==============================] - 26s 55ms/step - loss: 1.9976 - age_loss: 0.6263 - race_loss: 0.6900 - gender_loss: 0.2325 - age_accuracy: 0.7383 - age_auc: 0.9464 - race_accuracy: 0.7618 - race_auc_1: 0.9390 - gender_accuracy: 0.9022 - gender_auc_2: 0.9672 - val_loss: 1.9612 - val_age_loss: 0.6345 - val_race_loss: 0.6555 - val_gender_loss: 0.2605 - val_age_accuracy: 0.7333 - val_age_auc: 0.9453 - val_race_accuracy: 0.7767 - val_race_auc_1: 0.9459 - val_gender_accuracy: 0.8912 - val_gender_auc_2: 0.9613
# Epoch 81/100
# 474/474 [==============================] - 28s 58ms/step - loss: 2.0064 - age_loss: 0.6287 - race_loss: 0.6934 - gender_loss: 0.2320 - age_accuracy: 0.7314 - age_auc: 0.9457 - race_accuracy: 0.7588 - race_auc_1: 0.9385 - gender_accuracy: 0.9017 - gender_auc_2: 0.9672 - val_loss: 1.9686 - val_age_loss: 0.6348 - val_race_loss: 0.6604 - val_gender_loss: 0.2580 - val_age_accuracy: 0.7344 - val_age_auc: 0.9452 - val_race_accuracy: 0.7741 - val_race_auc_1: 0.9451 - val_gender_accuracy: 0.8925 - val_gender_auc_2: 0.9621
# Epoch 82/100
# 474/474 [==============================] - 26s 55ms/step - loss: 2.0020 - age_loss: 0.6274 - race_loss: 0.6916 - gender_loss: 0.2342 - age_accuracy: 0.7328 - age_auc: 0.9459 - race_accuracy: 0.7573 - race_auc_1: 0.9389 - gender_accuracy: 0.9015 - gender_auc_2: 0.9666 - val_loss: 1.9656 - val_age_loss: 0.6315 - val_race_loss: 0.6616 - val_gender_loss: 0.2594 - val_age_accuracy: 0.7341 - val_age_auc: 0.9456 - val_race_accuracy: 0.7738 - val_race_auc_1: 0.9449 - val_gender_accuracy: 0.8938 - val_gender_auc_2: 0.9617
# Epoch 83/100
# 474/474 [==============================] - 26s 55ms/step - loss: 1.9910 - age_loss: 0.6282 - race_loss: 0.6839 - gender_loss: 0.2285 - age_accuracy: 0.7321 - age_auc: 0.9458 - race_accuracy: 0.7631 - race_auc_1: 0.9401 - gender_accuracy: 0.9028 - gender_auc_2: 0.9681 - val_loss: 1.9716 - val_age_loss: 0.6398 - val_race_loss: 0.6577 - val_gender_loss: 0.2537 - val_age_accuracy: 0.7331 - val_age_auc: 0.9444 - val_race_accuracy: 0.7744 - val_race_auc_1: 0.9454 - val_gender_accuracy: 0.8951 - val_gender_auc_2: 0.9632
# Epoch 84/100
# 474/474 [==============================] - 49s 103ms/step - loss: 1.9762 - age_loss: 0.6276 - race_loss: 0.6747 - gender_loss: 0.2278 - age_accuracy: 0.7343 - age_auc: 0.9462 - race_accuracy: 0.7634 - race_auc_1: 0.9417 - gender_accuracy: 0.9039 - gender_auc_2: 0.9684 - val_loss: 1.9700 - val_age_loss: 0.6384 - val_race_loss: 0.6578 - val_gender_loss: 0.2571 - val_age_accuracy: 0.7336 - val_age_auc: 0.9446 - val_race_accuracy: 0.7715 - val_race_auc_1: 0.9455 - val_gender_accuracy: 0.8912 - val_gender_auc_2: 0.9622
# Epoch 85/100
# 474/474 [==============================] - 50s 106ms/step - loss: 1.9789 - age_loss: 0.6302 - race_loss: 0.6736 - gender_loss: 0.2318 - age_accuracy: 0.7344 - age_auc: 0.9458 - race_accuracy: 0.7655 - race_auc_1: 0.9421 - gender_accuracy: 0.9030 - gender_auc_2: 0.9672 - val_loss: 1.9628 - val_age_loss: 0.6346 - val_race_loss: 0.6566 - val_gender_loss: 0.2598 - val_age_accuracy: 0.7325 - val_age_auc: 0.9452 - val_race_accuracy: 0.7707 - val_race_auc_1: 0.9458 - val_gender_accuracy: 0.8927 - val_gender_auc_2: 0.9617
# Epoch 86/100
# 474/474 [==============================] - 58s 122ms/step - loss: 1.9719 - age_loss: 0.6221 - race_loss: 0.6771 - gender_loss: 0.2308 - age_accuracy: 0.7372 - age_auc: 0.9472 - race_accuracy: 0.7629 - race_auc_1: 0.9414 - gender_accuracy: 0.8997 - gender_auc_2: 0.9675 - val_loss: 1.9541 - val_age_loss: 0.6316 - val_race_loss: 0.6537 - val_gender_loss: 0.2608 - val_age_accuracy: 0.7344 - val_age_auc: 0.9456 - val_race_accuracy: 0.7738 - val_race_auc_1: 0.9463 - val_gender_accuracy: 0.8922 - val_gender_auc_2: 0.9610
# Epoch 87/100
# Epoch 92/100
# 474/474 [==============================] - 28s 58ms/step - loss: 1.9302 - age_loss: 0.6130 - race_loss: 0.6590 - gender_loss: 0.2228 - age_accuracy: 0.7431 - age_auc: 0.9486 - race_accuracy: 0.7702 - race_auc_1: 0.9444 - gender_accuracy: 0.9059 - gender_auc_2: 0.9698 - val_loss: 1.9544 - val_age_loss: 0.6354 - val_race_loss: 0.6501 - val_gender_loss: 0.2614 - val_age_accuracy: 0.7357 - val_age_auc: 0.9451 - val_race_accuracy: 0.7775 - val_race_auc_1: 0.9471 - val_gender_accuracy: 0.8898 - val_gender_auc_2: 0.9614
# Epoch 93/100
# 474/474 [==============================] - 27s 57ms/step - loss: 1.9128 - age_loss: 0.6037 - race_loss: 0.6569 - gender_loss: 0.2187 - age_accuracy: 0.7447 - age_auc: 0.9500 - race_accuracy: 0.7713 - race_auc_1: 0.9447 - gender_accuracy: 0.9061 - gender_auc_2: 0.9709 - val_loss: 1.9473 - val_age_loss: 0.6373 - val_race_loss: 0.6436 - val_gender_loss: 0.2593 - val_age_accuracy: 0.7338 - val_age_auc: 0.9448 - val_race_accuracy: 0.7757 - val_race_auc_1: 0.9480 - val_gender_accuracy: 0.8919 - val_gender_auc_2: 0.9619
# Epoch 94/100
# 474/474 [==============================] - 27s 57ms/step - loss: 1.9176 - age_loss: 0.6108 - race_loss: 0.6526 - gender_loss: 0.2239 - age_accuracy: 0.7399 - age_auc: 0.9488 - race_accuracy: 0.7722 - race_auc_1: 0.9455 - gender_accuracy: 0.9077 - gender_auc_2: 0.9695 - val_loss: 1.9452 - val_age_loss: 0.6314 - val_race_loss: 0.6473 - val_gender_loss: 0.2713 - val_age_accuracy: 0.7360 - val_age_auc: 0.9457 - val_race_accuracy: 0.7762 - val_race_auc_1: 0.9477 - val_gender_accuracy: 0.8859 - val_gender_auc_2: 0.9597
# Epoch 95/100
# 474/474 [==============================] - 27s 56ms/step - loss: 1.9200 - age_loss: 0.6077 - race_loss: 0.6573 - gender_loss: 0.2235 - age_accuracy: 0.7439 - age_auc: 0.9495 - race_accuracy: 0.7690 - race_auc_1: 0.9447 - gender_accuracy: 0.9053 - gender_auc_2: 0.9696 - val_loss: 1.9551 - val_age_loss: 0.6332 - val_race_loss: 0.6525 - val_gender_loss: 0.2650 - val_age_accuracy: 0.7346 - val_age_auc: 0.9454 - val_race_accuracy: 0.7749 - val_race_auc_1: 0.9469 - val_gender_accuracy: 0.8898 - val_gender_auc_2: 0.9609
# Epoch 96/100
# 474/474 [==============================] - 27s 57ms/step - loss: 1.9100 - age_loss: 0.6085 - race_loss: 0.6502 - gender_loss: 0.2195 - age_accuracy: 0.7431 - age_auc: 0.9492 - race_accuracy: 0.7739 - race_auc_1: 0.9458 - gender_accuracy: 0.9091 - gender_auc_2: 0.9707 - val_loss: 1.9520 - val_age_loss: 0.6335 - val_race_loss: 0.6503 - val_gender_loss: 0.2638 - val_age_accuracy: 0.7323 - val_age_auc: 0.9452 - val_race_accuracy: 0.7786 - val_race_auc_1: 0.9473 - val_gender_accuracy: 0.8927 - val_gender_auc_2: 0.9612
# Epoch 97/100
# 474/474 [==============================] - 27s 56ms/step - loss: 1.9145 - age_loss: 0.6077 - race_loss: 0.6541 - gender_loss: 0.2178 - age_accuracy: 0.7420 - age_auc: 0.9493 - race_accuracy: 0.7737 - race_auc_1: 0.9451 - gender_accuracy: 0.9092 - gender_auc_2: 0.9711 - val_loss: 1.9454 - val_age_loss: 0.6323 - val_race_loss: 0.6473 - val_gender_loss: 0.2597 - val_age_accuracy: 0.7309 - val_age_auc: 0.9454 - val_race_accuracy: 0.7775 - val_race_auc_1: 0.9477 - val_gender_accuracy: 0.8914 - val_gender_auc_2: 0.9620
# Epoch 98/100
# 474/474 [==============================] - 27s 57ms/step - loss: 1.8900 - age_loss: 0.6041 - race_loss: 0.6409 - gender_loss: 0.2242 - age_accuracy: 0.7400 - age_auc: 0.9498 - race_accuracy: 0.7735 - race_auc_1: 0.9474 - gender_accuracy: 0.9076 - gender_auc_2: 0.9693 - val_loss: 1.9414 - val_age_loss: 0.6301 - val_race_loss: 0.6469 - val_gender_loss: 0.2589 - val_age_accuracy: 0.7362 - val_age_auc: 0.9459 - val_race_accuracy: 0.7760 - val_race_auc_1: 0.9481 - val_gender_accuracy: 0.8922 - val_gender_auc_2: 0.9623
# Epoch 99/100
# 474/474 [==============================] - 28s 58ms/step - loss: 1.8947 - age_loss: 0.6046 - race_loss: 0.6443 - gender_loss: 0.2146 - age_accuracy: 0.7389 - age_auc: 0.9496 - race_accuracy: 0.7733 - race_auc_1: 0.9468 - gender_accuracy: 0.9113 - gender_auc_2: 0.9719 - val_loss: 1.9366 - val_age_loss: 0.6311 - val_race_loss: 0.6428 - val_gender_loss: 0.2570 - val_age_accuracy: 0.7323 - val_age_auc: 0.9456 - val_race_accuracy: 0.7760 - val_race_auc_1: 0.9481 - val_gender_accuracy: 0.8938 - val_gender_auc_2: 0.9627
# Epoch 100/100
# 474/474 [==============================] - 27s 57ms/step - loss: 1.8716 - age_loss: 0.5950 - race_loss: 0.6387 - gender_loss: 0.2107 - age_accuracy: 0.7513 - age_auc: 0.9514 - race_accuracy: 0.7752 - race_auc_1: 0.9478 - gender_accuracy: 0.9105 - gender_auc_2: 0.9730 - val_loss: 1.9506 - val_age_loss: 0.6350 - val_race_loss: 0.6482 - val_gender_loss: 0.2584 - val_age_accuracy: 0.7331 - val_age_auc: 0.9451 - val_race_accuracy: 0.7730 - val_race_auc_1: 0.9478 - val_gender_accuracy: 0.8943 - val_gender_auc_2: 0.9626
#
# Elapsed Time:  0:54:18.559140

# %%
# save the model to disk
#Source: (https://www.tensorflow.org/api_docs/python/tf/keras/models/save_model)
# Save the entire model as a SavedModel.

# save(): To create a SavedModel folder `saved_model`, containing "assets", "saved_model.pb" & "variables".
# The model architecture, and training configuration (including the optimizer, losses, and metrics) are stored in `saved_model.pb`.
# The weights are saved in the `variables/` directory.
# path = "../models/saved_model/latest_model"

#model.save('../models/saved_model/latest_model/you_model_name.tf')

f_name = r'CNN-model-'
f_time = datetime.now().strftime("%Y-%m-%d_%I-%M-%S_%p")
file = f_name + f_time + '.h5'
filepath = '../ModelTrainingService/models/' + file
model.save(filepath, include_optimizer=True)
print("[INFO] Model \"%s\" saved (Saving into the path takes few minutes)." % file)
# Out:
# [INFO] Model "CNN-model-2023-01-01_02-55-26_AM.h5" saved (Saving into the path takes few minutes).

# %%
# Load the latest trained model
from keras.models import load_model

#loaded_model = load_model('../models/saved_model/latest_model')
#loaded_model = load_model('../models/saved_model/latest_model/you_model_name.tf')
loaded_model = load_model(filepath, compile=False)
print("[INFO] Model \"%s\" loaded" % file)
# Out:
# [INFO] Model "CNN-model-2023-01-01_02-55-26_AM.h5" loaded

# %%
# Predict the age group and the gender of the person from aligned & cropped profile face picture.

from keras.preprocessing import image
from keras.utils import load_img
from keras.preprocessing.image import ImageDataGenerator

# Load the image and size it.
def loadImage(filepath):
  test_img = load_img(filepath, target_size=(image_width, image_height, 3))
  test_img = img_to_array(test_img) # To convert a loaded image in PIL format into a NumPy array for use with deep learning models.
  test_img /= 255
  test_img = np.expand_dims(test_img, axis = 0)

  return test_img

import random as rn
from PIL import Image, ImageFont

# To choose image randomly from dataset
path=df['file']
picture = rn.choice(path)

#picture='../models/test_img/kenny-rogers.jpg' # Change the path for other image files if you would like to see more.
age_prediction, race_prediction, gender_prediction = loaded_model.predict(loadImage(picture))

print('Age_prediction: ', (age_prediction * 100), '%')
print('Race_prediction: ', (race_prediction * 100), '%')
print('Gender_prediction: ', (gender_prediction * 100), '%')
print(picture)

img = load_img(picture)
plt.imshow(img)
plt.show()
max = -1
count = 0

for i in age_prediction[0]:
    if i > max:
        max = i
        temp = count
    count+=1

#Conditions for outputs
if temp == 0:
    print('0-24 yrs old')
if temp == 1:
    print('25-49 yrs old')
if temp == 2:
    print('50-74 yrs old')
if temp == 3:
    print('75-99 yrs old')
if temp == 4:
    print('100-124 yrs old')

if gender_prediction[0][0] > gender_prediction[0][1]:
  print('Male')
else:
  print('Female')
# Out:
# 1/1 [==============================] - 0s 27ms/step
# Age_prediction:  [[2.1210759e+00 6.1607475e+01 3.4577461e+01 1.6699225e+00 2.4069183e-02]] %
# Race_prediction:  [[89.29267     0.36522964  1.506298    2.4806044   6.3551946 ]] %
# Gender_prediction:  [[92.87312   6.881996]] %
# ../ModelTrainingService/input/utkface-new/UTKFace\31_0_4_20170120133240958.jpg.chip.jpg
# 25-49 yrs old
# Male

# %% [markdown]
# ## Evaluating our model on the validation and test dataset

# %%
# To returns the loss value & metric values for the model in test dataset
test_batch_size = 128
test_generator = data_generator.generate_images(test_idx,
                                                is_training=False,
                                                batch_size=test_batch_size)

age_pred, race_pred, gender_pred = model.predict(test_generator,
                                                 steps=len(test_idx)//test_batch_size)
# print('Age_on_test: ', len(age_pred))
# print('Gender_on_test: ', len(gender_pred))
# print('Race_on_test: ', len(race_pred))
# Out:
# 37/37 [==============================] - 9s 232ms/step

# %%
test_batch_size = 128

test_generator  = data_generator.generate_images(test_idx,
                                                is_training=False,
                                                batch_size=test_batch_size)

images, age_true, race_true, gender_true = [], [], [], []

for test_batch in test_generator:
    image = test_batch[0]
    labels = test_batch[1]

    images.extend(image)
    age_true.extend(labels[0])
    race_true.extend(labels[1])
    gender_true.extend(labels[2])

age_true = np.array(age_true)
race_true = np.array(race_true)
gender_true = np.array(gender_true)

race_true, gender_true = race_true.argmax(axis=-1), gender_true.argmax(axis=-1)
race_pred, gender_pred = race_pred.argmax(axis=-1), gender_pred.argmax(axis=-1)

age_true = age_true.argmax(axis=-1) # * data_generator.max_age
age_pred = age_pred.argmax(axis=-1) # * data_generator.max_age

# %%
# Evaluate the model on test data
test_gen = data_generator.generate_images(test_idx,
                                           is_training=True,
                                           batch_size=32)

test_results = {}
test_scores = model.evaluate(test_gen, steps=4742, verbose=1, batch_size=32)
print('\nEvaluation results on test dataset...')
dict(zip(model.metrics_names, test_scores))
# test_results = dict(zip(model.metrics_names, val_scores))
# print('\n')
# for key, value in test_results.items():
#   print("%s: %s" % (key, round(value*100, 2)), '%')
# Out:
# 4742/4742 [==============================] - 301s 63ms/step - loss: 1.9124 - age_loss: 0.6167 - race_loss: 0.6416 - gender_loss: 0.2497 - age_accuracy: 0.7379 - age_auc: 0.9474 - race_accuracy: 0.7819 - race_auc_1: 0.9480 - gender_accuracy: 0.8990 - gender_auc_2: 0.9644
#
# Evaluation results on test dataset...
# {'loss': 1.9124205112457275,
#  'age_loss': 0.6167306900024414,
#  'race_loss': 0.6415722966194153,
#  'gender_loss': 0.2496822625398636,
#  'age_accuracy': 0.7378743290901184,
#  'age_auc': 0.9473942518234253,
#  'race_accuracy': 0.7819485664367676,
#  'race_auc_1': 0.9480165243148804,
#  'gender_accuracy': 0.8989877700805664,
#  'gender_auc_2': 0.9643920063972473}

# %%
# Classification report for gender feature
from sklearn.metrics import classification_report, confusion_matrix
print('Classification Report for "Gender"\n')
classification_report_gender = classification_report(gender_true, gender_pred, target_names=dataset_dict['gender_temp'].keys(), zero_division=0)
print(classification_report_gender)
# Out:
# Classification Report for "Gender"
#
#               precision    recall  f1-score   support
#
#         male       0.92      0.88      0.90      2480
#       female       0.88      0.92      0.90      2256
#
#     accuracy                           0.90      4736
#    macro avg       0.90      0.90      0.90      4736
# weighted avg       0.90      0.90      0.90      4736

# %%
# Classification report for age feature
classification_report_gender = classification_report(age_true, age_pred, target_names=dataset_dict['age_id'].keys(), zero_division=0)
print(classification_report_gender)
#print('Classification Report for "Gender"\n')
# Out:
#               precision    recall  f1-score   support
#
#         0-24       0.86      0.61      0.72      1387
#        25-49       0.73      0.87      0.79      2342
#        50-74       0.64      0.64      0.64       805
#        75-99       0.61      0.49      0.54       195
#      100-124       0.00      0.00      0.00         7
#
#     accuracy                           0.74      4736
#    macro avg       0.57      0.52      0.54      4736
# weighted avg       0.75      0.74      0.73      4736

# %%
# Age ROC curves (Multiclass classification)
# Source: https://stackoverflow.com/questions/39685740/calculate-sklearn-roc-auc-score-for-multi-class
from sklearn.metrics import accuracy_score, roc_curve

age_groups = ['0-24', '25-49','50-74','75-99', '100-124']
def roc_auc_score_multiclass(age_true, age_pred, average = "macro"):

  #creating a set of all the unique classes using the actual class list
  unique_class = set(age_true)
  roc_auc_dict = {}

  for per_class in unique_class:
    #creating a list of all the classes except the current class
    other_class = [x for x in unique_class if x != per_class]

    #marking the current class as 1 and all other classes as 0
    new_actual_class = [0 if x in other_class else 1 for x in age_true]
    new_pred_class = [0 if x in other_class else 1 for x in age_pred]

    #using the sklearn metrics method to calculate the roc_auc_score
    from sklearn.metrics import roc_curve, roc_auc_score
    fpr_age, tpr_age, threshold_age = roc_curve(new_actual_class, new_pred_class)
    roc_auc = roc_auc_score(new_actual_class, new_pred_class)
    roc_auc_dict[per_class] = roc_auc


    # plotting
    plt.plot(fpr_age, tpr_age, linestyle='-',color='red', label=f'Area Under ROC Curve : {roc_auc:.3f}')
    plt.plot([0, 1], [0, 1], color='blue', linestyle='--', label='Baseline')
    plt.title('Age group ' + age_groups[per_class] + ' ROC curve')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive rate')
    plt.legend(loc='best', fancybox=True,)
    save_name = 'metrics_figures/ROC_curve_age_group_' + age_groups[per_class] + '.png'
    plt.savefig(save_name, bbox_inches='tight')
    plt.show()
    plt.close()

  return roc_auc_dict

roc_auc_multiclass = roc_auc_score_multiclass(age_true, age_pred)
acc = accuracy_score(age_true, age_pred)

for i in roc_auc_multiclass:
  print('Roc_Auc_score for age group', age_groups[i], ': {:.0%}'.format(roc_auc_multiclass[i]))
# Out:
# Roc_Auc_score for age group 0-24 : 79%
# Roc_Auc_score for age group 25-49 : 78%
# Roc_Auc_score for age group 50-74 : 78%
# Roc_Auc_score for age group 75-99 : 74%
# Roc_Auc_score for age group 100-124 : 50%

# %%
# Gender ROC curves (Binary classification)
from sklearn.metrics import roc_auc_score, roc_curve

fpr_gender, tpr_gender, threshold_gender = roc_curve(gender_true, gender_pred)
auc_score_gender = roc_auc_score(gender_true, gender_pred)

# plotting
plt.plot(fpr_gender, tpr_gender, linestyle='-',color='green', label=f'Area Under ROC Curve : {auc_score_gender:.3f}')
plt.plot([0, 1], [0, 1], color='blue', linestyle='--', label='Baseline')
plt.title('Gender ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best', fancybox=True,)
plt.savefig(fname='metrics_figures/ROC_curve_gender.png', bbox_inches='tight')
plt.show()
plt.close()

# %%
# Confusion matrix for age and gender (true vs predicted)
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools

# Source= https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html#sphx-glr-auto-examples-model-selection-plot-confusion-matrix-py
def plot_confusion_matrix(cm,
                          classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm,
               interpolation='nearest',
               cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if title == 'Confusion Matrix for "Age" (Multiclass Classification)':
      plt.savefig(fname='metrics_figures/Conf_Mtrx_age.png', bbox_inches='tight')
    else:
      plt.savefig(fname='metrics_figures/Conf_Mtrx_gender.png', bbox_inches='tight')
    plt.show()
    plt.close()

print('Total age count in test dataset: %s' % len(age_pred), '\n')
cm_age = confusion_matrix(age_true, age_pred)
cm_age_plot_labels = ['0-24', '25-49', '50-74', '75-99', '100-124']
plot_confusion_matrix(cm=cm_age, classes=cm_age_plot_labels, title='Confusion Matrix for "Age" (Multiclass Classification)')

print('Total gender count in test dataset: %s' % len(gender_pred), '\n')
cm_gender = confusion_matrix(gender_true, gender_pred)
cm_gender_plot_labels = ['male', 'female']
plot_confusion_matrix(cm=cm_gender, classes=cm_gender_plot_labels, title='Confusion Matrix for "Gender" (Binary Classification)')
# Out:
# Total age count in test dataset: 4736
#
# Confusion matrix, without normalization
# [[ 853  511   21    2    0]
#  [ 133 2032  176    1    0]
#  [   6  231  517   51    0]
#  [   2    4   94   95    0]
#  [   0    0    1    6    0]]
# Total gender count in test dataset: 4736
#
# Confusion matrix, without normalization
# [[2190  290]
#  [ 189 2067]]

# %%
# Age accuracy
plt.plot(history.history['age_accuracy'])
plt.plot(history.history['val_age_accuracy'])
plt.title('Age Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='best', fancybox=True)
plt.savefig(fname='metrics_figures/accuracy_age.png', bbox_inches='tight')
plt.show()
plt.close()

# %%
# Gender accuracy
plt.plot(history.history['gender_accuracy'])
plt.plot(history.history['val_gender_accuracy'])
plt.title('Gender Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='best', fancybox=True)
plt.savefig(fname='metrics_figures/accuracy_gender.png', bbox_inches='tight')
plt.show()
plt.close()

# %%
# Overall loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Overall Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='best', fancybox=True)
plt.savefig(fname='metrics_figures/overall_loss.png', bbox_inches='tight')
plt.show()
plt.close()
