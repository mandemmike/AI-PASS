# %% [markdown]
# # Age & Gender Detection with CNN
#
# **Dataset : UTKFace**
#
# UTKFace dataset is a large-scale face dataset with range from 0 to 116 years old. It consists of over 23,708 face images with labels of age, gender, and ethnicity. The images cover large variation in pose, facial expression, illumination, occlusion, resolution, etc.
#
# Since the dataset is `aligned and cropped` faces available to train the model. Have to say that any face input for testing must be cropped and aligned vertically to large extent.

# %%
# Essential libraries
import os
import glob
import seaborn as sns
import scipy.io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras import applications,activations
from keras_preprocessing.image import img_to_array, load_img
from keras.preprocessing import image
from keras import optimizers,utils
from keras.utils import plot_model
from keras.models import Sequential, Model
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D,BatchNormalization,ZeroPadding2D, Input
from keras.layers import Conv2D, Activation,MaxPooling2D
from keras import backend as k
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping

# %%
# Mounting the directory for the dataset to be read.
dataset_folder = '../ModelTrainingService/input/utkface-new/UTKFace/'
training_split = 0.8
image_width = image_height = 48

dataset_dict = {
    'age_id': {'0-24': 0, '25-49':1, '50-74':2, '75-99':3, '100-124':4},
    'race_id': {0: 'white', 1: 'black', 2: 'asian', 3: 'indian', 4: 'others'},
    'gender_id': {0: 'male', 1: 'female'}
}

dataset_dict['age_temp'] = dict((a, i) for i, a in dataset_dict['age_id'].items())          # (Age: id)
dataset_dict['gender_temp'] = dict((g, i) for i, g in dataset_dict['gender_id'].items())    # (Gender: id)
dataset_dict['race_temp'] = dict((r, i) for i, r in dataset_dict['race_id'].items())        # (Race: id)

# %%
# Function to extract the data from our dataset by iterating over each file of the UTK dataset and
# return a Pandas Dataframe with all the fields (age, gender and sex).

def parse_dataset(dataset_path, ext='jpg'):

    def parse_info_from_file(path):  #Parsing info from a file

        try:
            file_name = os.path.split(path)[1]
            file_name = os.path.splitext(file_name)[0]
            age, gender, race, _ = file_name.split('_')

            return int(age), dataset_dict['gender_id'][int(gender)], dataset_dict['race_id'][int(race)]
        except Exception as ex:
            return None, None, None

    files = glob.glob(os.path.join(dataset_path, "*.%s" % ext))

    records = []
    for file in files:
        info = parse_info_from_file(file)
        records.append(info) # To place new items in the available space

    df = pd.DataFrame(records)
    df['file'] = files
    df.columns = ['age', 'gender', 'race', 'file']


    df = df.dropna() # To remove the rows that contains NULL values.

    return df

# %%
# Dataset before indexing
df = parse_dataset(dataset_folder)
df.head()
# Out:
#    age  gender   race                                               file
# 0  100    male  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 1  100    male  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 2  100  female  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 3  100  female  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 4  100  female  white  ../ModelTrainingService/input/utkface-new/UTKF...

# %%
# No NAN values, means our dataset is already clean.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23708 entries, 0 to 23707
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     23708 non-null  int64
#  1   gender  23708 non-null  object
#  2   race    23708 non-null  object
#  3   file    23708 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 741.0+ KB

# %%
# Lower percentile - 25, median - 50 & upper percentile - 75 (for numerical data)
df.describe()
# Out:
#                 age
# count  23708.000000
# mean      33.303484
# std       19.886112
# min        1.000000
# 25%       23.000000
# 50%       29.000000
# 75%       45.000000
# max      116.000000

# %%
# Mean age by gender
df.groupby(['gender']).mean('age')
# Out:
#               age
# gender
# female  30.684280
# male    35.695666

# %%
# Mean age by race
df.groupby(['race']).mean('age')
# Out:
#               age
# race
# asian   25.877729
# black   33.861498
# indian  31.540241
# others  23.169031
# white   37.980949

# %% [markdown]
# # Data analysis & visualization (EDA)
#
# We can create here a function to generate some pie plots. We also look at the other visualization below to understand and grasp better about the data distribution to crete
# more efficient training, validation and test processes.

# %%
import plotly.graph_objects as go
from IPython.display import display, Image

def plot_distribution(pd_series):

    labels = pd_series.value_counts().index.tolist()
    counts = pd_series.value_counts().values.tolist()

    pie_plot = go.Pie(labels=labels, values=counts, hole=.3)
    fig = go.Figure(data=[pie_plot])
    fig.update_layout(title_text='Distribution for %s' % pd_series.name)

    img_bytes = fig.to_image(format="png")
    #fig.show()
    display(Image(img_bytes))

# # Same as bar plot. Creating bins for age ranges and plotting that data. This helps us to see grouped age into bins with percentages.
bins = [0, 10, 20, 30, 40, 60, 80, np.inf]
names = ['<10', '10-20', '20-30', '30-40', '40-60', '60-80', '80+']
age_binned = pd.cut(df['age'], bins, labels=names)
plot_distribution(age_binned)

# %%
# Uniform distribution to a large extent. Although, males slightly exceed females in numbers.No need to change gender in data.
# Pretty well-balanced ! Let's also visualize this on a bar graph (to get better understanding of numbers)
x = (df.gender=='male').sum()
y = (df.gender=='female').sum()

# Males over 12k while females close to 12k
labels = ['male','female']
colors = [ 'r', 'g']
gender_pie = [x,y]
explode = (0, 0)  # explode the 2nd slice (i.e. 'female')
plt.pie(gender_pie,labels = labels,
        colors = colors,
        explode=explode,
        radius=1.5,
        autopct='%.1f%%',
        textprops={'color':"Black", 'size':15},
        startangle=90)
plt.legend(gender_pie, bbox_to_anchor=(1.1, 1.1), fontsize='x-large')
plt.show()

# %%
# Distribution for race
x = (df.race == 'white').sum()
y = (df.race == 'black').sum()
z = (df.race == 'asian').sum()
a = (df.race == 'indian').sum()
b = (df.race == 'others').sum()

race_pie = [x, y, z, a, b]
labels = ['white', 'black', 'asian', 'indian', 'others']
colors = ['g', 'r', 'b', 'y', 'm']
plt.pie(race_pie, labels=labels, colors=colors, radius=1.5, autopct='%.1f%%', textprops={'color':"Black", 'size':10},)
plt.show()

# %%
# The population is mostly between 20-30 age group, the dataset is not very well-balanced. We try to embrace this imbalance through imagedatagenerator below.
ages = df['age']
nbins = 120
plt.figure(figsize=(15,8))
plt.hist(ages,nbins,color='red',histtype='bar')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Number of datapoints')
plt.show()

# %%
# Males over 12k & females close to 12k
sns.countplot(x='gender', data=df);

# %%
# Gives the mean age of both genders of all races
sns.catplot(x='race', y='age', hue='gender', data=df,kind='bar', height=5);

# %%
# We see that most of the males are between 25 and 55, whereas most of the females are between 20 and 40.
# Grouping by race, there is good amount of variations in different races.
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
_ = sns.boxplot(data=df, x='gender', y='age', ax=ax1)
_ = sns.boxplot(data=df, x='race', y='age', ax=ax2)

# %%
# RUN THIS CELL ONLY ONCE
# To create age groups
df['age'] = df['age']//25

''' This basically makes 5 divisions in age-groups -
1. 0-24
2. 25-49
3. 50-74
4. 75-99
5. 100-124 '''

x = (df.age==0).sum()
y = (df.age==1).sum()
z = (df.age==2).sum()
a = (df.age==3).sum()
b = (df.age==4).sum()
c = (df.age==5).sum() # To see that nothing left in the dataset

print(x,' ', y,' ', z,' ', a,' ', b, ' ', c,' ')
# Out:
# 6903   11816   3990   967   32   0

# %%
# After distribition of the ages into groups, we have now age groups 0 to 4 for age feature which contains ages from 1y to 116y.
df.head()
# Out:
#    age  gender   race                                               file
# 0    4    male  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 1    4    male  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 2    4  female  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 3    4  female  white  ../ModelTrainingService/input/utkface-new/UTKF...
# 4    4  female  white  ../ModelTrainingService/input/utkface-new/UTKF...

# %% [markdown]
# # Data image generator
# To be able to use as input to our model, below is the keras image data generator by creating batches of image data to feed the multi-output predictions.

# %%
# Data image generator for augmenting the data
# Generating batches of data, which will be used to feed our multi-output model with both the images and their labels.
import cv2
from keras.utils import to_categorical, normalize
from PIL import Image, ImageFont

class UtkFaceDataGenerator():

    # Data generator for the UTKFace dataset. This class should be used when training our Keras multi-output model.
    def __init__(self, df):
        self.df = df

    def generate_split_indexes(self):
      p = np.random.permutation(len(self.df))
      train_df = int(len(self.df) * training_split)
      train_idx = p[:train_df]
      test_idx = p[train_df:]

      train_df = int(train_df * training_split)
      train_idx, valid_idx = train_idx[:train_df], train_idx[train_df:]


      # converts alias to id
      self.df['age_id'] = self.df['age'].map(lambda age: dataset_dict['age_temp'][age])
      self.df['gender_id'] = self.df['gender'].map(lambda gender: dataset_dict['gender_temp'][gender])
      self.df['race_id'] = self.df['race'].map(lambda race: dataset_dict['race_temp'][race])
      #self.max_age = self.df['age'].max()

      return train_idx, valid_idx, test_idx

    def preprocess_image(self, img_path):

      # Used to perform some minor preprocessing (BGR2RGB) on the image before inputting into the network because matplotlib plot function expects RGB.

      im = cv2.imread(img_path)
      im = cv2.resize(im, (image_width, image_height))
      im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
      im = np.array(im) / 255.0

      return im

    def generate_images(self, image_idx, is_training, batch_size=16):
      """
      Used to generate a batch with images when training/testing/validating our Keras model.
      """

      # arrays to store our batched data
      images, ages, races, genders = [], [], [], []
      while True:
        for idx in image_idx:
          person = self.df.iloc[idx]

          age = person['age']
          race = person['race_id']
          gender = person['gender_id']
          file = person['file']

          im = self.preprocess_image(file)

          #ages.append(age / self.max_age)
          ages.append(to_categorical(age,len(dataset_dict['age_id'])))
          races.append(to_categorical(race, len(dataset_dict['race_id'])))
          genders.append(to_categorical(gender, len(dataset_dict['gender_id'])))
          images.append(im)

          # yielding condition
          if len(images) >= batch_size:
            yield np.array(images), [np.array(ages), np.array(races), np.array(genders)]
            images, ages, races, genders = [], [], [], []

        if not is_training:
          break

data_generator = UtkFaceDataGenerator(df)
train_idx, valid_idx, test_idx = data_generator.generate_split_indexes()

print('Train dataset lenght: ', len(train_idx))
print('Validation dataset lenght: ', len(valid_idx))
print('Test dataset lenght: ', len(test_idx))
# Out:
# Train dataset lenght:  15172
# Validation dataset lenght:  3794
# Test dataset lenght:  4742

# %% [markdown]
# ## Model Architecture

# %%
# Source: https://pyimagesearch.com/2018/06/04/keras-multiple-outputs-and-multiple-losses/
# CNN Model Architecture by splitting the labels (age, gender, race) for flatten, dropout and activation of the layers.
from keras.layers.convolutional import Conv2D, SeparableConv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Dropout
from keras.layers.core import Lambda
from keras.layers.core import Dense
from keras.models import Model
from keras.layers import BatchNormalization
from keras.layers import SpatialDropout2D
from keras.layers import Flatten
from keras.layers import Input
from keras.regularizers import l2
import tensorflow as tf

# SeparableConv2D: A variation of the traditional convolution that was to compute it faster than conv2D.
# "same" vs "valid": Output size is the "same" results in padding with zeros evenly to the left/right or up/down, while "valid" is no padding.
# Source for more detail about padding: https://stackoverflow.com/questions/37674306/what-is-the-difference-between-same-and-valid-padding-in-tf-nn-max-pool-of-t
# BatchNormalization: To speed up training and to use higher learning rates, making learning easier and to distribute the data uniformly across a mean
#                     that the network sees best as well as to guarantee that the values are within a healthy range, avoiding saturation and vanishing gradients.
# MaxPooling2D: To downsample the input along its spatial dimensions (height and width) by taking the maximum value over an input window defined by pool_size for each channel.
# SpatialDropout2D: To drop the entire 2D feature maps instead of individual elements as dropout does.
# Strides: The window for shifting.
# Source: https://stackoverflow.com/questions/59634780/correct-order-for-spatialdropout2d-batchnormalization-and-activation-function
# Dropouts: To prevent over-fitting the model during training
# relu(Rectifier Linear Unit): Activation to prevent exponential growth in the computation and the emergence of the “vanishing gradient” problem
#                               by keeping gradient always high.
# Dense layer: To create fully connected layers, in which (linear) every output depends on every input after usage of Convolutional Layers with fewer parameters
# by forcing every input to the function and let the neurol network to learn its relation to the output.


class UtkMultiOutputModel():
    """
    Used to generate our multi-output model. This CNN contains three branches, one for age, other for
    sex and another for race. Each branch contains a sequence of Convolutional Layers that is defined
    on the make_default_hidden_layers method.
    """

    def hidden_layers(self, inputs):

        # To generate a default set of hidden layers. Structured as => Conv2D -> Activation "relu" -> BatchNormalization -> Pooling -> Dropout

        x = Conv2D(16, (3, 3), padding="same")(inputs)
        x = Activation("relu")(x)
        x = BatchNormalization(axis=-1)(x)
        x = MaxPooling2D(pool_size=(2, 2))(x)
        x = Dropout(0.25)(x)

        x = Conv2D(32, (3, 3), padding="same")(x)
        x = Activation("relu")(x)
        x = BatchNormalization(axis=-1)(x)
        x = MaxPooling2D(pool_size=(2, 2))(x)
        x = Dropout(0.25)(x)

        x = Conv2D(32, (3, 3), padding="same")(x)
        x = Activation("relu")(x)
        x = BatchNormalization(axis=-1)(x)
        x = MaxPooling2D(pool_size=(2, 2))(x)
        x = Dropout(0.25)(x)

        return x

    def build_race_branch(self, inputs):

        # Race branch is structured as => Conv -> BatchNormalization -> Pool -> Dropout blocks, followed by the Dense output layer.
        x = self.hidden_layers(inputs)
        x = Flatten()(x)
        x = Dense(64)(x)
        x = Activation("relu")(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(5)(x)
        x = Activation("softmax", name="race")(x)

        return x

    def build_gender_branch(self, inputs):

        # The gender branch is structured as = Conv -> BatchNormalization -> Pool -> Dropout blocks, followed by the Dense output layer.
        x = Lambda(lambda c: tf.image.rgb_to_grayscale(c))(inputs)
        x = self.hidden_layers(inputs)
        x = Flatten()(x)
        x = Dense(64)(x)
        x = Activation("relu")(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(2)(x)
        x = Activation("sigmoid", name="gender")(x)

        return x

    def build_age_branch(self, inputs):

        # The age branch is structured as = Conv -> BatchNormalization -> Pool -> Dropout blocks, followed by the Dense output layer.
        x = self.hidden_layers(inputs)
        x = Flatten()(x)
        x = Dense(64)(x)
        x = Activation("relu")(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(5)(x)
        x = Activation("softmax", name="age")(x)

        return x

    # To assemble the output model with their determined height and width.
    def assemble_full_model(self, width, height):

        input_shape = (height, width, 3)
        inputs = Input(shape=input_shape)

        age_branch = self.build_age_branch(inputs)
        race_branch = self.build_race_branch(inputs)
        gender_branch = self.build_gender_branch(inputs)
        model = Model(inputs=inputs,
                     outputs = [age_branch, race_branch, gender_branch],
                     name="face_net")
        return model

model = UtkMultiOutputModel().assemble_full_model(image_width, image_height)

# To print out and save the layer model plot as png
from keras.utils import plot_model

plot_model(model, to_file='../ModelTrainingService/cnn_model_plot(latest).png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "face_net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 48, 48, 16)   448         ['input_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 48, 48, 16)   448         ['input_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 48, 48, 16)   448         ['input_1[0][0]']
#
#  activation (Activation)        (None, 48, 48, 16)   0           ['conv2d[0][0]']
#
#  activation_4 (Activation)      (None, 48, 48, 16)   0           ['conv2d_3[0][0]']
#
#  activation_8 (Activation)      (None, 48, 48, 16)   0           ['conv2d_6[0][0]']
#
#  batch_normalization (BatchNorm  (None, 48, 48, 16)  64          ['activation[0][0]']
#  alization)
#
#  batch_normalization_4 (BatchNo  (None, 48, 48, 16)  64          ['activation_4[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 48, 48, 16)  64          ['activation_8[0][0]']
#  rmalization)
#
#  max_pooling2d (MaxPooling2D)   (None, 24, 24, 16)   0           ['batch_normalization[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 24, 24, 16)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 24, 24, 16)  0           ['batch_normalization_8[0][0]']
#
#  dropout (Dropout)              (None, 24, 24, 16)   0           ['max_pooling2d[0][0]']
#
#  dropout_4 (Dropout)            (None, 24, 24, 16)   0           ['max_pooling2d_3[0][0]']
#
#  dropout_8 (Dropout)            (None, 24, 24, 16)   0           ['max_pooling2d_6[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 24, 24, 32)   4640        ['dropout[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 24, 24, 32)   4640        ['dropout_4[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 24, 24, 32)   4640        ['dropout_8[0][0]']
#
#  activation_1 (Activation)      (None, 24, 24, 32)   0           ['conv2d_1[0][0]']
#
#  activation_5 (Activation)      (None, 24, 24, 32)   0           ['conv2d_4[0][0]']
#
#  activation_9 (Activation)      (None, 24, 24, 32)   0           ['conv2d_7[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 24, 24, 32)  128         ['activation_1[0][0]']
#  rmalization)
#
#  batch_normalization_5 (BatchNo  (None, 24, 24, 32)  128         ['activation_5[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 24, 24, 32)  128         ['activation_9[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 32)  0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 12, 12, 32)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 12, 12, 32)  0           ['batch_normalization_9[0][0]']
#
#  dropout_1 (Dropout)            (None, 12, 12, 32)   0           ['max_pooling2d_1[0][0]']
#
#  dropout_5 (Dropout)            (None, 12, 12, 32)   0           ['max_pooling2d_4[0][0]']
#
#  dropout_9 (Dropout)            (None, 12, 12, 32)   0           ['max_pooling2d_7[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 12, 12, 32)   9248        ['dropout_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 12, 12, 32)   9248        ['dropout_5[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 12, 12, 32)   9248        ['dropout_9[0][0]']
#
#  activation_2 (Activation)      (None, 12, 12, 32)   0           ['conv2d_2[0][0]']
#
#  activation_6 (Activation)      (None, 12, 12, 32)   0           ['conv2d_5[0][0]']
#
#  activation_10 (Activation)     (None, 12, 12, 32)   0           ['conv2d_8[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 12, 12, 32)  128         ['activation_2[0][0]']
#  rmalization)
#
#  batch_normalization_6 (BatchNo  (None, 12, 12, 32)  128         ['activation_6[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 12, 12, 32)  128         ['activation_10[0][0]']
#  ormalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 6, 6, 32)    0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 6, 6, 32)    0           ['batch_normalization_6[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 6, 6, 32)    0           ['batch_normalization_10[0][0]']
#
#  dropout_2 (Dropout)            (None, 6, 6, 32)     0           ['max_pooling2d_2[0][0]']
#
#  dropout_6 (Dropout)            (None, 6, 6, 32)     0           ['max_pooling2d_5[0][0]']
#
#  dropout_10 (Dropout)           (None, 6, 6, 32)     0           ['max_pooling2d_8[0][0]']
#
#  flatten (Flatten)              (None, 1152)         0           ['dropout_2[0][0]']
#
#  flatten_1 (Flatten)            (None, 1152)         0           ['dropout_6[0][0]']
#
#  flatten_2 (Flatten)            (None, 1152)         0           ['dropout_10[0][0]']
#
#  dense (Dense)                  (None, 64)           73792       ['flatten[0][0]']
#
#  dense_2 (Dense)                (None, 64)           73792       ['flatten_1[0][0]']
#
#  dense_4 (Dense)                (None, 64)           73792       ['flatten_2[0][0]']
#
#  activation_3 (Activation)      (None, 64)           0           ['dense[0][0]']
#
#  activation_7 (Activation)      (None, 64)           0           ['dense_2[0][0]']
#
#  activation_11 (Activation)     (None, 64)           0           ['dense_4[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64)          256         ['activation_3[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 64)          256         ['activation_7[0][0]']
#  rmalization)
#
#  batch_normalization_11 (BatchN  (None, 64)          256         ['activation_11[0][0]']
#  ormalization)
#
#  dropout_3 (Dropout)            (None, 64)           0           ['batch_normalization_3[0][0]']
#
#  dropout_7 (Dropout)            (None, 64)           0           ['batch_normalization_7[0][0]']
#
#  dropout_11 (Dropout)           (None, 64)           0           ['batch_normalization_11[0][0]']
#
#  dense_1 (Dense)                (None, 5)            325         ['dropout_3[0][0]']
#
#  dense_3 (Dense)                (None, 5)            325         ['dropout_7[0][0]']
#
#  dense_5 (Dense)                (None, 2)            130         ['dropout_11[0][0]']
#
#  age (Activation)               (None, 5)            0           ['dense_1[0][0]']
#
#  race (Activation)              (None, 5)            0           ['dense_3[0][0]']
#
#  gender (Activation)            (None, 2)            0           ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 266,892
# Trainable params: 266,028
# Non-trainable params: 864
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training the model

# %%
from keras.metrics import AUC
import math
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras.callbacks import LearningRateScheduler

# Source: https://neptune.ai/blog/keras-metrics
init_lr = 1e-4
epochs = 150
#opt = Adam(learning_rate=0.0)                   # 0.0 means not to be used here.
opt = Adam(learning_rate=init_lr, decay=init_lr / epochs)
model.compile(optimizer=opt,
              loss={
                  'age': 'categorical_crossentropy',
                  'race': 'categorical_crossentropy',
                  'gender': 'binary_crossentropy'},
              loss_weights={
                  'age': 4.,
                  'race': 1.5,
                  'gender': 0.1},
              metrics={
                  'age': ['accuracy', AUC(curve="ROC")],
                  'race': ['accuracy', AUC(curve="ROC")],
                  'gender': ['accuracy', AUC(curve="ROC")]})

# %%
# class_weight in Keras: To ensure the unevenness in data distribution (as in age) is sorted out by giving the classes with fewer numbers is assigned more
# weight to prevent being biased.
from sklearn.utils import class_weight

class_weight = class_weight.compute_class_weight('balanced',
                                                 classes=np.array([0,1,2,3,4]),
                                                 y=np.array(df['age']))

class_weight1 = {'age': class_weight}

# %%
# To generate batches for train_idx to be able to prevent "too large to fit inside RAM at once so-called memory errors".
# Soource: https://www.codementor.io/@alexander-k/keras-training-earlystopping-callback-to-avoid-overfitting-1ehrjlx8kw

import sys
import math
import keras
from datetime import datetime
import datetime
import time
import os
from django.utils.datetime_safe import datetime
from keras.callbacks import EarlyStopping
from livelossplot import PlotLossesKeras
plt.style.use('ggplot')
from sklearn.preprocessing import LabelBinarizer
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler

# CALLBACKS

# Exponential_decay() or step_decay() functions alternatively can be used for dynamic learning rate
#----------------------------------------------------------------------------------------------------------------------------------------------
# Learning Rate Schedules in Keras reduces the learning rate by a certain factor after certain no of epochs

#Source:    (https://towardsdatascience.com/learning-rate-schedules-and-adaptive-learning-rate-methods-for-deep-learning-2c8f433990d1)
#           (https://github.com/ShreyanshJoshi/Facial-Demographics-using-CNN#overview)
#           (https://github.com/sukilau/Ziff-deep-learning/blob/master/3-CIFAR10-lrate/CIFAR10-lrate.ipynb)

# According ot several sources (few example of it above), since the learning rate is the most important
# hyperparameter to tune the training in a neural network, it is stated that to reduce learning rate as the training progresses,
# is a good practice for a better outcome (accuracy).

# Exponential Decay
# def exp_decay(epoch):
#    initial_lrate = 0.001
#    k = 0.2
#    lrate = initial_lrate * np.exp(-k * epoch)  # lr, k are hyperparameters and t=epoch is the iteration number
#    return lrate

# Step Decay, to drop the learning rate by a factor every few epochs.
# def step_decay(epoch):
# 	initial_lrate = 0.008
# 	drop = 0.7              # % drop rate
# 	epochs_drop = 5.0       # To drop after every number of epoch
# 	lrate = initial_lrate * math.pow(drop, math.floor((1 + epoch) / epochs_drop)) #Fromula for step_decay
# 	return lrate

# Source: (https://datascience.stackexchange.com/questions/42599/what-is-the-relationship-between-the-accuracy-and-the-loss-in-deep-learning)
# a low accuracy and huge loss means you made huge errors on a lot of data
# a low accuracy but low loss means you made little errors on a lot of data
# a great accuracy with low loss means you made low errors on a few data (best case)

# lrate = LearningRateScheduler(step_decay)       # At the beginning of every epoch, this callback gets the updated learning rate value
#lrate = LearningRateScheduler(exp_decay)

# `binary_crossentropy`, sigmoid activation, scalar target.
# `categorical_crossentropy`, softmax activation, one-hot encoded target.

# It is this callback that allows a function to invoke during program execution.
#callbacks_list = [lrate]
#----------------------------------------------------------------------------------------------------------------------------------------

# To measure the time for the traiing session
start = datetime.now()

filepath = "../ModelTrainingService/models/CNN_Dec260151.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

monitor_val_acc = [EarlyStopping(monitor = 'val_loss',
                                min_delta = 0,
                                patience = 10,
                                verbose = 1,
                                mode='max',
                                restore_best_weights = True)]

#callbacks_list = [PlotLossesKeras(), monitor_val_acc, checkpoint]


# Training and validation batches
batch_size = 32
train_gen = data_generator.generate_images(train_idx,
                                           is_training=True,
                                           batch_size=batch_size)

valid_gen = data_generator.generate_images(valid_idx,
                                           is_training=True,
                                           batch_size=batch_size)

# fit() as known fit_generator() before 2020: Validation while training the model to evaluate the loss.
history = model.fit(train_gen,
                    steps_per_epoch=len(train_idx)//batch_size,
                    epochs=epochs,
                    #callbacks=callbacks_list,
                    validation_data=valid_gen,
                    validation_steps=len(valid_idx)//batch_size,
                    verbose=1)

#Training time
end = datetime.now()
elapsed = end-start
print ('\nElapsed Time: ', elapsed)
# Out:
# Epoch 1/150
# 474/474 [==============================] - 41s 65ms/step - loss: 11.9413 - age_loss: 2.1786 - race_loss: 2.0967 - gender_loss: 0.8195 - age_accuracy: 0.2950 - age_auc: 0.5978 - race_accuracy: 0.3146 - race_auc_1: 0.6152 - gender_accuracy: 0.6361 - gender_auc_2: 0.6588 - val_loss: 8.7698 - val_age_loss: 1.6257 - val_race_loss: 1.4696 - val_gender_loss: 0.6251 - val_age_accuracy: 0.3064 - val_age_auc: 0.6583 - val_race_accuracy: 0.4685 - val_race_auc_1: 0.7372 - val_gender_accuracy: 0.6597 - val_gender_auc_2: 0.7273
# Epoch 2/150
# 474/474 [==============================] - 19s 40ms/step - loss: 9.5052 - age_loss: 1.7184 - race_loss: 1.7105 - gender_loss: 0.6598 - age_accuracy: 0.3889 - age_auc: 0.6905 - race_accuracy: 0.3999 - race_auc_1: 0.6948 - gender_accuracy: 0.7175 - gender_auc_2: 0.7590 - val_loss: 7.1407 - val_age_loss: 1.2926 - val_race_loss: 1.2812 - val_gender_loss: 0.4837 - val_age_accuracy: 0.5196 - val_age_auc: 0.7889 - val_race_accuracy: 0.5093 - val_race_auc_1: 0.7871 - val_gender_accuracy: 0.7609 - val_gender_auc_2: 0.8489
# Epoch 3/150
# 474/474 [==============================] - 20s 42ms/step - loss: 8.2754 - age_loss: 1.4773 - race_loss: 1.5394 - gender_loss: 0.5725 - age_accuracy: 0.4552 - age_auc: 0.7481 - race_accuracy: 0.4484 - race_auc_1: 0.7312 - gender_accuracy: 0.7548 - gender_auc_2: 0.8117 - val_loss: 6.9423 - val_age_loss: 1.2377 - val_race_loss: 1.2982 - val_gender_loss: 0.4398 - val_age_accuracy: 0.5339 - val_age_auc: 0.8197 - val_race_accuracy: 0.5217 - val_race_auc_1: 0.7945 - val_gender_accuracy: 0.7953 - val_gender_auc_2: 0.8783
# Epoch 4/150
# Epoch 9/150
# 474/474 [==============================] - 21s 44ms/step - loss: 5.4532 - age_loss: 0.9530 - race_loss: 1.0670 - gender_loss: 0.4061 - age_accuracy: 0.6184 - age_auc: 0.8848 - race_accuracy: 0.6115 - race_auc_1: 0.8570 - gender_accuracy: 0.8244 - gender_auc_2: 0.8991 - val_loss: 5.0521 - val_age_loss: 0.8989 - val_race_loss: 0.9492 - val_gender_loss: 0.3272 - val_age_accuracy: 0.6324 - val_age_auc: 0.9002 - val_race_accuracy: 0.6446 - val_race_auc_1: 0.8870 - val_gender_accuracy: 0.8514 - val_gender_auc_2: 0.9346
# Epoch 10/150
# 474/474 [==============================] - 21s 44ms/step - loss: 5.2812 - age_loss: 0.9246 - race_loss: 1.0285 - gender_loss: 0.4008 - age_accuracy: 0.6258 - age_auc: 0.8911 - race_accuracy: 0.6247 - race_auc_1: 0.8665 - gender_accuracy: 0.8257 - gender_auc_2: 0.9022 - val_loss: 5.2514 - val_age_loss: 0.9653 - val_race_loss: 0.9042 - val_gender_loss: 0.3383 - val_age_accuracy: 0.6006 - val_age_auc: 0.8844 - val_race_accuracy: 0.6653 - val_race_auc_1: 0.8972 - val_gender_accuracy: 0.8422 - val_gender_auc_2: 0.9296
# Epoch 11/150
# 474/474 [==============================] - 21s 45ms/step - loss: 5.1208 - age_loss: 0.8945 - race_loss: 1.0029 - gender_loss: 0.3853 - age_accuracy: 0.6335 - age_auc: 0.8971 - race_accuracy: 0.6377 - race_auc_1: 0.8730 - gender_accuracy: 0.8310 - gender_auc_2: 0.9084 - val_loss: 4.5571 - val_age_loss: 0.8020 - val_race_loss: 0.8783 - val_gender_loss: 0.3145 - val_age_accuracy: 0.6578 - val_age_auc: 0.9166 - val_race_accuracy: 0.6819 - val_race_auc_1: 0.9028 - val_gender_accuracy: 0.8581 - val_gender_auc_2: 0.9399
# Epoch 12/150
# 474/474 [==============================] - 21s 44ms/step - loss: 4.9378 - age_loss: 0.8585 - race_loss: 0.9777 - gender_loss: 0.3728 - age_accuracy: 0.6468 - age_auc: 0.9046 - race_accuracy: 0.6456 - race_auc_1: 0.8791 - gender_accuracy: 0.8360 - gender_auc_2: 0.9149 - val_loss: 4.5897 - val_age_loss: 0.8156 - val_race_loss: 0.8643 - val_gender_loss: 0.3073 - val_age_accuracy: 0.6555 - val_age_auc: 0.9149 - val_race_accuracy: 0.6856 - val_race_auc_1: 0.9059 - val_gender_accuracy: 0.8641 - val_gender_auc_2: 0.9431
# Epoch 13/150
# 474/474 [==============================] - 21s 44ms/step - loss: 4.8286 - age_loss: 0.8392 - race_loss: 0.9565 - gender_loss: 0.3701 - age_accuracy: 0.6480 - age_auc: 0.9081 - race_accuracy: 0.6534 - race_auc_1: 0.8842 - gender_accuracy: 0.8418 - gender_auc_2: 0.9161 - val_loss: 4.5944 - val_age_loss: 0.8127 - val_race_loss: 0.8757 - val_gender_loss: 0.3027 - val_age_accuracy: 0.6568 - val_age_auc: 0.9157 - val_race_accuracy: 0.6745 - val_race_auc_1: 0.9044 - val_gender_accuracy: 0.8644 - val_gender_auc_2: 0.9444
# Epoch 14/150
150
# 474/474 [==============================] - 20s 43ms/step - loss: 3.9059 - age_loss: 0.6839 - race_loss: 0.7607 - gender_loss: 0.2929 - age_accuracy: 0.7072 - age_auc: 0.9362 - race_accuracy: 0.7302 - race_auc_1: 0.9264 - gender_accuracy: 0.8718 - gender_auc_2: 0.9476 - val_loss: 4.1461 - val_age_loss: 0.7640 - val_race_loss: 0.7098 - val_gender_loss: 0.2540 - val_age_accuracy: 0.6761 - val_age_auc: 0.9221 - val_race_accuracy: 0.7503 - val_race_auc_1: 0.9362 - val_gender_accuracy: 0.8962 - val_gender_auc_2: 0.9610
# Epoch 36/150
# 474/474 [==============================] - 20s 43ms/step - loss: 3.8994 - age_loss: 0.6844 - race_loss: 0.7555 - gender_loss: 0.2851 - age_accuracy: 0.7073 - age_auc: 0.9360 - race_accuracy: 0.7323 - race_auc_1: 0.9274 - gender_accuracy: 0.8722 - gender_auc_2: 0.9506 - val_loss: 4.0498 - val_age_loss: 0.7481 - val_race_loss: 0.6880 - val_gender_loss: 0.2523 - val_age_accuracy: 0.6843 - val_age_auc: 0.9255 - val_race_accuracy: 0.7617 - val_race_auc_1: 0.9397 - val_gender_accuracy: 0.8967 - val_gender_auc_2: 0.9615
# Epoch 37/150
# 474/474 [==============================] - 22s 47ms/step - loss: 3.8575 - age_loss: 0.6755 - race_loss: 0.7511 - gender_loss: 0.2863 - age_accuracy: 0.7104 - age_auc: 0.9377 - race_accuracy: 0.7381 - race_auc_1: 0.9283 - gender_accuracy: 0.8776 - gender_auc_2: 0.9507 - val_loss: 4.0386 - val_age_loss: 0.7520 - val_race_loss: 0.6703 - val_gender_loss: 0.2505 - val_age_accuracy: 0.6835 - val_age_auc: 0.9247 - val_race_accuracy: 0.7736 - val_race_auc_1: 0.9425 - val_gender_accuracy: 0.8994 - val_gender_auc_2: 0.9621
# Epoch 38/150
# 474/474 [==============================] - 21s 45ms/step - loss: 3.8609 - age_loss: 0.6769 - race_loss: 0.7501 - gender_loss: 0.2799 - age_accuracy: 0.7119 - age_auc: 0.9375 - race_accuracy: 0.7369 - race_auc_1: 0.9285 - gender_accuracy: 0.8803 - gender_auc_2: 0.9524 - val_loss: 4.3061 - val_age_loss: 0.8190 - val_race_loss: 0.6697 - val_gender_loss: 0.2555 - val_age_accuracy: 0.6510 - val_age_auc: 0.9113 - val_race_accuracy: 0.7728 - val_race_auc_1: 0.9425 - val_gender_accuracy: 0.8957 - val_gender_auc_2: 0.9605
# Epoch 39/150
# 474/474 [==============================] - 20s 43ms/step - loss: 3
# Epoch 45/150
# 474/474 [==============================] - 20s 41ms/step - loss: 3.7386 - age_loss: 0.6569 - race_loss: 0.7227 - gender_loss: 0.2707 - age_accuracy: 0.7204 - age_auc: 0.9411 - race_accuracy: 0.7463 - race_auc_1: 0.9337 - gender_accuracy: 0.8838 - gender_auc_2: 0.9554 - val_loss: 3.6104 - val_age_loss: 0.6457 - val_race_loss: 0.6689 - val_gender_loss: 0.2442 - val_age_accuracy: 0.7317 - val_age_auc: 0.9434 - val_race_accuracy: 0.7654 - val_race_auc_1: 0.9430 - val_gender_accuracy: 0.9012 - val_gender_auc_2: 0.9639
# Epoch 46/150
# 474/474 [==============================] - 21s 45ms/step - loss: 3.7489 - age_loss: 0.6605 - race_loss: 0.7199 - gender_loss: 0.2715 - age_accuracy: 0.7199 - age_auc: 0.9404 - race_accuracy: 0.7485 - race_auc_1: 0.9340 - gender_accuracy: 0.8813 - gender_auc_2: 0.9551 - val_loss: 3.6385 - val_age_loss: 0.6439 - val_race_loss: 0.6922 - val_gender_loss: 0.2466 - val_age_accuracy: 0.7283 - val_age_auc: 0.9439 - val_race_accuracy: 0.7564 - val_race_auc_1: 0.9399 - val_gender_accuracy: 0.8996 - val_gender_auc_2: 0.9632
# Epoch 47/150
# 474/474 [==============================] - 20s 43ms/step - loss: 3.7118 - age_loss: 0.6532 - race_loss: 0.7145 - gender_loss: 0.2716 - age_accuracy: 0.7204 - age_auc: 0.9415 - race_accuracy: 0.7504 - race_auc_1: 0.9348 - gender_accuracy: 0.8826 - gender_auc_2: 0.9551 - val_loss: 4.0808 - val_age_loss: 0.7690 - val_race_loss: 0.6535 - val_gender_loss: 0.2462 - val_age_accuracy: 0.6708 - val_age_auc: 0.9212 - val_race_accuracy: 0.7757 - val_race_auc_1: 0.9453 - val_gender_accuracy: 0.9010 - val_gender_auc_2: 0.9635
# Epoch 48/150
# 474/474 [==============================] - 20s 42ms/step - loss: 3.6763 - age_loss: 0.6470 - race_loss: 0.7077 - gender_loss: 0.2666 - age_accuracy: 0.7234 - age_auc: 0.9424 - race_accuracy: 0.7510 - race_auc_1: 0.9363 - gender_accuracy: 0.8819 - gender_auc_2: 0.9566 - val_loss: 4.0152 - val_age_loss: 0.7567 - val_race_loss: 0.6429 - val_gender_loss: 0.2411 - val_age_accuracy: 0.6830 - val_age_auc: 0.9247 - val_race_accuracy: 0.7797 - val_race_auc_1: 0.9469 - val_gender_accuracy: 0.9047 - val_gender_auc_2: 0.9648
# Epoch 49/150
# 474/474 [==============================] - 21s 44ms/step - loss: 3.6806 - age_loss: 0.6478 - race_loss: 0.7083 - gender_loss: 0.2679 - age_accuracy: 0.7205 - age_auc: 0.9422 - race_accuracy: 0.7538 - race_auc_1: 0.9360 - gender_accuracy: 0.8854 - gender_auc_2: 0.9564 - val_loss: 3.8048 - val_age_loss: 0.7004 - val_race_loss: 0.6528 - val_gender_loss: 0.2422 - val_age_accuracy: 0.7060 - val_age_auc: 0.9343 - val_race_accuracy: 0.7722 - val_race_auc_1: 0.9457 - val_gender_accuracy: 0.9041 - val_gender_auc_2: 0.9646
# Epoch 50/150
150
# 474/474 [==============================] - 21s 44ms/step - loss: 3.4762 - age_loss: 0.6169 - race_loss: 0.6555 - gender_loss: 0.2524 - age_accuracy: 0.7350 - age_auc: 0.9474 - race_accuracy: 0.7691 - race_auc_1: 0.9452 - gender_accuracy: 0.8939 - gender_auc_2: 0.9614 - val_loss: 3.6476 - val_age_loss: 0.6741 - val_race_loss: 0.6183 - val_gender_loss: 0.2370 - val_age_accuracy: 0.7166 - val_age_auc: 0.9385 - val_race_accuracy: 0.7865 - val_race_auc_1: 0.9509 - val_gender_accuracy: 0.9060 - val_gender_auc_2: 0.9663
# Epoch 67/150
# 474/474 [==============================] - 20s 43ms/step - loss: 3.4816 - age_loss: 0.6151 - race_loss: 0.6647 - gender_loss: 0.2429 - age_accuracy: 0.7368 - age_auc: 0.9477 - race_accuracy: 0.7673 - race_auc_1: 0.9439 - gender_accuracy: 0.8954 - gender_auc_2: 0.9642 - val_loss: 4.0735 - val_age_loss: 0.7811 - val_race_loss: 0.6169 - val_gender_loss: 0.2390 - val_age_accuracy: 0.6690 - val_age_auc: 0.9196 - val_race_accuracy: 0.7932 - val_race_auc_1: 0.9511 - val_gender_accuracy: 0.9068 - val_gender_auc_2: 0.9660
# Epoch 68/150
# 474/474 [==============================] - 20s 43ms/step - loss: 3.4804 - age_loss: 0.6163 - race_loss: 0.6608 - gender_loss: 0.2420 - age_accuracy: 0.7369 - age_auc: 0.9476 - race_accuracy: 0.7656 - race_auc_1: 0.9445 - gender_accuracy: 0.8968 - gender_auc_2: 0.9645 - val_loss: 4.3128 - val_age_loss: 0.8449 - val_race_loss: 0.6064 - val_gender_loss: 0.2362 - val_age_accuracy: 0.6459 - val_age_auc: 0.9075 - val_race_accuracy: 0.7929 - val_race_auc_1: 0.9525 - val_gender_accuracy: 0.9073 - val_gender_auc_2: 0.9666
# Epoch 69/150
# 474/474 [==============================] - 21s 44ms/step - loss: 3.4500 - age_loss: 0.6100 - race_loss: 0.6577 - gender_loss: 0.2354 - age_accuracy: 0.7396 - age_auc: 0.9488 - race_accuracy: 0.7646 - race_auc_1: 0.9450 - gender_accuracy: 0.9014 - gender_auc_2: 0.9665 - val_loss: 3.3213 - val_age_loss: 0.5907 - val_race_loss: 0.6219 - val_gender_loss: 0.2543 - val_age_accuracy: 0.7471 - val_age_auc: 0.9516 - val_race_accuracy: 0.7873 - val_race_auc_1: 0.9501 - val_gender_accuracy: 0.8988 - val_gender_auc_2: 0.9622
# Epoch 70/150
# 474/474 [==============================] - 20s 43ms/step - loss: 3.4644 - age_loss: 0.6123 - race_loss: 0.6605 - gender_loss: 0.2444 - age_accuracy: 0.7393 - age_auc: 0.9484 - race_accuracy: 0.7671 - race_auc_1: 0.9445 - gender_accuracy: 0.8944 - gender_auc_2: 0.9637 - val_loss: 3.3489 - val_age_loss: 0.6036 - val_race_loss: 0.6063 - val_gender_loss: 0.2509 - val_age_accuracy: 0.7447 - val_age_auc: 0.9498 - val_race_accuracy: 0.7953 - val_race_auc_1: 0.9522 - val_gender_accuracy: 0.8975 - val_gender_auc_2: 0.9627
# Epoch 71/150
# 474/474 [==============================] - 20s 43ms/step - loss: 3.4346 - age_loss: 0.6066 - race_loss: 0.6562 - gender_loss: 0.2384 - age_accuracy: 0.7426 - age_auc: 0.9493 - race_accuracy: 0.7691 - race_auc_1: 0.9450 - gender_accuracy: 0.8995 - gender_auc_2: 0.9655 - val_loss: 3.3790 - val_age_loss: 0.6114 - val_race_loss: 0.6068 - val_gender_loss: 0.2332 - val_age_accuracy: 0.7434 - val_age_auc: 0.9487 - val_race_accuracy: 0.7929 - val_race_auc_1: 0.9523 - val_gender_accuracy: 0.9086 - val_gender_auc_2: 0.9674
# Epoch 72/150
# 474/474 [==============================] - 22s 46ms/step - loss: 3.4361 - age_loss: 0.6078 - race_loss: 0.6540 - gender_loss: 0.2411 - age_accuracy: 0.7435 - age_auc: 0.9489 - race_accuracy: 0.7702 - race_auc_1: 0.9454 - gender_accuracy: 0.8975 - gender_auc_2: 0.9646 - val_loss: 3.4945 - val_age_loss: 0.6403 - val_race_loss: 0.6064 - val_gender_loss: 0.2394 - val_age_accuracy: 0.7325 - val_age_auc: 0.9444 - val_race_accuracy: 0.7932 - val_race_auc_1: 0.9522 - val_gender_accuracy: 0.9065 - val_gender_auc_2: 0.9659
# Epoch 73/150
# 474/474 [==============================] - 27s 57ms/step - loss: 3.4182 - age_loss: 0.6027 - race_loss: 0.6557 - gender_loss: 0.2377 - age_accuracy: 0.7489 - age_auc: 0.9499 - race_accuracy: 0.7690 - race_auc_1: 0.9451 - gender_accuracy: 0.8999 - gender_auc_2: 0.9656 - val_loss: 3.6689 - val_age_loss: 0.6836 - val_race_loss: 0.6070 - val_gender_loss: 0.2384 - val_age_accuracy: 0.7137 - val_age_auc: 0.9369 - val_race_accuracy: 0.7940 - val_race_auc_1: 0.9522 - val_gender_accuracy: 0.9047 - val_gender_auc_2: 0.9664
# Epoch 74/150
# 474/474 [==============================] - 22s 47ms/step - loss: 3.4314 - age_loss: 0.6110 - race_loss: 0.6422 - gender_loss: 0.2416 - age_accuracy: 0.7387 - age_auc: 0.9484 - race_accuracy: 0.7751 - race_auc_1: 0.9473 - gender_accuracy: 0.8983 - gender_auc_2: 0.9646 - val_loss: 3.8753 - val_age_loss: 0.7351 - val_race_loss: 0.6073 - val_gender_loss: 0.2381 - val_age_accuracy: 0.6920 - val_age_auc: 0.9280 - val_race_accuracy: 0.7918 - val_race_auc_1: 0.9523 - val_gender_accuracy: 0.9041 - val_gender_auc_2: 0.9663
# Epoch 75/150
# 474/474 [==============================] - 25s 52ms/step - loss: 3.4456 - age_loss: 0.6106 - race_loss: 0.6528 - gender_loss: 0.2417 - age_accuracy: 0.7387 - age_auc: 0.9486 - race_accuracy: 0.7702 - race_auc_1: 0.9455 - gender_accuracy: 0.8968 - gender_auc_2: 0.9645 - val_loss: 3.3149 - val_age_loss: 0.5931 - val_race_loss: 0.6127 - val_gender_loss: 0.2325 - val_age_accuracy: 0.7500 - val_age_auc: 0.9512 - val_race_accuracy: 0.7916 - val_race_auc_1: 0.9518 - val_gender_accuracy: 0.9110 - val_gender_auc_2: 0.9679
# Epoch 76/150
# 474/474 [==============================] - 22s 46ms/step - loss: 3.3687 - age_loss: 0.5977 - race_loss: 0.6364 - gender_loss: 0.2342 - age_accuracy: 0.7445 - age_auc: 0.9508 - race_accuracy: 0.7780 - race_auc_1: 0.9482 - gender_accuracy: 0.9010 - gender_auc_2: 0.9666 - val_loss: 4.2931 - val_age_loss: 0.8427 - val_race_loss: 0.5990 - val_gender_loss: 0.2368 - val_age_accuracy: 0.6502 - val_age_auc: 0.9093 - val_race_accuracy: 0.7971 - val_race_auc_1: 0.9536 - val_gender_accuracy: 0.9081 - val_gender_auc_2: 0.9669
# Epoch 82/150
# 474/474 [==============================] - 21s 44ms/step - loss: 3.3375 - age_loss: 0.5933 - race_loss: 0.6274 - gender_loss: 0.2302 - age_accuracy: 0.7497 - age_auc: 0.9512 - race_accuracy: 0.7781 - race_auc_1: 0.9499 - gender_accuracy: 0.9021 - gender_auc_2: 0.9678 - val_loss: 3.5724 - val_age_loss: 0.6636 - val_race_loss: 0.5965 - val_gender_loss: 0.2327 - val_age_accuracy: 0.7177 - val_age_auc: 0.9401 - val_race_accuracy: 0.7977 - val_race_auc_1: 0.9539 - val_gender_accuracy: 0.9070 - val_gender_auc_2: 0.9675
# Epoch 83/150
# 474/474 [==============================] - 21s 44ms/step - loss: 3.3680 - age_loss: 0.5980 - race_loss: 0.6352 - gender_loss: 0.2323 - age_accuracy: 0.7500 - age_auc: 0.9504 - race_accuracy: 0.7770 - race_auc_1: 0.9486 - gender_accuracy: 0.9024 - gender_auc_2: 0.9671 - val_loss: 3.5175 - val_age_loss: 0.6428 - val_race_loss: 0.6144 - val_gender_loss: 0.2459 - val_age_accuracy: 0.7288 - val_age_auc: 0.9435 - val_race_accuracy: 0.7908 - val_race_auc_1: 0.9518 - val_gender_accuracy: 0.9033 - val_gender_auc_2: 0.9646
# Epoch 84/150
# 474/474 [==============================] - 21s 44ms/step - loss: 3.3533 - age_loss: 0.5957 - race_loss: 0.6318 - gender_loss: 0.2269 - age_accuracy: 0.7475 - age_auc: 0.9510 - race_accuracy: 0.7820 - race_auc_1: 0.9488 - gender_accuracy: 0.9029 - gender_auc_2: 0.9688 - val_loss: 4.1090 - val_age_loss: 0.7970 - val_race_loss: 0.5987 - val_gender_loss: 0.2305 - val_age_accuracy: 0.6666 - val_age_auc: 0.9174 - val_race_accuracy: 0.7953 - val_race_auc_1: 0.9539 - val_gender_accuracy: 0.9097 - val_gender_auc_2: 0.9682
# Epoch 85/150
# 474/474 [==============================] - 20s 43ms/step - loss: 3.3171 - age_loss: 0.5863 - race_loss: 0.6327 - gender_loss: 0.2278 - age_accuracy: 0.7485 - age_auc: 0.9525 - race_accuracy: 0.7795 - race_auc_1: 0.9489 - gender_accuracy: 0.9042 - gender_auc_2: 0.9684 - val_loss: 3.3640 - val_age_loss: 0.6108 - val_race_loss: 0.5976 - val_gender_loss: 0.2435 - val_age_accuracy: 0.7418 - val_age_auc: 0.9487 - val_race_accuracy: 0.7963 - val_race_auc_1: 0.9539 - val_gender_accuracy: 0.9023 - val_gender_auc_2: 0.9652
# Epoch 86/150
# 474/474 [==============================] - 20s 43ms/step - loss: 3.3308 - age_loss: 0.5939 - race_loss: 0.6219 - gender_loss: 0.2235 - age_accuracy: 0.7495 - age_auc: 0.9512 - race_accuracy: 0.7846 - race_auc_1: 0.9507 - gender_accuracy: 0.9066 - gender_auc_2: 0.9697 - val_loss: 3.3590 - val_age_loss: 0.6130 - val_race_loss: 0.5893 - val_gender_loss: 0.2324 - val_age_accuracy: 0.7413 - val_age_auc: 0.9483 - val_race_accuracy: 0.8030 - val_race_auc_1: 0.9552 - val_gender_accuracy: 0.9137 - val_gender_auc_2: 0.9680
# Epoch 87/150
# 474/474 [==============================] - 21s 44ms/step - loss: 3.3172 - age_loss: 0.5879 - race_loss: 0.6289 - gender_loss: 0.2229 - age_accuracy: 0.7528 - age_auc: 0.9522 - race_accuracy: 0.7783 - race_auc_1: 0.9496 - gender_accuracy: 0.9062 - gender_auc_2: 0.9698 - val_loss: 3.4134 - val_age_loss: 0.6120 - val_race_loss: 0.6279 - val_gender_loss: 0.2342 - val_age_accuracy: 0.7471 - val_age_auc: 0.9484 - val_race_accuracy: 0.7844 - val_race_auc_1: 0.9491 - val_gender_accuracy: 0.9089 - val_gender_auc_2: 0.9677
# Epoch 88/150
# 474/474 [==============================] - 21s 44ms/step - loss: 3.3297 - age_loss: 0.5930 - race_loss: 0.6231 - gender_loss: 0.2280 - age_accuracy: 0.7483 - age_auc: 0.9512 - race_accuracy: 0.7814 - race_auc_1: 0.9503 - gender_accuracy: 0.9029 - gender_auc_2: 0.9685 - val_loss: 3.7979 - val_age_loss: 0.7179 - val_race_loss: 0.6019 - val_gender_loss: 0.2361 - val_age_accuracy: 0.7005 - val_age_auc: 0.9313 - val_race_accuracy: 0.7987 - val_race_auc_1: 0.9534 - val_gender_accuracy: 0.9070 - val_gender_auc_2: 0.9670
# Epoch 89/150
# 474/474 [==============================] - 21s 44ms/step - loss: 3.2999 - age_loss: 0.5838 - race_loss: 0.6280 - gender_loss: 0.2278 - age_accuracy: 0.7534 - age_auc: 0.9527 - race_accuracy: 0.7790 - race_auc_1: 0.9496 - gender_accuracy: 0.9063 - gender_auc_2: 0.9684 - val_loss: 3.2597 - val_age_loss: 0.5877 - val_race_loss: 0.5905 - val_gender_loss: 0.2338 - val_age_accuracy: 0.7481 - val_age_auc: 0.9521 - val_race_accuracy: 0.8014 - val_race_auc_1: 0.9548 - val_gender_accuracy: 0.9097 - val_gender_auc_2: 0.9676
# Epoch 90/150
# 474/474 [==============================] - 20s 42ms/step - loss: 3.2738 - age_loss: 0.5797 - race_loss: 0.6216 - gender_loss: 0.2246 - age_accuracy: 0.7544 - age_auc: 0.9534 - race_accuracy: 0.7838 - race_auc_1: 0.9505 - gender_accuracy: 0.9063 - gender_auc_2: 0.9694 - val_loss: 3.2299 - val_age_loss: 0.5801 - val_race_loss: 0.5910 - val_gender_loss: 0.2296 - val_age_accuracy: 0.7516 - val_age_auc: 0.9531 - val_race_accuracy: 0.8011 - val_race_auc_1: 0.9548 - val_gender_accuracy: 0.9118 - val_gender_auc_2: 0.9685
# Epoch 91/150
# ...
# Epoch 122/150
# 474/474 [==============================] - 21s 44ms/step - loss: 3
# Epoch 128/150
# 474/474 [==============================] - 22s 46ms/step - loss: 3.0381 - age_loss: 0.5416 - race_loss: 0.5676 - gender_loss: 0.2021 - age_accuracy: 0.7714 - age_auc: 0.9590 - race_accuracy: 0.7994 - race_auc_1: 0.9587 - gender_accuracy: 0.9164 - gender_auc_2: 0.9750 - val_loss: 3.7266 - val_age_loss: 0.6991 - val_race_loss: 0.6047 - val_gender_loss: 0.2317 - val_age_accuracy: 0.7158 - val_age_auc: 0.9352 - val_race_accuracy: 0.7963 - val_race_auc_1: 0.9531 - val_gender_accuracy: 0.9123 - val_gender_auc_2: 0.9692
# Epoch 129/150
# 474/474 [==============================] - 23s 49ms/step - loss: 3.0456 - age_loss: 0.5423 - race_loss: 0.5707 - gender_loss: 0.2041 - age_accuracy: 0.7727 - age_auc: 0.9588 - race_accuracy: 0.8018 - race_auc_1: 0.9580 - gender_accuracy: 0.9190 - gender_auc_2: 0.9746 - val_loss: 3.4478 - val_age_loss: 0.6344 - val_race_loss: 0.5913 - val_gender_loss: 0.2316 - val_age_accuracy: 0.7407 - val_age_auc: 0.9451 - val_race_accuracy: 0.8019 - val_race_auc_1: 0.9549 - val_gender_accuracy: 0.9139 - val_gender_auc_2: 0.9688
# Epoch 130/150
# 474/474 [==============================] - 23s 48ms/step - loss: 3.0547 - age_loss: 0.5427 - race_loss: 0.5757 - gender_loss: 0.2050 - age_accuracy: 0.7697 - age_auc: 0.9589 - race_accuracy: 0.8003 - race_auc_1: 0.9574 - gender_accuracy: 0.9162 - gender_auc_2: 0.9743 - val_loss: 3.1648 - val_age_loss: 0.5692 - val_race_loss: 0.5764 - val_gender_loss: 0.2338 - val_age_accuracy: 0.7609 - val_age_auc: 0.9545 - val_race_accuracy: 0.8069 - val_race_auc_1: 0.9568 - val_gender_accuracy: 0.9147 - val_gender_auc_2: 0.9689
# Epoch 131/150
# 474/474 [==============================] - 21s 45ms/step - loss: 3.0592 - age_loss: 0.5466 - race_loss: 0.5680 - gender_loss: 0.2081 - age_accuracy: 0.7696 - age_auc: 0.9582 - race_accuracy: 0.8013 - race_auc_1: 0.9585 - gender_accuracy: 0.9130 - gender_auc_2: 0.9737 - val_loss: 3.2678 - val_age_loss: 0.5937 - val_race_loss: 0.5797 - val_gender_loss: 0.2334 - val_age_accuracy: 0.7513 - val_age_auc: 0.9511 - val_race_accuracy: 0.8099 - val_race_auc_1: 0.9565 - val_gender_accuracy: 0.9137 - val_gender_auc_2: 0.9690
# Epoch 132/150
# 474/474 [==============================] - 23s 49ms/step - loss: 3.0614 - age_loss: 0.5452 - race_loss: 0.5738 - gender_loss: 0.1963 - age_accuracy: 0.7682 - age_auc: 0.9585 - race_accuracy: 0.7989 - race_auc_1: 0.9576 - gender_accuracy: 0.9192 - gender_auc_2: 0.9765 - val_loss: 3.2240 - val_age_loss: 0.5804 - val_race_loss: 0.5864 - val_gender_loss: 0.2300 - val_age_accuracy: 0.7564 - val_age_auc: 0.9529 - val_race_accuracy: 0.8051 - val_race_auc_1: 0.9561 - val_gender_accuracy: 0.9150 - val_gender_auc_2: 0.9698
# Epoch 133/150
# 474/474 [==============================] - 24s 50ms/step - loss: 3.0401 - age_loss: 0.5414 - race_loss: 0.5700 - gender_loss: 0.1945 - age_accuracy: 0.7725 - age_auc: 0.9591 - race_accuracy: 0.7983 - race_auc_1: 0.9583 - gender_accuracy: 0.9208 - gender_auc_2: 0.9771 - val_loss: 3.5425 - val_age_loss: 0.6635 - val_race_loss: 0.5750 - val_gender_loss: 0.2619 - val_age_accuracy: 0.7275 - val_age_auc: 0.9406 - val_race_accuracy: 0.8093 - val_race_auc_1: 0.9569 - val_gender_accuracy: 0.8986 - val_gender_auc_2: 0.9627
# Epoch 134/150
# 474/474 [==============================] - 22s 46ms/step - loss: 3.0004 - age_loss: 0.5325 - race_loss: 0.5669 - gender_loss: 0.2016 - age_accuracy: 0.7780 - age_auc: 0.9605 - race_accuracy: 0.8006 - race_auc_1: 0.9587 - gender_accuracy: 0.9188 - gender_auc_2: 0.9753 - val_loss: 3.1643 - val_age_loss: 0.5728 - val_race_loss: 0.5665 - val_gender_loss: 0.2347 - val_age_accuracy: 0.7595 - val_age_auc: 0.9541 - val_race_accuracy: 0.8159 - val_race_auc_1: 0.9582 - val_gender_accuracy: 0.9108 - val_gender_auc_2: 0.9690
# Epoch 135/150
# 474/474 [==============================] - 23s 49ms/step - loss: 3.0484 - age_loss: 0.5438 - race_loss: 0.5688 - gender_loss: 0.2021 - age_accuracy: 0.7676 - age_auc: 0.9587 - race_accuracy: 0.7983 - race_auc_1: 0.9584 - gender_accuracy: 0.9166 - gender_auc_2: 0.9750 - val_loss: 3.1973 - val_age_loss: 0.5797 - val_race_loss: 0.5702 - val_gender_loss: 0.2317 - val_age_accuracy: 0.7548 - val_age_auc: 0.9527 - val_race_accuracy: 0.8114 - val_race_auc_1: 0.9580 - val_gender_accuracy: 0.9126 - val_gender_auc_2: 0.9692
# Epoch 136/150
# 474/474 [==============================] - 23s 48ms/step - loss: 3.0129 - age_loss: 0.5383 - race_loss: 0.5602 - gender_loss: 0.1955 - age_accuracy: 0.7714 - age_auc: 0.9595 - race_accuracy: 0.8024 - race_auc_1: 0.9598 - gender_accuracy: 0.9210 - gender_auc_2: 0.9766 - val_loss: 3.2790 - val_age_loss: 0.5983 - val_race_loss: 0.5753 - val_gender_loss: 0.2288 - val_age_accuracy: 0.7455 - val_age_auc: 0.9507 - val_race_accuracy: 0.8101 - val_race_auc_1: 0.9573 - val_gender_accuracy: 0.9134 - val_gender_auc_2: 0.9693
# Epoch 137/150
# 474/474 [==============================] - 21s 45ms/step - loss: 3.0065 - age_loss: 0.5375 - race_loss: 0.5576 - gender_loss: 0.2020 - age_accuracy: 0.7731 - age_auc: 0.9595 - race_accuracy: 0.8026 - race_auc_1: 0.9601 - gender_accuracy: 0.9162 - gender_auc_2: 0.9751 - val_loss: 3.2840 - val_age_loss: 0.5989 - val_race_loss: 0.5768 - val_gender_loss: 0.2315 - val_age_accuracy: 0.7468 - val_age_auc: 0.9503 - val_race_accuracy: 0.8133 - val_race_auc_1: 0.9567 - val_gender_accuracy: 0.9160 - val_gender_auc_2: 0.9693
# Epoch 138/150
# 474/474 [==============================] - 22s 47ms/step - loss: 3.0180 - age_loss: 0.5373 - race_loss: 0.5662 - gender_loss: 0.1956 - age_accuracy: 0.7754 - age_auc: 0.9595 - race_accuracy: 0.8028 - race_auc_1: 0.9588 - gender_accuracy: 0.9167 - gender_auc_2: 0.9767 - val_loss: 3.2466 - val_age_loss: 0.5857 - val_race_loss: 0.5874 - val_gender_loss: 0.2287 - val_age_accuracy: 0.7532 - val_age_auc: 0.9522 - val_race_accuracy: 0.8075 - val_race_auc_1: 0.9555 - val_gender_accuracy: 0.9129 - val_gender_auc_2: 0.9699
# Epoch 139/150
# 474/474 [==============================] - 22s 47ms/step - loss: 3.0167 - age_loss: 0.5364 - race_loss: 0.5675 - gender_loss: 0.1984 - age_accuracy: 0.7719 - age_auc: 0.9595 - race_accuracy: 0.8002 - race_auc_1: 0.9585 - gender_accuracy: 0.9173 - gender_auc_2: 0.9760 - val_loss: 3.1840 - val_age_loss: 0.5742 - val_race_loss: 0.5763 - val_gender_loss: 0.2287 - val_age_accuracy: 0.7572 - val_age_auc: 0.9538 - val_race_accuracy: 0.8117 - val_race_auc_1: 0.9568 - val_gender_accuracy: 0.9174 - val_gender_auc_2: 0.9702
# Epoch 140/150
# 474/474 [==============================] - 22s 46ms/step - loss: 2.9860 - age_loss: 0.5315 - race_loss: 0.5601 - gender_loss: 0.1965 - age_accuracy: 0.7733 - age_auc: 0.9603 - race_accuracy: 0.8035 - race_auc_1: 0.9598 - gender_accuracy: 0.9212 - gender_auc_2: 0.9765 - val_loss: 3.4303 - val_age_loss: 0.6339 - val_race_loss: 0.5809 - val_gender_loss: 0.2344 - val_age_accuracy: 0.7397 - val_age_auc: 0.9457 - val_race_accuracy: 0.8091 - val_race_auc_1: 0.9565 - val_gender_accuracy: 0.9113 - val_gender_auc_2: 0.9684
# Epoch 141/150
# 474/474 [==============================] - 22s 46ms/step - loss: 2.9733 - age_loss: 0.5296 - race_loss: 0.5568 - gender_loss: 0.1960 - age_accuracy: 0.7758 - age_auc: 0.9608 - race_accuracy: 0.8041 - race_auc_1: 0.9601 - gender_accuracy: 0.9200 - gender_auc_2: 0.9765 - val_loss: 3.4965 - val_age_loss: 0.6518 - val_race_loss: 0.5775 - val_gender_loss: 0.2300 - val_age_accuracy: 0.7283 - val_age_auc: 0.9428 - val_race_accuracy: 0.8117 - val_race_auc_1: 0.9570 - val_gender_accuracy: 0.9168 - val_gender_auc_2: 0.9699
# Epoch 142/150
# 474/474 [==============================] - 22s 47ms/step - loss: 2.9869 - age_loss: 0.5317 - race_loss: 0.5606 - gender_loss: 0.1934 - age_accuracy: 0.7776 - age_auc: 0.9605 - race_accuracy: 0.8052 - race_auc_1: 0.9597 - gender_accuracy: 0.9207 - gender_auc_2: 0.9771 - val_loss: 3.1934 - val_age_loss: 0.5804 - val_race_loss: 0.5657 - val_gender_loss: 0.2310 - val_age_accuracy: 0.7569 - val_age_auc: 0.9530 - val_race_accuracy: 0.8157 - val_race_auc_1: 0.9585 - val_gender_accuracy: 0.9163 - val_gender_auc_2: 0.9699
# Epoch 143/150
# 474/474 [==============================] - 20s 43ms/step - loss: 2.9807 - age_loss: 0.5299 - race_loss: 0.5617 - gender_loss: 0.1875 - age_accuracy: 0.7756 - age_auc: 0.9607 - race_accuracy: 0.8004 - race_auc_1: 0.9595 - gender_accuracy: 0.9225 - gender_auc_2: 0.9786 - val_loss: 3.2865 - val_age_loss: 0.5949 - val_race_loss: 0.5893 - val_gender_loss: 0.2313 - val_age_accuracy: 0.7497 - val_age_auc: 0.9511 - val_race_accuracy: 0.8056 - val_race_auc_1: 0.9557 - val_gender_accuracy: 0.9137 - val_gender_auc_2: 0.9698
# Epoch 144/150
# 474/474 [==============================] - 22s 46ms/step - loss: 2.9957 - age_loss: 0.5322 - race_loss: 0.5648 - gender_loss: 0.1987 - age_accuracy: 0.7771 - age_auc: 0.9604 - race_accuracy: 0.8020 - race_auc_1: 0.9592 - gender_accuracy: 0.9189 - gender_auc_2: 0.9758 - val_loss: 3.2229 - val_age_loss: 0.5852 - val_race_loss: 0.5724 - val_gender_loss: 0.2343 - val_age_accuracy: 0.7534 - val_age_auc: 0.9528 - val_race_accuracy: 0.8125 - val_race_auc_1: 0.9579 - val_gender_accuracy: 0.9134 - val_gender_auc_2: 0.9691
# Epoch 145/150
# 474/474 [==============================] - 21s 45ms/step - loss: 2.9560 - age_loss: 0.5263 - race_loss: 0.5545 - gender_loss: 0.1899 - age_accuracy: 0.7804 - age_auc: 0.9611 - race_accuracy: 0.8032 - race_auc_1: 0.9604 - gender_accuracy: 0.9241 - gender_auc_2: 0.9779 - val_loss: 3.2752 - val_age_loss: 0.5885 - val_race_loss: 0.5985 - val_gender_loss: 0.2332 - val_age_accuracy: 0.7534 - val_age_auc: 0.9522 - val_race_accuracy: 0.8038 - val_race_auc_1: 0.9552 - val_gender_accuracy: 0.9131 - val_gender_auc_2: 0.9693
# Epoch 146/150
# 474/474 [==============================] - 22s 46ms/step - loss: 2.9959 - age_loss: 0.5317 - race_loss: 0.5662 - gender_loss: 0.1981 - age_accuracy: 0.7738 - age_auc: 0.9603 - race_accuracy: 0.7994 - race_auc_1: 0.9589 - gender_accuracy: 0.9185 - gender_auc_2: 0.9760 - val_loss: 3.2020 - val_age_loss: 0.5749 - val_race_loss: 0.5865 - val_gender_loss: 0.2283 - val_age_accuracy: 0.7603 - val_age_auc: 0.9540 - val_race_accuracy: 0.8059 - val_race_auc_1: 0.9555 - val_gender_accuracy: 0.9171 - val_gender_auc_2: 0.9700
# Epoch 147/150
# 474/474 [==============================] - 27s 57ms/step - loss: 2.9502 - age_loss: 0.5228 - race_loss: 0.5595 - gender_loss: 0.1965 - age_accuracy: 0.7736 - age_auc: 0.9617 - race_accuracy: 0.8025 - race_auc_1: 0.9598 - gender_accuracy: 0.9175 - gender_auc_2: 0.9765 - val_loss: 3.2867 - val_age_loss: 0.5923 - val_race_loss: 0.5959 - val_gender_loss: 0.2363 - val_age_accuracy: 0.7505 - val_age_auc: 0.9517 - val_race_accuracy: 0.8043 - val_race_auc_1: 0.9546 - val_gender_accuracy: 0.9131 - val_gender_auc_2: 0.9685
# Epoch 148/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.9910 - age_loss: 0.5359 - race_loss: 0.5524 - gender_loss: 0.1899 - age_accuracy: 0.7760 - age_auc: 0.9598 - race_accuracy: 0.8056 - race_auc_1: 0.9606 - gender_accuracy: 0.9226 - gender_auc_2: 0.9779 - val_loss: 3.2008 - val_age_loss: 0.5810 - val_race_loss: 0.5695 - val_gender_loss: 0.2270 - val_age_accuracy: 0.7569 - val_age_auc: 0.9532 - val_race_accuracy: 0.8122 - val_race_auc_1: 0.9580 - val_gender_accuracy: 0.9171 - val_gender_auc_2: 0.9700
# Epoch 149/150
# 474/474 [==============================] - 21s 45ms/step - loss: 2.9556 - age_loss: 0.5278 - race_loss: 0.5505 - gender_loss: 0.1882 - age_accuracy: 0.7771 - age_auc: 0.9610 - race_accuracy: 0.8076 - race_auc_1: 0.9610 - gender_accuracy: 0.9213 - gender_auc_2: 0.9784 - val_loss: 3.3629 - val_age_loss: 0.6036 - val_race_loss: 0.6166 - val_gender_loss: 0.2373 - val_age_accuracy: 0.7466 - val_age_auc: 0.9502 - val_race_accuracy: 0.7950 - val_race_auc_1: 0.9513 - val_gender_accuracy: 0.9145 - val_gender_auc_2: 0.9682
# Epoch 150/150
# 474/474 [==============================] - 21s 44ms/step - loss: 2.9614 - age_loss: 0.5271 - race_loss: 0.5563 - gender_loss: 0.1843 - age_accuracy: 0.7772 - age_auc: 0.9610 - race_accuracy: 0.8035 - race_auc_1: 0.9602 - gender_accuracy: 0.9245 - gender_auc_2: 0.9793 - val_loss: 3.2308 - val_age_loss: 0.5883 - val_race_loss: 0.5696 - val_gender_loss: 0.2307 - val_age_accuracy: 0.7579 - val_age_auc: 0.9525 - val_race_accuracy: 0.8141 - val_race_auc_1: 0.9582 - val_gender_accuracy: 0.9110 - val_gender_auc_2: 0.9702
#
# Elapsed Time:  0:54:13.896360

# %%
# save the model to disk
#Source: (https://www.tensorflow.org/api_docs/python/tf/keras/models/save_model)
# Save the entire model as a SavedModel.

# save(): To create a SavedModel folder `saved_model`, containing "assets", "saved_model.pb" & "variables".
# The model architecture, and training configuration (including the optimizer, losses, and metrics) are stored in `saved_model.pb`.
# The weights are saved in the `variables/` directory.
# path = "../models/saved_model/latest_model"

#model.save('../models/saved_model/latest_model/you_model_name.tf')

f_name = r'CNN-model-'
f_time = datetime.now().strftime("%Y-%m-%d_%I-%M-%S_%p")
file = f_name + f_time + '.h5'
filepath = '../ModelTrainingService/models/' + file
model.save(filepath, include_optimizer=True)
print("[INFO] Model \"%s\" saved (Saving into the path takes few minutes)." % file)
# Out:
# [INFO] Model "CNN-model-2022-12-30_02-35-58_AM.h5" saved (Saving into the path takes few minutes).

# %%
# Load the latest trained model
from keras.models import load_model

#loaded_model = load_model('../models/saved_model/latest_model')
#loaded_model = load_model('../models/saved_model/latest_model/you_model_name.tf')
loaded_model = load_model(filepath, compile=False)
print("[INFO] Model \"%s\" loaded" % file)
# Out:
# [INFO] Model "CNN-model-2022-12-30_02-35-58_AM.h5" loaded

# %%
# Predict the age group and the gender of the person from aligned & cropped profile face picture.

from keras.preprocessing import image
from keras.utils import load_img
from keras.preprocessing.image import ImageDataGenerator

# Load the image and size it.
def loadImage(filepath):
  test_img = load_img(filepath, target_size=(image_width, image_height, 3))
  test_img = img_to_array(test_img)
  test_img /= 255
  test_img = np.expand_dims(test_img, axis = 0)

  return test_img

import random as rn
from PIL import Image, ImageFont

# To choose image randomly from dataset
path=df['file']
picture = rn.choice(path)

#picture='../models/test_img/kenny-rogers.jpg' # Change the path for other image files if you would like to see more.
age_prediction, race_prediction, gender_prediction = loaded_model.predict(loadImage(picture))

print('Age_prediction: ', (age_prediction * 100), '%')
print('Race_prediction: ', (race_prediction * 100), '%')
print('Gender_prediction: ', (gender_prediction * 100), '%')
print(picture)

img = load_img(picture)
plt.imshow(img)
plt.show()
max = -1
count = 0

for i in age_prediction[0]:
    if i > max:
        max = i
        temp = count
    count+=1

#Conditions for outputs
if temp == 0:
    print('0-24 yrs old')
if temp == 1:
    print('25-49 yrs old')
if temp == 2:
    print('50-74 yrs old')
if temp == 3:
    print('75-99 yrs old')
if temp == 4:
    print('100-124 yrs old')

if gender_prediction[0][0] > gender_prediction[0][1]:
  print('Male')
else:
  print('Female')
# Out:
# 1/1 [==============================] - 0s 55ms/step
# Age_prediction:  [[4.6734965e-01 8.3377281e+01 1.6148973e+01 6.2335362e-03 1.7340959e-04]] %
# Race_prediction:  [[1.0271772e+00 9.4578835e+01 1.8388690e-02 3.7635286e+00 6.1207116e-01]] %
# Gender_prediction:  [[9.9987686e+01 1.2295882e-02]] %
# ../ModelTrainingService/input/utkface-new/UTKFace\36_0_1_20170116203518157.jpg.chip.jpg
# 25-49 yrs old
# Male

# %% [markdown]
# ## Evaluating our model on the validation and test dataset

# %%
# To returns the loss value & metric values for the model in test dataset
test_batch_size = 128
test_generator = data_generator.generate_images(test_idx,
                                                is_training=False,
                                                batch_size=test_batch_size)

age_pred, race_pred, gender_pred = model.predict(test_generator,
                                                 steps=len(test_idx)//test_batch_size)
# print('Age_on_test: ', len(age_pred))
# print('Gender_on_test: ', len(gender_pred))
# print('Race_on_test: ', len(race_pred))
# Out:
# 37/37 [==============================] - 10s 240ms/step

# %%
test_batch_size = 128

test_generator  = data_generator.generate_images(test_idx,
                                                is_training=False,
                                                batch_size=test_batch_size)

images, age_true, race_true, gender_true = [], [], [], []

for test_batch in test_generator:
    image = test_batch[0]
    labels = test_batch[1]

    images.extend(image)
    age_true.extend(labels[0])
    race_true.extend(labels[1])
    gender_true.extend(labels[2])

age_true = np.array(age_true)
race_true = np.array(race_true)
gender_true = np.array(gender_true)

race_true, gender_true = race_true.argmax(axis=-1), gender_true.argmax(axis=-1)
race_pred, gender_pred = race_pred.argmax(axis=-1), gender_pred.argmax(axis=-1)

age_true = age_true.argmax(axis=-1) # * data_generator.max_age
age_pred = age_pred.argmax(axis=-1) # * data_generator.max_age

# %%
# Evaluate on validation data
val_results = {}
val_scores = model.evaluate(valid_gen, steps=3794, verbose=1, batch_size=32)
print('\nEvaluation results on validation dataset...')
dict(zip(model.metrics_names, val_scores))
# val_results = dict(zip(model.metrics_names, val_scores))
# print('\n')
# for key, value in val_results.items():
#   print("%s: %s" % (key, round(value*100, 2)), '%')
# Out:
# 3794/3794 [==============================] - 137s 36ms/step - loss: 3.2256 - age_loss: 0.5879 - race_loss: 0.5672 - gender_loss: 0.2310 - age_accuracy: 0.7578 - age_auc: 0.9525 - race_accuracy: 0.8150 - race_auc_1: 0.9585 - gender_accuracy: 0.9109 - gender_auc_2: 0.9702
#
# Evaluation results on validation dataset...
# {'loss': 3.225595712661743,
#  'age_loss': 0.5879279971122742,
#  'race_loss': 0.5671889781951904,
#  'gender_loss': 0.23096856474876404,
#  'age_accuracy': 0.7577754259109497,
#  'age_auc': 0.9525021910667419,
#  'race_accuracy': 0.8149710297584534,
#  'race_auc_1': 0.9584787487983704,
#  'gender_accuracy': 0.9109119772911072,
#  'gender_auc_2': 0.9702023267745972}

# %%
# Evaluate on test data
test_gen = data_generator.generate_images(test_idx,
                                           is_training=True,
                                           batch_size=32)

test_results = {}
test_scores = model.evaluate(test_gen, steps=4742, verbose=1, batch_size=32)
print('\nEvaluation results on test dataset...')
dict(zip(model.metrics_names, test_scores))
# test_results = dict(zip(model.metrics_names, val_scores))
# print('\n')
# for key, value in test_results.items():
#   print("%s: %s" % (key, round(value*100, 2)), '%')
# Out:
# 4742/4742 [==============================] - 166s 35ms/step - loss: 3.1803 - age_loss: 0.5745 - race_loss: 0.5738 - gender_loss: 0.2166 - age_accuracy: 0.7585 - age_auc: 0.9545 - race_accuracy: 0.8064 - race_auc_1: 0.9581 - gender_accuracy: 0.9108 - gender_auc_2: 0.9733
#
# Evaluation results on test dataset...
# {'loss': 3.1802899837493896,
#  'age_loss': 0.5744861364364624,
#  'race_loss': 0.5737930536270142,
#  'gender_loss': 0.2165517508983612,
#  'age_accuracy': 0.758540689945221,
#  'age_auc': 0.9544901847839355,
#  'race_accuracy': 0.8064107894897461,
#  'race_auc_1': 0.958113968372345,
#  'gender_accuracy': 0.910797119140625,
#  'gender_auc_2': 0.9733145833015442}

# %%
# Classification report for gender feature
from sklearn.metrics import classification_report, confusion_matrix
print('Classification Report for "Age"\n')
classification_report_gender = classification_report(gender_true, gender_pred, target_names=dataset_dict['gender_temp'].keys())
print(classification_report_gender)
# Out:
# Classification Report for "Age"
#
#               precision    recall  f1-score   support
#
#         male       0.93      0.89      0.91      2484
#       female       0.89      0.93      0.91      2252
#
#     accuracy                           0.91      4736
#    macro avg       0.91      0.91      0.91      4736
# weighted avg       0.91      0.91      0.91      4736

# %%
# Classification report for age feature
classification_report_gender = classification_report(age_true, age_pred, target_names=dataset_dict['age_id'].keys())
int(classification_report_gender)
#print('Classification Report for "Gender"\n')
# Out:
# C:\Users\edizg\dit825-age-detection\venv\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# C:\Users\edizg\dit825-age-detection\venv\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# C:\Users\edizg\dit825-age-detection\venv\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 3
#       1 # Classification report for age feature
#       2 classification_report_gender = classification_report(age_true, age_pred, target_names=dataset_dict['age_id'].keys())
# ----> 3 int(classification_report_gender)
#       4 #print('Classification Report for "Gender"\n')
#
# ValueError: invalid literal for int() with base 10: '              precision    recall  f1-score   support\n\n        0-24       0.84      0.71      0.77      1382\n       25-49       0.77      0.83      0.80      2333\n       50-74       0.65      0.6

# %%
# Age ROC curves (Multiclass classification)
# Source: https://stackoverflow.com/questions/39685740/calculate-sklearn-roc-auc-score-for-multi-class
from sklearn.metrics import accuracy_score
age_groups = ['0-24', '25-49','50-74','75-99', '100-124']
def roc_auc_score_multiclass(age_true, age_pred, average = "macro"):

  #creating a set of all the unique classes using the actual class list
  unique_class = set(age_true)
  roc_auc_dict = {}

  for per_class in unique_class:
    #creating a list of all the classes except the current class
    other_class = [x for x in unique_class if x != per_class]

    #marking the current class as 1 and all other classes as 0
    new_actual_class = [0 if x in other_class else 1 for x in age_true]
    new_pred_class = [0 if x in other_class else 1 for x in age_pred]

    #using the sklearn metrics method to calculate the roc_auc_score
    fpr_age, tpr_age, threshold_age = roc_curve(new_actual_class, new_pred_class)
    roc_auc = roc_auc_score(new_actual_class, new_pred_class, average = average)
    roc_auc_dict[per_class] = roc_auc


    # plotting
    plt.plot(fpr_age, tpr_age, linestyle='-',color='red', label=f'Area Under ROC Curve : {roc_auc:.3f}')
    plt.plot([0, 1], [0, 1], color='blue', linestyle='--', label='Baseline')
    plt.title('Age group ' + age_groups[per_class] + ' ROC curve')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive rate')
    plt.legend(loc='best', fancybox=True,)
    save_name = 'metrics_figures/ROC_curve_age_group_' + age_groups[per_class] + '.png'
    plt.savefig(save_name, bbox_inches='tight')
    plt.show()
    plt.close()

  return roc_auc_dict

roc_auc_multiclass = roc_auc_score_multiclass(age_true, age_pred)
acc = accuracy_score(age_true, age_pred)

for i in roc_auc_multiclass:
  print('Roc_Auc_score for age group', age_groups[i], ': {:.0%}'.format(roc_auc_multiclass[i]))
# Out:
# Roc_Auc_score for age group 0-24 : 83%
# Roc_Auc_score for age group 25-49 : 80%
# Roc_Auc_score for age group 50-74 : 81%
# Roc_Auc_score for age group 75-99 : 78%
# Roc_Auc_score for age group 100-124 : 50%

# %%
# Gender ROC curves (Binary classification)
from sklearn.metrics import roc_auc_score, roc_curve

fpr_gender, tpr_gender, threshold_gender = roc_curve(gender_true, gender_pred)
auc_score_gender = roc_auc_score(gender_true, gender_pred)

# plotting
plt.plot(fpr_gender, tpr_gender, linestyle='-',color='green', label=f'Area Under ROC Curve : {auc_score_gender:.3f}')
plt.plot([0, 1], [0, 1], color='blue', linestyle='--', label='Baseline')
plt.title('Gender ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best', fancybox=True,)
plt.savefig(fname='metrics_figures/ROC_curve_gender.png', bbox_inches='tight')
plt.show()
plt.close()

# %%
# Confusion matrix for age and gender (true vs predicted)
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools

# Source= https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html#sphx-glr-auto-examples-model-selection-plot-confusion-matrix-py
def plot_confusion_matrix(cm,
                          classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm,
               interpolation='nearest',
               cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if title == 'Confusion Matrix for "Age" (Multiclass Classification)':
      plt.savefig(fname='metrics_figures/Conf_Mtrx_age.png', bbox_inches='tight')
    else:
      plt.savefig(fname='metrics_figures/Conf_Mtrx_gender.png', bbox_inches='tight')
    plt.show()
    plt.close()

print('Total age count in test dataset: %s' % len(age_pred), '\n')
cm_age = confusion_matrix(age_true, age_pred)
cm_age_plot_labels = ['0-24', '25-49', '50-74', '75-99', '100-124']
plot_confusion_matrix(cm=cm_age, classes=cm_age_plot_labels, title='Confusion Matrix for "Age" (Multiclass Classification)')

print('Total gender count in test dataset: %s' % len(gender_pred), '\n')
cm_gender = confusion_matrix(gender_true, gender_pred)
cm_gender_plot_labels = ['male', 'female']
plot_confusion_matrix(cm=cm_gender, classes=cm_gender_plot_labels, title='Confusion Matrix for "Gender" (Binary Classification)')
# Out:
# Total age count in test dataset: 4736
#
# Confusion matrix, without normalization
# [[ 976  388   17    1    0]
#  [ 174 1940  214    5    0]
#  [   8  182  568   63    0]
#  [   0    4   79  109    0]
#  [   0    0    2    6    0]]
# Total gender count in test dataset: 4736
#
# Confusion matrix, without normalization
# [[2216  268]
#  [ 155 2097]]

# %%
# Age accuracy
plt.plot(history.history['age_accuracy'])
plt.plot(history.history['val_age_accuracy'])
plt.title('Age Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='best', fancybox=True)
plt.savefig(fname='metrics_figures/accuracy_age.png', bbox_inches='tight')
plt.show()
plt.close()

# %%
# Gender accuracy
plt.plot(history.history['gender_accuracy'])
plt.plot(history.history['val_gender_accuracy'])
plt.title('Gender Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='best', fancybox=True)
plt.savefig(fname='metrics_figures/accuracy_gender.png', bbox_inches='tight')
plt.show()
plt.close()

# %%
# Overall loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Overall Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='best', fancybox=True)
plt.savefig(fname='metrics_figures/overall_loss.png', bbox_inches='tight')
plt.show()
plt.close()
