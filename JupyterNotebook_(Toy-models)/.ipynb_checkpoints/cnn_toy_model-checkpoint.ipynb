# %% [markdown]
# # Age & Gender Detection with CNN
#
# **Dataset : UTKFace**
#
# UTKFace dataset is a large-scale face dataset with range from 0 to 116 years old. It consists of over 23,708 face images with labels of age, gender, and ethnicity. The images cover large variation in pose, facial expression, illumination, occlusion, resolution, etc.
#
# Since the dataset is `aligned and cropped` faces available to train the model. Have to say that any face input for testing must be cropped and aligned vertically to large extent.

# %%
# Essential libraries
import numpy as np
import pandas as pd
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras import applications,activations
#from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.preprocessing import image
from keras import optimizers,utils
from keras.utils import plot_model
from keras.models import Sequential, Model
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D,BatchNormalization,ZeroPadding2D, Input
from keras.layers import Conv2D, Activation,MaxPooling2D
from keras import backend as k
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping

# %%
# Mounting the directory for the dataset to be read.
dataset_folder = '../input/utkface-new/UTKFace/'
training_split = 0.8
image_width = image_height = 224

dataset_dict = {
    'race_id': {0: 'white', 1: 'black', 2: 'asian', 3: 'indian', 4: 'others'},
    'gender_id': {0: 'male', 1: 'female'}
}

dataset_dict['gender_temp'] = dict((g, i) for i, g in dataset_dict['gender_id'].items())    # (Gender: id)
dataset_dict['race_temp'] = dict((r, i) for i, r in dataset_dict['race_id'].items())        # (Race: id)

# %%
# Function to extract the data from our dataset by iterating over each file of the UTK dataset and
# return a Pandas Dataframe with all the fields (age, gender and sex).

def parse_dataset(dataset_path, ext='jpg'):

    def parse_info_from_file(path):  #Parsing info from a file

        try:
            file_name = os.path.split(path)[1]
            file_name = os.path.splitext(file_name)[0]
            age, gender, race, _ = file_name.split('_')

            return int(age), dataset_dict['gender_id'][int(gender)], dataset_dict['race_id'][int(race)]
        except Exception as ex:
            return None, None, None

    files = glob.glob(os.path.join(dataset_path, "*.%s" % ext))

    records = []
    for file in files:
        info = parse_info_from_file(file)
        records.append(info) # To place new items in the available space

    df = pd.DataFrame(records)
    df['file'] = files
    df.columns = ['age', 'gender', 'race', 'file']


    df = df.dropna() # To remove the rows that contains NULL values.

    return df

# %%
df = parse_dataset(dataset_folder)
df.head()
# Out:
#    age  gender   race                                               file
# 0  100    male  white  ../input/utkface-new/UTKFace\100_0_0_201701122...
# 1  100    male  white  ../input/utkface-new/UTKFace\100_0_0_201701122...
# 2  100  female  white  ../input/utkface-new/UTKFace\100_1_0_201701101...
# 3  100  female  white  ../input/utkface-new/UTKFace\100_1_0_201701122...
# 4  100  female  white  ../input/utkface-new/UTKFace\100_1_0_201701122...

# %%
df.info()       # No NAN values, means our dataset is already clean.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23708 entries, 0 to 23707
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     23708 non-null  int64
#  1   gender  23708 non-null  object
#  2   race    23708 non-null  object
#  3   file    23708 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 741.0+ KB

# %%
df.describe() # Lower percentile - 25, median - 50 & upper percentile - 75 (for numerical data)
# Out:
#                 age
# count  23708.000000
# mean      33.303484
# std       19.886112
# min        1.000000
# 25%       23.000000
# 50%       29.000000
# 75%       45.000000
# max      116.000000

# %%
ages = df['age']
nbins = 10
plt.hist(ages,nbins,color='yellow',histtype='bar')
plt.show()

# Since the population is mostly between 20-30 age group, the dataset is not very well-balanced.

# %%
x = (df.gender=='male').sum()
y = (df.gender=='female').sum()
gender = [x,y]
labels = ['male','female']
colors = [ 'y', 'g']
explode = (0, 0.2)  # explode the 2nd slice (i.e. 'female')
plt.pie(gender,labels = labels,
        colors = colors,
        explode=explode,
        radius=3,
        shadow=True,
        autopct='%.1f%%',
        textprops={'color':"gray", 'size':20},
        startangle=90)
plt.legend(gender, bbox_to_anchor=(1.7, 1.7), fontsize='xx-large')
plt.show()

# Uniform distribution to a large extent. Although, males slightly exceed females in numbers.No need to change gender in data.
# Pretty well-balanced ! Let's also visualize this on a bar graph (to get better understanding of numbers)

# %%
# Males ~ Over 12k & females ~ Close to 12k
sns.countplot(x='gender', data=df);

# %%
# Mean age by gender
df.groupby(['gender']).mean()
# Out:
#               age
# gender
# female  30.684280
# male    35.695666

# %%
white = (df.race=='white').sum()
black = (df.race=='black').sum()
asian = (df.race=='asian').sum()
indian = (df.race=='indian').sum()
others = (df.race=='others').sum()

gender = [white,black,asian,indian,others]
labels = ['white','black','asian','indian','others']
colors = [ 'y', 'g','b','r','m']
plt.pie(gender,
        labels = labels,
        colors = colors,
        radius=3,
        shadow=True,
        autopct='%.1f%%',
        textprops={'color':"black", 'size':20},
        startangle=90)
plt.show()

# %%
# Mean age by race
df.groupby(['race']).mean()
# Out:
#               age
# race
# asian   25.877729
# black   33.861498
# indian  31.540241
# others  23.169031
# white   37.980949

# %%
# Gives the mean age of both genders of all races
sns.catplot(x='race', y='age', hue='gender', data=df,kind='bar', height=10);

# %%
# We see that most of the males are between 25 and 55, whereas most of the females are between 20 and 40.
# Grouping by race, there is good amount of variations in different races.
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
_ = sns.boxplot(data=df, x='gender', y='age', ax=ax1)
_ = sns.boxplot(data=df, x='race', y='age', ax=ax2)

# %%
df['age'] = df['age']//25

''' This basically makes 5 divisions in age-groups -
1. 0-24
2. 25-49
3. 50-74
4. 75-99
5. 100-124 '''

x = (df.age==0).sum()
y = (df.age==1).sum()
z = (df.age==2).sum()
a = (df.age==3).sum()
b = (df.age==4).sum()
c = (df.age==5).sum()

print(x,' ', y,' ', z,' ', a,' ', b, ' ', c,' ')
# Out:
# 6903   11816   3990   967   32   0

# %%
df.head()
# Out:
#    age  gender   race                                               file
# 0    4    male  white  ../input/utkface-new/UTKFace\100_0_0_201701122...
# 1    4    male  white  ../input/utkface-new/UTKFace\100_0_0_201701122...
# 2    4  female  white  ../input/utkface-new/UTKFace\100_1_0_201701101...
# 3    4  female  white  ../input/utkface-new/UTKFace\100_1_0_201701122...
# 4    4  female  white  ../input/utkface-new/UTKFace\100_1_0_201701122...

# %%
# Data image generator
from keras.utils import to_categorical
from PIL import Image, ImageFont
p = np.random.permutation(len(df))

# Train_idx, valid_idx, for training the dataset with over 20k images by generating batches with images to train and validate at the same time.
train_up_to = int(len(df) * training_split)
train_idx = p[:train_up_to]
val_idx = p[train_up_to:]

# converts temps to ids
df['gender_id'] = df['gender'].map(lambda gender: dataset_dict['gender_temp'][gender])
df['race_id'] = df['race'].map(lambda race: dataset_dict['race_temp'][race])

# Minor preprocessing on the image to transfer into the model.
def preprocess_image(img_path):

    im = Image.open(img_path)
    im = im.resize((image_width, image_height))
    im = np.array(im) / 255.0

    return im

# To generate a batch with images when training/validating our model.
def generate_images(image_idx, is_training, batch_size=16):

    images, ages, races, genders = [], [], [], [] # arrays for the batched data

    while True:
        for idx in image_idx:
            person = df.iloc[idx]

            age = person['age']
            race = person['race_id']
            gender = person['gender_id']
            file = person['file']

            im = preprocess_image(file)

            races.append(to_categorical(race, len(dataset_dict['race_id'])))
            genders.append(to_categorical(gender, len(dataset_dict['gender_id'])))
            ages.append(to_categorical(age,5))
            images.append(im)

            # yielding condition: To return the yielded value (images) to the caller when you execute the function below for training and validating.
            if len(images) >= batch_size:
                yield np.array(images), [np.array(ages), np.array(genders)]
                images, ages, genders = [], [], []

        if not is_training:
            break

# %%
# CNN Model Architecture by splitting the labels (age and gender) for flatten, dropout and activation of the layers.
from keras.models import Model
from keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import SeparableConv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Dropout
from keras.layers import SpatialDropout2D
from keras.layers.core import Lambda
from keras.layers.core import Dense
from keras.layers import Flatten
from keras.layers import Input
from keras.regularizers import l2

import tensorflow as tf

# SeparableConv2D: A variation of the traditional convolution that was to compute it faster than conv2D.
# "same" vs "valid": Output size is the "same" as input size, while valid is padding.
# Source for more detail about padding: https://stackoverflow.com/questions/37674306/what-is-the-difference-between-same-and-valid-padding-in-tf-nn-max-pool-of-t
# BatchNormalization: To speed up training and to use higher learning rates, making learning easier and to distribute the data uniformly across a mean
#                     that the network sees best.
# MaxPooling2D: To downsample the input along its spatial dimensions (height and width) by taking the maximum value over an input window defined by pool_size for each channel.
# SpatialDropout2D: To drop the entire 2D feature maps instead of individual elements as dropout does.
# Strides: The window for shifting.
# Source: https://stackoverflow.com/questions/59634780/correct-order-for-spatialdropout2d-batchnormalization-and-activation-function

def hidden_layers(inputs):

    # x = SeparableConv2D(32, (3, 3), padding="same")(inputs)
    x = Conv2D(32, (3, 3), padding="same")(inputs)
    x = MaxPooling2D(pool_size=(3, 3))(x)
    x = Activation("relu")(x)
    x = BatchNormalization(axis=-1)(x)

    # x = SeparableConv2D(64, (3, 3), padding="same")(inputs)
    x = Conv2D(64, (3, 3), padding="same")(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Activation("relu")(x)
    x = BatchNormalization(axis=-1)(x)

    # x = SeparableConv2D(128, (3, 3), padding="same")(inputs)
    x = Conv2D(128, (3, 3), padding="same")(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Activation("relu")(x)
    x = BatchNormalization(axis=-1)(x)

    # x = SeparableConv2D(128, (3, 3), padding="same")(inputs)
    x = Conv2D(128, (3, 3), padding="same")(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Activation("relu")(x)
    x = SpatialDropout2D(0.1)(x)
    x = BatchNormalization(axis=-1)(x)

    # x = SeparableConv2D(256, (3, 3), padding="same")(inputs)
    x = Conv2D(256, (3, 3), padding="same")(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Activation("relu")(x)
    x = SpatialDropout2D(0.1)(x)
    x = BatchNormalization(axis=-1)(x)

    # x = SeparableConv2D(256, (3, 3), padding="same")(inputs)
    x = Conv2D(256, (3, 3), padding="same")(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Activation("relu")(x)
    x = SpatialDropout2D(0.15)(x)
    x = BatchNormalization(axis=-1)(x)

    # x = SeparableConv2D(512, (3, 3), padding="same")(inputs)
    x = Conv2D(512, (3, 3), padding="same")(x)
    x = Activation("relu")(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = SpatialDropout2D(0.15)(x)
    x = BatchNormalization(axis=-1)(x)

    return x

# Dropouts: To prevent over-fitting the model during training
# relu(Rectifier Linear Unit): Activation to prevent exponential growth in the computation and the emergence of the “vanishing gradient” problem by keeping gradient always high.
# Dense layer: To create fully connected layers, in which (linear) every output depends on every input after usage of Convolutional Layers with fewer parameters by forcing
#               every input to the function and let the neurol network to learn its relation to the output.
# BatchNormalization: To speed up training and use higher learning rates, making learning easier and to guarantee that the values are within a healthy range,
#                     avoiding saturation and vanishing gradients.

def build_gender_branch(inputs):

    x = hidden_layers(inputs)

    x = Flatten()(x)

    x = Dense(128)(x)
    x = Activation("relu")(x)
    x = Dropout(0.2)(x)
    x = BatchNormalization()(x)

    x = Dense(64)(x)
    x = Activation("relu")(x)
    x = Dropout(0.2)(x)
    x = BatchNormalization()(x)

    # Why softmax! Source: (https://medium.com/arteos-ai/the-differences-between-sigmoid-and-softmax-activation-function-12adee8cf322)
    x = Dense(2)(x)
    x = Activation("softmax", name="gender_output")(x)

    return x

def build_age_branch(inputs):

    x = hidden_layers(inputs)

    x = Flatten()(x)

    x = Dense(256, kernel_regularizer=l2(0.03))(x)
    x = Activation("relu")(x)
    x = Dropout(0.2)(x)
    x = BatchNormalization()(x)

    x = Dense(128)(x)
    x = Activation("relu")(x)
    x = Dropout(0.2)(x)
    x = BatchNormalization()(x)

    x = Dense(64)(x)
    x = Activation("relu")(x)
    x = Dropout(0.2)(x)
    x = BatchNormalization()(x)

    # Why softmax! Source: (https://medium.com/arteos-ai/the-differences-between-sigmoid-and-softmax-activation-function-12adee8cf322)
    x = Dense(5)(x)
    x = Activation("softmax", name="age_output")(x)

    return x

# To assemble the model with their determined height and width.
def assemble_model(width, height, color):

    input_shape = (height, width, 3)
    inputs = Input(shape=input_shape)

    age_branch = build_age_branch(inputs)
    gender_branch = build_gender_branch(inputs)

    model = Model(inputs=inputs,
                  outputs = [age_branch, gender_branch],
                  name="face")

    return model

model = assemble_model(224, 224, 3)

from keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "face"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 32  896         ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 74, 74, 32)   0           ['conv2d[0][0]']
#
#  activation (Activation)        (None, 74, 74, 32)   0           ['max_pooling2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 74, 74, 32)  128         ['activation[0][0]']
#  alization)
#
#  conv2d_1 (Conv2D)              (None, 74, 74, 64)   18496       ['batch_normalization[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 224, 224, 32  896         ['input_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 37, 37, 64)  0           ['conv2d_1[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 74, 74, 32)  0           ['conv2d_7[0][0]']
#
#  activation_1 (Activation)      (None, 37, 37, 64)   0           ['max_pooling2d_1[0][0]']
#
#  activation_10 (Activation)     (None, 74, 74, 32)   0           ['max_pooling2d_7[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 37, 37, 64)  256         ['activation_1[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 74, 74, 32)  128         ['activation_10[0][0]']
#  ormalization)
#
#  conv2d_2 (Conv2D)              (None, 37, 37, 128)  73856       ['batch_normalization_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 74, 74, 64)   18496       ['batch_normalization_10[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 18, 18, 128)  0          ['conv2d_2[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 37, 37, 64)  0           ['conv2d_8[0][0]']
#
#  activation_2 (Activation)      (None, 18, 18, 128)  0           ['max_pooling2d_2[0][0]']
#
#  activation_11 (Activation)     (None, 37, 37, 64)   0           ['max_pooling2d_8[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 18, 18, 128)  512        ['activation_2[0][0]']
#  rmalization)
#
#  batch_normalization_11 (BatchN  (None, 37, 37, 64)  256         ['activation_11[0][0]']
#  ormalization)
#
#  conv2d_3 (Conv2D)              (None, 18, 18, 128)  147584      ['batch_normalization_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 37, 37, 128)  73856       ['batch_normalization_11[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 9, 9, 128)   0           ['conv2d_3[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 18, 18, 128)  0          ['conv2d_9[0][0]']
#
#  activation_3 (Activation)      (None, 9, 9, 128)    0           ['max_pooling2d_3[0][0]']
#
#  activation_12 (Activation)     (None, 18, 18, 128)  0           ['max_pooling2d_9[0][0]']
#
#  spatial_dropout2d (SpatialDrop  (None, 9, 9, 128)   0           ['activation_3[0][0]']
#  out2D)
#
#  batch_normalization_12 (BatchN  (None, 18, 18, 128)  512        ['activation_12[0][0]']
#  ormalization)
#
#  batch_normalization_3 (BatchNo  (None, 9, 9, 128)   512         ['spatial_dropout2d[0][0]']
#  rmalization)
#
#  conv2d_10 (Conv2D)             (None, 18, 18, 128)  147584      ['batch_normalization_12[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 9, 9, 256)    295168      ['batch_normalization_3[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 9, 9, 128)   0           ['conv2d_10[0][0]']
#  )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 256)   0           ['conv2d_4[0][0]']
#
#  activation_13 (Activation)     (None, 9, 9, 128)    0           ['max_pooling2d_10[0][0]']
#
#  activation_4 (Activation)      (None, 4, 4, 256)    0           ['max_pooling2d_4[0][0]']
#
#  spatial_dropout2d_4 (SpatialDr  (None, 9, 9, 128)   0           ['activation_13[0][0]']
#  opout2D)
#
#  spatial_dropout2d_1 (SpatialDr  (None, 4, 4, 256)   0           ['activation_4[0][0]']
#  opout2D)
#
#  batch_normalization_13 (BatchN  (None, 9, 9, 128)   512         ['spatial_dropout2d_4[0][0]']
#  ormalization)
#
#  batch_normalization_4 (BatchNo  (None, 4, 4, 256)   1024        ['spatial_dropout2d_1[0][0]']
#  rmalization)
#
#  conv2d_11 (Conv2D)             (None, 9, 9, 256)    295168      ['batch_normalization_13[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 4, 4, 256)    590080      ['batch_normalization_4[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 4, 4, 256)   0           ['conv2d_11[0][0]']
#  )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 2, 2, 256)   0           ['conv2d_5[0][0]']
#
#  activation_14 (Activation)     (None, 4, 4, 256)    0           ['max_pooling2d_11[0][0]']
#
#  activation_5 (Activation)      (None, 2, 2, 256)    0           ['max_pooling2d_5[0][0]']
#
#  spatial_dropout2d_5 (SpatialDr  (None, 4, 4, 256)   0           ['activation_14[0][0]']
#  opout2D)
#
#  spatial_dropout2d_2 (SpatialDr  (None, 2, 2, 256)   0           ['activation_5[0][0]']
#  opout2D)
#
#  batch_normalization_14 (BatchN  (None, 4, 4, 256)   1024        ['spatial_dropout2d_5[0][0]']
#  ormalization)
#
#  batch_normalization_5 (BatchNo  (None, 2, 2, 256)   1024        ['spatial_dropout2d_2[0][0]']
#  rmalization)
#
#  conv2d_12 (Conv2D)             (None, 4, 4, 256)    590080      ['batch_normalization_14[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 2, 2, 512)    1180160     ['batch_normalization_5[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 2, 2, 256)   0           ['conv2d_12[0][0]']
#  )
#
#  activation_6 (Activation)      (None, 2, 2, 512)    0           ['conv2d_6[0][0]']
#
#  activation_15 (Activation)     (None, 2, 2, 256)    0           ['max_pooling2d_12[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 1, 1, 512)   0           ['activation_6[0][0]']
#
#  spatial_dropout2d_6 (SpatialDr  (None, 2, 2, 256)   0           ['activation_15[0][0]']
#  opout2D)
#
#  spatial_dropout2d_3 (SpatialDr  (None, 1, 1, 512)   0           ['max_pooling2d_6[0][0]']
#  opout2D)
#
#  batch_normalization_15 (BatchN  (None, 2, 2, 256)   1024        ['spatial_dropout2d_6[0][0]']
#  ormalization)
#
#  batch_normalization_6 (BatchNo  (None, 1, 1, 512)   2048        ['spatial_dropout2d_3[0][0]']
#  rmalization)
#
#  conv2d_13 (Conv2D)             (None, 2, 2, 512)    1180160     ['batch_normalization_15[0][0]']
#
#  flatten (Flatten)              (None, 512)          0           ['batch_normalization_6[0][0]']
#
#  activation_16 (Activation)     (None, 2, 2, 512)    0           ['conv2d_13[0][0]']
#
#  dense (Dense)                  (None, 256)          131328      ['flatten[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 1, 1, 512)   0           ['activation_16[0][0]']
#  )
#
#  activation_7 (Activation)      (None, 256)          0           ['dense[0][0]']
#
#  spatial_dropout2d_7 (SpatialDr  (None, 1, 1, 512)   0           ['max_pooling2d_13[0][0]']
#  opout2D)
#
#  dropout (Dropout)              (None, 256)          0           ['activation_7[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 1, 1, 512)   2048        ['spatial_dropout2d_7[0][0]']
#  ormalization)
#
#  batch_normalization_7 (BatchNo  (None, 256)         1024        ['dropout[0][0]']
#  rmalization)
#
#  flatten_1 (Flatten)            (None, 512)          0           ['batch_normalization_16[0][0]']
#
#  dense_1 (Dense)                (None, 128)          32896       ['batch_normalization_7[0][0]']
#
#  dense_4 (Dense)                (None, 128)          65664       ['flatten_1[0][0]']
#
#  activation_8 (Activation)      (None, 128)          0           ['dense_1[0][0]']
#
#  activation_17 (Activation)     (None, 128)          0           ['dense_4[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['activation_8[0][0]']
#
#  dropout_3 (Dropout)            (None, 128)          0           ['activation_17[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 128)         512         ['dropout_1[0][0]']
#  rmalization)
#
#  batch_normalization_17 (BatchN  (None, 128)         512         ['dropout_3[0][0]']
#  ormalization)
#
#  dense_2 (Dense)                (None, 64)           8256        ['batch_normalization_8[0][0]']
#
#  dense_5 (Dense)                (None, 64)           8256        ['batch_normalization_17[0][0]']
#
#  activation_9 (Activation)      (None, 64)           0           ['dense_2[0][0]']
#
#  activation_18 (Activation)     (None, 64)           0           ['dense_5[0][0]']
#
#  dropout_2 (Dropout)            (None, 64)           0           ['activation_9[0][0]']
#
#  dropout_4 (Dropout)            (None, 64)           0           ['activation_18[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 64)          256         ['dropout_2[0][0]']
#  rmalization)
#
#  batch_normalization_18 (BatchN  (None, 64)          256         ['dropout_4[0][0]']
#  ormalization)
#
#  dense_3 (Dense)                (None, 5)            325         ['batch_normalization_9[0][0]']
#
#  dense_6 (Dense)                (None, 2)            130         ['batch_normalization_18[0][0]']
#
#  age_output (Activation)        (None, 5)            0           ['dense_3[0][0]']
#
#  gender_output (Activation)     (None, 2)            0           ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 4,872,903
# Trainable params: 4,866,119
# Non-trainable params: 6,784
# __________________________________________________________________________________________________

# %%
import math
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras.callbacks import LearningRateScheduler

# Learning Rate Schedules in Keras reduces the learning rate by a certain factor after certain no of epochs

#Source:    (https://github.com/ShreyanshJoshi/Facial-Demographics-using-CNN#overview)
#           (https://towardsdatascience.com/learning-rate-schedules-and-adaptive-learning-rate-methods-for-deep-learning-2c8f433990d1)
#           (https://github.com/sukilau/Ziff-deep-learning/blob/master/3-CIFAR10-lrate/CIFAR10-lrate.ipynb)

# According ot several sources (few example of it above), since the learning rate is the most important
# hyperparameter to tune the training in a neural network, it is stated that to reduce learning rate as the training progresses,
# is a good practice for a better outcome (accuracy).

#-------------------------------------------------------------
# Exponential Decay
# def exp_decay(epoch):
#    initial_lrate = 0.001
#    k = 0.2
#    lrate = initial_lrate * np.exp(-k * epoch)  # lr, k are hyperparameters and t=epoch is the iteration number
#    return lrate

#--------------------------------------------------------------

# Step Decay, to drop the learning rate by a factor every few epochs.
def step_decay(epoch):
	initial_lrate = 0.008
	drop = 0.5              # % drop rate
	epochs_drop = 4.0       # To drop after every number of epoch
	lrate = initial_lrate * math.pow(drop, math.floor((1 + epoch) / epochs_drop)) #Fromula for step_decay
	return lrate

# Source: (https://datascience.stackexchange.com/questions/42599/what-is-the-relationship-between-the-accuracy-and-the-loss-in-deep-learning)
# a low accuracy and huge loss means you made huge errors on a lot of data
# a low accuracy but low loss means you made little errors on a lot of data
# a great accuracy with low loss means you made low errors on a few data (best case)

opt = Adam(learning_rate=0.0)                   # 0.0 means not to be used here.
lrate = LearningRateScheduler(step_decay)       # At the beginning of every epoch, this callback gets the updated learning rate value
#lrate = LearningRateScheduler(exp_decay)

# `binary_crossentropy`, sigmoid activation, scalar target.
# `categorical_crossentropy`, softmax activation, one-hot encoded target.
model.compile(optimizer=opt,
              loss={
                  'age_output': 'categorical_crossentropy',
                  'gender_output': 'categorical_crossentropy'},
              metrics={
                  'age_output': 'accuracy',
                  'gender_output': 'accuracy'})

callbacks_list = [lrate]
# It is this callback that allows a function to invoke during program execution.

# %%
# class_weight in Keras: To ensure the unevenness in data distribution (as in age) is sorted out by giving the classes with fewer numbers is assigned more
# weight to prevent being biased.
from sklearn.utils import class_weight
class_weight = class_weight.compute_class_weight('balanced',
                                                 classes=np.array([0,1,2,3,4]),
                                                 y=np.array(df['age']))

class_weight1 = {'age_output': class_weight}

# %%
# To generate batches for train_idx to be able to prevent "too large to fit inside RAM at once so-called memory errors".
train_gen = generate_images(train_idx,
                            is_training=True,
                            batch_size=32)

valid_gen = generate_images(val_idx,
                            is_training=True,
                            batch_size=32)

# fit() as known fit_generator() before 2020: Validation while training the model to evaluate the loss.
history = model.fit(train_gen,
                    steps_per_epoch = len(train_idx)//32,
                    epochs=16,
                    callbacks=callbacks_list,
                    validation_data=valid_gen,
                    validation_steps=len(val_idx)//32)
# Out:
# Epoch 1/16
# 592/592 [==============================] - 123s 193ms/step - loss: 2.3306 - age_output_loss: 1.0886 - gender_output_loss: 0.5377 - age_output_accuracy: 0.5417 - gender_output_accuracy: 0.7336 - val_loss: 1.7796 - val_age_output_loss: 1.1014 - val_gender_output_loss: 0.3702 - val_age_output_accuracy: 0.5342 - val_gender_output_accuracy: 0.8294 - lr: 0.0080
# Epoch 2/16
# 592/592 [==============================] - 111s 188ms/step - loss: 1.5795 - age_output_loss: 0.8744 - gender_output_loss: 0.3652 - age_output_accuracy: 0.6312 - gender_output_accuracy: 0.8324 - val_loss: 2.1254 - val_age_output_loss: 1.3338 - val_gender_output_loss: 0.3453 - val_age_output_accuracy: 0.4335 - val_gender_output_accuracy: 0.8370 - lr: 0.0080
# Epoch 3/16
# 592/592 [==============================] - 111s 187ms/step - loss: 1.4405 - age_output_loss: 0.7756 - gender_output_loss: 0.3083 - age_output_accuracy: 0.6701 - gender_output_accuracy: 0.8625 - val_loss: 1.4678 - val_age_output_loss: 0.7540 - val_gender_output_loss: 0.3712 - val_age_output_accuracy: 0.6807 - val_gender_output_accuracy: 0.8406 - lr: 0.0080
# Epoch 4/16
# 592/592 [==============================] - 110s 185ms/step - loss: 1.1096 - age_output_loss: 0.6823 - gender_output_loss: 0.2507 - age_output_accuracy: 0.7098 - gender_output_accuracy: 0.8875 - val_loss: 1.1592 - val_age_output_loss: 0.6760 - val_gender_output_loss: 0.2554 - val_age_output_accuracy: 0.7156 - val_gender_output_accuracy: 0.8894 - lr: 0.0040
# Epoch 5/16
# 592/592 [==============================] - 108s 183ms/step - loss: 1.0414 - age_output_loss: 0.6455 - gender_output_loss: 0.2295 - age_output_accuracy: 0.7231 - gender_output_accuracy: 0.9004 - val_loss: 1.0631 - val_age_output_loss: 0.6266 - val_gender_output_loss: 0.2742 - val_age_output_accuracy: 0.7302 - val_gender_output_accuracy: 0.8794 - lr: 0.0040
# Epoch 6/16
# 592/592 [==============================] - 109s 184ms/step - loss: 1.0080 - age_output_loss: 0.6191 - gender_output_loss: 0.2181 - age_output_accuracy: 0.7357 - gender_output_accuracy: 0.9068 - val_loss: 1.0251 - val_age_output_loss: 0.6377 - val_gender_output_loss: 0.2480 - val_age_output_accuracy: 0.7204 - val_gender_output_accuracy: 0.8932 - lr: 0.0040
# Epoch 7/16
# 592/592 [==============================] - 109s 184ms/step - loss: 0.9481 - age_output_loss: 0.5895 - gender_output_loss: 0.1975 - age_output_accuracy: 0.7490 - gender_output_accuracy: 0.9152 - val_loss: 1.0439 - val_age_output_loss: 0.6072 - val_gender_output_loss: 0.2815 - val_age_output_accuracy: 0.7278 - val_gender_output_accuracy: 0.8923 - lr: 0.0040
# Epoch 8/16
# 592/592 [==============================] - 111s 187ms/step - loss: 0.7598 - age_output_loss: 0.5089 - gender_output_loss: 0.1625 - age_output_accuracy: 0.7848 - gender_output_accuracy: 0.9338 - val_loss: 0.9412 - val_age_output_loss: 0.6026 - val_gender_output_loss: 0.2358 - val_age_output_accuracy: 0.7380 - val_gender_output_accuracy: 0.9073 - lr: 0.0020
# Epoch 9/16
# 592/592 [==============================] - 110s 186ms/step - loss: 0.7116 - age_output_loss: 0.4691 - gender_output_loss: 0.1461 - age_output_accuracy: 0.8038 - gender_output_accuracy: 0.9401 - val_loss: 1.0156 - val_age_output_loss: 0.6361 - val_gender_output_loss: 0.2559 - val_age_output_accuracy: 0.7280 - val_gender_output_accuracy: 0.9079 - lr: 0.0020
# Epoch 10/16
# 592/592 [==============================] - 109s 185ms/step - loss: 0.6396 - age_output_loss: 0.4210 - gender_output_loss: 0.1334 - age_output_accuracy: 0.8291 - gender_output_accuracy: 0.9456 - val_loss: 0.9927 - val_age_output_loss: 0.6468 - val_gender_output_loss: 0.2517 - val_age_output_accuracy: 0.7418 - val_gender_output_accuracy: 0.9096 - lr: 0.0020
# Epoch 11/16
# 592/592 [==============================] - 111s 187ms/step - loss: 0.5974 - age_output_loss: 0.3802 - gender_output_loss: 0.1265 - age_output_accuracy: 0.8484 - gender_output_accuracy: 0.9493 - val_loss: 1.1431 - val_age_output_loss: 0.7863 - val_gender_output_loss: 0.2674 - val_age_output_accuracy: 0.7221 - val_gender_output_accuracy: 0.9010 - lr: 0.0020
# Epoch 12/16
# 592/592 [==============================] - 111s 187ms/step - loss: 0.4524 - age_output_loss: 0.3000 - gender_output_loss: 0.0987 - age_output_accuracy: 0.8885 - gender_output_accuracy: 0.9628 - val_loss: 1.0763 - val_age_output_loss: 0.7597 - val_gender_output_loss: 0.2734 - val_age_output_accuracy: 0.7447 - val_gender_output_accuracy: 0.9113 - lr: 0.0010
# Epoch 13/16
# 592/592 [==============================] - 115s 194ms/step - loss: 0.3817 - age_output_loss: 0.2499 - gender_output_loss: 0.0819 - age_output_accuracy: 0.9079 - gender_output_accuracy: 0.9682 - val_loss: 1.1521 - val_age_output_loss: 0.8071 - val_gender_output_loss: 0.2945 - val_age_output_accuracy: 0.7454 - val_gender_output_accuracy: 0.9113 - lr: 0.0010
# Epoch 14/16
# 592/592 [==============================] - 113s 191ms/step - loss: 0.3302 - age_output_loss: 0.2038 - gender_output_loss: 0.0758 - age_output_accuracy: 0.9255 - gender_output_accuracy: 0.9718 - val_loss: 1.1857 - val_age_output_loss: 0.8484 - val_gender_output_loss: 0.2913 - val_age_output_accuracy: 0.7411 - val_gender_output_accuracy: 0.9088 - lr: 0.0010
# Epoch 15/16
# 592/592 [==============================] - 117s 197ms/step - loss: 0.3093 - age_output_loss: 0.1891 - gender_output_loss: 0.0654 - age_output_accuracy: 0.9324 - gender_output_accuracy: 0.9770 - val_loss: 1.2522 - val_age_output_loss: 0.9121 - val_gender_output_loss: 0.2946 - val_age_output_accuracy: 0.7373 - val_gender_output_accuracy: 0.9147 - lr: 0.0010
# Epoch 16/16
# 592/592 [==============================] - 111s 188ms/step - loss: 0.2227 - age_output_loss: 0.1387 - gender_output_loss: 0.0530 - age_output_accuracy: 0.9512 - gender_output_accuracy: 0.9798 - val_loss: 1.4066 - val_age_output_loss: 1.0004 - val_gender_output_loss: 0.3769 - val_age_output_accuracy: 0.7432 - val_gender_output_accuracy: 0.9098 - lr: 5.0000e-04

# %%
# Re-training the model for better results

import math
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras.callbacks import LearningRateScheduler

def step_decay(epoch):
	initial_lrate = 0.002
	drop = 0.5
	epochs_drop = 7.0
	lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
	return lrate

opt = Adam(learning_rate=0.0)               # 0.0 means not to be used here.
lrate = LearningRateScheduler(step_decay)

train_gen = generate_images(train_idx, is_training=True, batch_size=32)
valid_gen = generate_images(val_idx, is_training=True, batch_size=32)

callbacks_list = [lrate]

history = model.fit(train_gen,
                    steps_per_epoch = len(train_idx)//32,
                    epochs=16,
                    callbacks=callbacks_list,
                    validation_data=valid_gen,
                    validation_steps=len(val_idx)//32)
# Out:
# Epoch 1/16
# 592/592 [==============================] - 105s 176ms/step - loss: 0.3997 - age_output_loss: 0.2118 - gender_output_loss: 0.0878 - age_output_accuracy: 0.9248 - gender_output_accuracy: 0.9662 - val_loss: 1.2189 - val_age_output_loss: 0.8139 - val_gender_output_loss: 0.3090 - val_age_output_accuracy: 0.7340 - val_gender_output_accuracy: 0.9065 - lr: 0.0020
# Epoch 2/16
# 592/592 [==============================] - 112s 190ms/step - loss: 0.3788 - age_output_loss: 0.2056 - gender_output_loss: 0.0840 - age_output_accuracy: 0.9269 - gender_output_accuracy: 0.9683 - val_loss: 1.2623 - val_age_output_loss: 0.8323 - val_gender_output_loss: 0.3409 - val_age_output_accuracy: 0.7380 - val_gender_output_accuracy: 0.9041 - lr: 0.0020
# Epoch 3/16
# 592/592 [==============================] - 111s 188ms/step - loss: 0.3585 - age_output_loss: 0.1984 - gender_output_loss: 0.0717 - age_output_accuracy: 0.9300 - gender_output_accuracy: 0.9738 - val_loss: 1.4602 - val_age_output_loss: 0.9864 - val_gender_output_loss: 0.3423 - val_age_output_accuracy: 0.7245 - val_gender_output_accuracy: 0.9065 - lr: 0.0020
# Epoch 4/16
# 592/592 [==============================] - 117s 199ms/step - loss: 0.3319 - age_output_loss: 0.1813 - gender_output_loss: 0.0649 - age_output_accuracy: 0.9362 - gender_output_accuracy: 0.9758 - val_loss: 1.3795 - val_age_output_loss: 0.9523 - val_gender_output_loss: 0.3608 - val_age_output_accuracy: 0.7432 - val_gender_output_accuracy: 0.9033 - lr: 0.0020
# Epoch 5/16
# 592/592 [==============================] - 110s 185ms/step - loss: 0.3113 - age_output_loss: 0.1672 - gender_output_loss: 0.0633 - age_output_accuracy: 0.9422 - gender_output_accuracy: 0.9752 - val_loss: 1.3577 - val_age_output_loss: 0.8968 - val_gender_output_loss: 0.3951 - val_age_output_accuracy: 0.7432 - val_gender_output_accuracy: 0.9079 - lr: 0.0020
# Epoch 6/16
# 592/592 [==============================] - 111s 187ms/step - loss: 0.2921 - age_output_loss: 0.1528 - gender_output_loss: 0.0608 - age_output_accuracy: 0.9493 - gender_output_accuracy: 0.9771 - val_loss: 1.3954 - val_age_output_loss: 0.9813 - val_gender_output_loss: 0.3497 - val_age_output_accuracy: 0.7443 - val_gender_output_accuracy: 0.9075 - lr: 0.0020
# Epoch 7/16
# 592/592 [==============================] - 111s 187ms/step - loss: 0.2107 - age_output_loss: 0.1203 - gender_output_loss: 0.0344 - age_output_accuracy: 0.9596 - gender_output_accuracy: 0.9875 - val_loss: 1.4901 - val_age_output_loss: 1.0416 - val_gender_output_loss: 0.4080 - val_age_output_accuracy: 0.7401 - val_gender_output_accuracy: 0.9124 - lr: 0.0010
# Epoch 8/16
# 592/592 [==============================] - 110s 186ms/step - loss: 0.1468 - age_output_loss: 0.0863 - gender_output_loss: 0.0246 - age_output_accuracy: 0.9712 - gender_output_accuracy: 0.9904 - val_loss: 1.5541 - val_age_output_loss: 1.0569 - val_gender_output_loss: 0.4668 - val_age_output_accuracy: 0.7261 - val_gender_output_accuracy: 0.9092 - lr: 0.0010
# Epoch 9/16
# 592/592 [==============================] - 118s 199ms/step - loss: 0.1417 - age_output_loss: 0.0790 - gender_output_loss: 0.0228 - age_output_accuracy: 0.9747 - gender_output_accuracy: 0.9915 - val_loss: 1.5752 - val_age_output_loss: 1.0333 - val_gender_output_loss: 0.4394 - val_age_output_accuracy: 0.7409 - val_gender_output_accuracy: 0.9126 - lr: 0.0010
# Epoch 10/16
# 592/592 [==============================] - 115s 195ms/step - loss: 0.1585 - age_output_loss: 0.0785 - gender_output_loss: 0.0199 - age_output_accuracy: 0.9745 - gender_output_accuracy: 0.9929 - val_loss: 1.7400 - val_age_output_loss: 1.2046 - val_gender_output_loss: 0.4937 - val_age_output_accuracy: 0.7321 - val_gender_output_accuracy: 0.9090 - lr: 0.0010
# Epoch 11/16
# 592/592 [==============================] - 114s 192ms/step - loss: 0.1545 - age_output_loss: 0.0749 - gender_output_loss: 0.0226 - age_output_accuracy: 0.9761 - gender_output_accuracy: 0.9921 - val_loss: 1.9008 - val_age_output_loss: 1.3685 - val_gender_output_loss: 0.4614 - val_age_output_accuracy: 0.7130 - val_gender_output_accuracy: 0.9107 - lr: 0.0010
# Epoch 12/16
# 592/592 [==============================] - 111s 187ms/step - loss: 0.1787 - age_output_loss: 0.0828 - gender_output_loss: 0.0211 - age_output_accuracy: 0.9747 - gender_output_accuracy: 0.9919 - val_loss: 1.5500 - val_age_output_loss: 1.0653 - val_gender_output_loss: 0.4503 - val_age_output_accuracy: 0.7435 - val_gender_output_accuracy: 0.9082 - lr: 0.0010
# Epoch 13/16
# 592/592 [==============================] - 110s 185ms/step - loss: 0.1195 - age_output_loss: 0.0659 - gender_output_loss: 0.0207 - age_output_accuracy: 0.9796 - gender_output_accuracy: 0.9925 - val_loss: 1.9650 - val_age_output_loss: 1.4178 - val_gender_output_loss: 0.5156 - val_age_output_accuracy: 0.7177 - val_gender_output_accuracy: 0.9145 - lr: 0.0010
# Epoch 14/16
# 592/592 [==============================] - 113s 190ms/step - loss: 0.0877 - age_output_loss: 0.0543 - gender_output_loss: 0.0125 - age_output_accuracy: 0.9831 - gender_output_accuracy: 0.9956 - val_loss: 1.6738 - val_age_output_loss: 1.1664 - val_gender_output_loss: 0.4839 - val_age_output_accuracy: 0.7498 - val_gender_output_accuracy: 0.9141 - lr: 5.0000e-04
# Epoch 15/16
# 592/592 [==============================] - 111s 187ms/step - loss: 0.0755 - age_output_loss: 0.0483 - gender_output_loss: 0.0086 - age_output_accuracy: 0.9845 - gender_output_accuracy: 0.9971 - val_loss: 1.7511 - val_age_output_loss: 1.2202 - val_gender_output_loss: 0.5130 - val_age_output_accuracy: 0.7523 - val_gender_output_accuracy: 0.9164 - lr: 5.0000e-04
# Epoch 16/16
# 592/592 [==============================] - 110s 186ms/step - loss: 0.0693 - age_output_loss: 0.0419 - gender_output_loss: 0.0084 - age_output_accuracy: 0.9872 - gender_output_accuracy: 0.9971 - val_loss: 1.9217 - val_age_output_loss: 1.3727 - val_gender_output_loss: 0.5320 - val_age_output_accuracy: 0.7428 - val_gender_output_accuracy: 0.9160 - lr: 5.0000e-04

# %%
#Source: (https://www.tensorflow.org/api_docs/python/tf/keras/models/save_model)
# Save the entire model as a SavedModel.

# save(): To create a SavedModel folder `saved_model`, containing "assets", "saved_model.pb" & "variables".
# The model architecture, and training configuration (including the optimizer, losses, and metrics) are stored in `saved_model.pb`.

# The weights are saved in the `variables/` directory.
#path = "../models/saved_model/latest_model"
#model.save(path) # Saving the above model with its latest best performance today until we apply better architecture.
#model.save('../models/saved_model/latest_model/you_model_name.tf')

# Converting to .h5 file for deployment
model.save('../models/result/latest_accuracy/best_by_now_on_20221129.h5', include_optimizer=True)

# %%
from keras.models import load_model
#loaded_model = load_model('../models/saved_model/latest_model')
#loaded_model = load_model('../models/saved_model/latest_model/you_model_name.tf')
loaded_model = load_model('../models/result/latest_accuracy/best_by_now_on_20221129.h5', compile=False)

# %%
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

# Load the image and size it.
def loadImage(filepath):
  test_img = tf.keras.utils.load_img(filepath, target_size=(224, 224, 3))
  test_img = tf.keras.preprocessing.image.img_to_array(test_img)
  test_img = np.expand_dims(test_img, axis = 0)
  test_img /= 255
  return test_img

import random as rn
from PIL import Image, ImageFont

# To choose image randomly from dataset
path=df['file']
picture = rn.choice(path)

#picture='../models/test_img/kenny-rogers.jpg' # Change the path for other image files if you would like to see more.
age_pred, gender_pred = loaded_model.predict(loadImage(picture))
img = tf.keras.preprocessing.image.load_img(picture)
plt.imshow(img)
max = -1
count = 0

for i in age_pred[0]:
  if i>max:
    max = i
    temp = count
  count+=1

#Conditions for outputs
if temp==0:
  print('0-24 yrs old')
if temp==1:
  print('25-49 yrs old')
if temp==2:
  print('50-74 yrs old')
if temp==3:
  print('75-99 yrs old')
if temp==4:
  print('91-124 yrs old')

if gender_pred[0][0]>gender_pred[0][1]:
  print('Male')
else:
  print('Female')
# Out:
# 1/1 [==============================] - 0s 78ms/step
# 75-99 yrs old
# Male

# %%
# To returns the loss value & metrics values for the model in test mode with the validation dataset
score = model.evaluate(valid_gen, steps=1000, verbose=0)
print(model.metrics_names)
print(score)
# Out:
# ['loss', 'age_output_loss', 'gender_output_loss', 'age_output_accuracy', 'gender_output_accuracy']
# [1.9239840507507324, 1.377338171005249, 0.5295826196670532, 0.7420312762260437, 0.9162499904632568]
